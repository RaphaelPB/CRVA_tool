# %%
import pandas as pd
import numpy as np
import seaborn as sns

from Functions_ImportData import import_BC_NOAA_NEX_GDDP_CMIP6
from Functions_ImportData import import_filtered_NOAA_obs
from Functions_ImportData import import_gorongosa_obs_pr

from Graphs_functions import cdf_plot_period
from Graphs_functions import cdf_plot_category_or_obs

# %%
# Observation data

# %%
df_obs_NOAA=import_filtered_NOAA_obs()

# %%
df_obs_NOAA_filtered = df_obs_NOAA.copy(deep=True)

# %%
df_obs_NOAA_filtered['Experiment'] = 'Observation data from NOAA'
df_obs_NOAA_filtered['Model'] = 'Observation data from NOAA'

# %%
df_obs_pr_gorongosa=import_gorongosa_obs_pr() # data given by Andre gorgens

# %% [markdown]
# # CDF temperature

# %% [markdown]
# ## Average temperature

# %% [markdown]
# ### BC Average temperature

# %%
tas_model_past=import_BC_NOAA_NEX_GDDP_CMIP6('tas',1970,2014,EmplacementStationNOAA='no')

# %%
tas_model_past_gorongosa = tas_model_past[tas_model_past['Name project']=='Gorongosa_EIB']

# %%
tas_model_past_gorongosa[['Daily Near-Surface Air Temperature °C']]=tas_model_past_gorongosa[['Daily Near-Surface Air Temperature °C']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\4289777325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tas_model_past_gorongosa[['Daily Near-Surface Air Temperature °C']]=tas_model_past_gorongosa[['Daily Near-Surface Air Temperature °C']].round(2)

# %%
tas_model_future=import_BC_NOAA_NEX_GDDP_CMIP6('tas',2030,2065,EmplacementStationNOAA='no')

# %%
tas_model_future_gorongosa = tas_model_future[tas_model_future['Name project']=='Gorongosa_EIB']

# %%
tas_model_future_gorongosa[['Daily Near-Surface Air Temperature °C']]=tas_model_future_gorongosa[['Daily Near-Surface Air Temperature °C']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\4267598522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tas_model_future_gorongosa[['Daily Near-Surface Air Temperature °C']]=tas_model_future_gorongosa[['Daily Near-Surface Air Temperature °C']].round(2)

# %%
df_obs_NOAA_filtered_tas = df_obs_NOAA_filtered[['DATE','TAVG','NAME','Year','Month','Season']].copy(deep=True)

# %%
df_obs_NOAA_filtered_tas_Chimoio = df_obs_NOAA_filtered_tas[df_obs_NOAA_filtered_tas['NAME']=='CHIMOIO, MZ']

# %%
df_obs_NOAA_filtered_tas_Chimoio.rename(columns={'DATE':'Date','TAVG':'Daily Near-Surface Air Temperature °C','NAME':'Name project'},inplace=True)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\2429006925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obs_NOAA_filtered_tas_Chimoio.rename(columns={'DATE':'Date','TAVG':'Daily Near-Surface Air Temperature °C','NAME':'Name project'},inplace=True)

# %%
df = pd.concat([tas_model_past_gorongosa[tas_model_past_gorongosa['Year'].between(1974,2014)],tas_model_future_gorongosa])

# %% [markdown]
# result
# ![image.png](attachment:image.png)

# %%
#cdf_plot_period(df,['1974-2014','2030-2065'],'Daily Near-Surface Air Temperature °C')

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=tas_model_past_gorongosa[tas_model_past_gorongosa['Year'].between(1974,2014)],name_column_df='Daily Near-Surface Air Temperature °C',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_tas_Chimoio[df_obs_NOAA_filtered_tas_Chimoio['Year'].between(1974,2014)],name_column_obs='Daily Near-Surface Air Temperature °C',source_obs='NOAA')

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=tas_model_future_gorongosa,name_column_df='Daily Near-Surface Air Temperature °C',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_tas_Chimoio[df_obs_NOAA_filtered_tas_Chimoio['Year'].between(1974,2014)],name_column_obs='Daily Near-Surface Air Temperature °C',source_obs='NOAA')

# %% [markdown]
# ## Maximum temperature

# %% [markdown]
# ### BC Maximum temperature

# %%
tasmax_model_past=import_BC_NOAA_NEX_GDDP_CMIP6('tasmax',1970,2014,EmplacementStationNOAA='no')

# %%
tasmax_model_past_gorongosa = tasmax_model_past[tasmax_model_past['Name project']=='Gorongosa_EIB']

# %%
tasmax_model_past_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']]=tasmax_model_past_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\3548128256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tasmax_model_past_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']]=tasmax_model_past_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']].round(2)

# %%
tasmax_model_future=import_BC_NOAA_NEX_GDDP_CMIP6('tasmax',2030,2065,EmplacementStationNOAA='no')

# %%
tasmax_model_future_gorongosa = tasmax_model_future[tasmax_model_future['Name project']=='Gorongosa_EIB']

# %%
tasmax_model_future_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']]=tasmax_model_future_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\732133084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tasmax_model_future_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']]=tasmax_model_future_gorongosa[['Daily Maximum Near-Surface Air Temperature °C']].round(2)

# %%
df_obs_NOAA_filtered_tasmax = df_obs_NOAA_filtered[['DATE','TMAX','NAME','Year','Month','Season']]

# %%
df_obs_NOAA_filtered_tasmax_Chimoio = df_obs_NOAA_filtered_tasmax[df_obs_NOAA_filtered_tasmax['NAME']=='CHIMOIO, MZ']

# %%
df_obs_NOAA_filtered_tasmax_Chimoio.rename(columns={'TMAX':'Daily Maximum Near-Surface Air Temperature °C'},inplace=True)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\1041583839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obs_NOAA_filtered_tasmax_Chimoio.rename(columns={'TMAX':'Daily Maximum Near-Surface Air Temperature °C'},inplace=True)

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=tasmax_model_past_gorongosa[tasmax_model_past_gorongosa['Year'].between(1974,2014)],name_column_df='Daily Maximum Near-Surface Air Temperature °C',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_tasmax_Chimoio[df_obs_NOAA_filtered_tasmax_Chimoio['Year'].between(1974,2014)],name_column_obs='Daily Maximum Near-Surface Air Temperature °C',source_obs='NOAA')

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=tasmax_model_future_gorongosa,name_column_df='Daily Maximum Near-Surface Air Temperature °C',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_tasmax_Chimoio[df_obs_NOAA_filtered_tasmax_Chimoio['Year'].between(1974,2014)],name_column_obs='Daily Maximum Near-Surface Air Temperature °C',source_obs='NOAA')

# %% [markdown]
# # Precipitation

# %% [markdown]
# ## BC precipitation data

# %%
pr_model_past=import_BC_NOAA_NEX_GDDP_CMIP6('pr',1970,2014,EmplacementStationNOAA='no')

# %%
pr_model_past_gorongosa = pr_model_past[pr_model_past['Name project']=='Gorongosa_EIB']

# %%
pr_model_past_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_past_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\2227886719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pr_model_past_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_past_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)

# %%
pr_model_future=import_BC_NOAA_NEX_GDDP_CMIP6('pr',2030,2065,EmplacementStationNOAA='no')

# %%
pr_model_future_gorongosa = pr_model_future[pr_model_future['Name project']=='Gorongosa_EIB']

# %%
pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\635422009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)

# %%
pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\635422009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']]=pr_model_future_gorongosa[['Mean of the daily precipitation rate mm_per_day']].round(2)

# %%
df_obs_NOAA_filtered_pr = df_obs_NOAA_filtered[['DATE','PRCP','NAME','Year','Month','Season']]

# %%
df_obs_NOAA_filtered_pr_Chimoio = df_obs_NOAA_filtered_pr[df_obs_NOAA_filtered_pr['NAME']=='CHIMOIO, MZ']

# %%
df_obs_NOAA_filtered_pr_Chimoio.rename(columns={'PRCP':'Mean of the daily precipitation rate mm_per_day'},inplace=True)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_12756\2174701187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obs_NOAA_filtered_pr_Chimoio.rename(columns={'PRCP':'Mean of the daily precipitation rate mm_per_day'},inplace=True)

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=pr_model_past_gorongosa[pr_model_past_gorongosa['Year'].between(1974,2014)],name_column_df='Mean of the daily precipitation rate mm_per_day',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_pr_Chimoio[df_obs_NOAA_filtered_pr_Chimoio['Year'].between(1974,2014)],name_column_obs='Mean of the daily precipitation rate mm_per_day',source_obs='NOAA')

# %%
cdf_plot_category_or_obs('Gorongosa',df_initial=pr_model_future_gorongosa,name_column_df='Mean of the daily precipitation rate mm_per_day',source_df='NEX-GDDP-CMIP6',category='Experiment',obs_initial=df_obs_NOAA_filtered_pr_Chimoio[df_obs_NOAA_filtered_pr_Chimoio['Year'].between(1974,2014)],name_column_obs='Mean of the daily precipitation rate mm_per_day',source_obs='NOAA')
