# %% [markdown]
# This notebook contains the treatment of the data from the NOAA stations. Some of the data were absurd for temperature (temperature above the highest registered temperature 57 celsius degrees), so data above 57 degrees were removed.
#
# Concerning precipitation data from Gorongosa, a column to count the missing data needed to be added to the dataset, to plot the compare_3_lines.

# %%
from Functions_ImportData import import_treat_obs_NOAA
from Functions_ImportData import treat_NOAA_data
from Functions_ImportData import count_na_in_df_NOAA
from Functions_Indicators import str_month
from Functions_Indicators import add_year_month_season

import pandas as pd
import numpy as np
import os
import os.path

# %%
daily_sum_obs_from_NOAA = import_treat_obs_NOAA()

# %%
daily_sum_obs_from_NOAA
# Out:
#             STATION           NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 1       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 2       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 3       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 4       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# ...             ...            ...       ...        ...        ...
# 161770  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 161771  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 161772  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 161773  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 161774  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
#
#               DATE  PRCP PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX  \
# 0       1974-04-05   2.0             ,,S  23.8            H,,S  29.0
# ...

# %%
# take out impossible observation data

## We can see for some maximum temperature observation data that some data points are completely impossible 
#  (100 for minimum or maximum temperature at Chimoio and Beira sometimes)
#daily_sum_obs_from_NOAA=daily_sum_obs_from_NOAA[daily_sum_obs_from_NOAA['TMAX']<80]
#daily_sum_obs_from_NOAA=daily_sum_obs_from_NOAA[daily_sum_obs_from_NOAA['TMIN']<80]
#daily_sum_obs_from_NOAA=daily_sum_obs_from_NOAA[daily_sum_obs_from_NOAA['TAVG']<80]

daily_sum_obs_from_NOAA.loc[daily_sum_obs_from_NOAA['TMAX']>57,'TMAX'] = np.nan
daily_sum_obs_from_NOAA.loc[daily_sum_obs_from_NOAA['TMIN']>57,'TMIN'] = np.nan
daily_sum_obs_from_NOAA.loc[daily_sum_obs_from_NOAA['TAVG']>57,'TAVG'] = np.nan

# %%
daily_sum_obs_from_NOAA = treat_NOAA_data(daily_sum_obs_from_NOAA)
# Out:
# C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\Functions_ImportData.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name_col+' MISSING']=0
# C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\Functions_ImportData.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name_col+' MISSING'][df[name_col].isna()]=1
# C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\Functions_ImportData.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
daily_sum_obs_from_NOAA
# Out:
#             STATION           NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 1       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 2       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 3       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# 4       MZM00067223  MONTEPUEZ, MZ   -13.133     39.033      535.0
# ...             ...            ...       ...        ...        ...
# 159722  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 159723  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 159724  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 159725  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
# 159726  MZ000067297      BEIRA, MZ   -19.800     34.900       16.0
#
#               DATE  PRCP PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  ...  \
# 0       1974-04-05   2.0             ,,S  23.8            H,,S  ...
# ...

# %%
out_path = r'C:\Users\CLMRX\COWI\A248363 - Climate analysis - Documents\General\CRVA_tool\Master_thesis\Project\3 - Implementation\1 - Data\1-BC\NOAA-ClimateDataOnline'

# %%
name_file = 'filtred_NOAA_obs_data.csv'

# %%
daily_sum_obs_from_NOAA.to_csv(os.path.join(out_path,name_file))

# %%
# pr from meteorological station gorongosa

# %%
path = r'C:\Users\CLMRX\COWI\A248363 - Climate analysis - Documents\General\CRVA_tool\Master_thesis\Project\3 - Implementation\1 - Data\1-BC\DirecltyfromMoz\Precipitation_Gorongosa_reformat.csv'
pr_obs_gorongosa_from_gorongosa = pd.read_csv(path)
pr_obs_gorongosa_from_gorongosa=add_year_month_season(pr_obs_gorongosa_from_gorongosa,'time')
pr_obs_gorongosa_from_gorongosa['pr'][pr_obs_gorongosa_from_gorongosa['pr']=='s/i'] = pr_obs_gorongosa_from_gorongosa['pr'].iloc[0]
pr_obs_gorongosa_from_gorongosa['pr'] = pr_obs_gorongosa_from_gorongosa['pr'].astype(float)
pr_obs_gorongosa_from_gorongosa
# Out:
#              time     pr  Year Month Season
# 0      1980-01-01    NaN  1980   Jan  Humid
# 1      1980-01-02    NaN  1980   Jan  Humid
# 2      1980-01-03    NaN  1980   Jan  Humid
# 3      1980-01-04    NaN  1980   Jan  Humid
# 4      1980-01-05    NaN  1980   Jan  Humid
# ...           ...    ...   ...   ...    ...
# 14971  2020-12-27    2.7  2020   Dec  Humid
# 14972  2020-12-28    0.0  2020   Dec  Humid
# 14973  2020-12-29    0.0  2020   Dec  Humid
# 14974  2020-12-30  138.4  2020   Dec  Humid
# 14975  2020-12-31   80.4  2020   Dec  Humid
#
# [14976 rows x 5 columns]

# %%
# this function 'count_na_in_df_NOAA' count the missing values in the columns named name_col in the dataframe df
pr_obs_gorongosa_from_gorongosa_treated=count_na_in_df_NOAA(pr_obs_gorongosa_from_gorongosa,'pr')
# Out:
# C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\Functions_ImportData.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name_col+' MISSING'][df[name_col].isna()]=1

# %%
pr_obs_gorongosa_from_gorongosa_treated.to_csv(r'C:\Users\CLMRX\COWI\A248363 - Climate analysis - Documents\General\CRVA_tool\Master_thesis\Project\3 - Implementation\1 - Data\1-BC\DirecltyfromMoz\Precipitation_Gorongosa_reformat_ready_to_use.csv')
