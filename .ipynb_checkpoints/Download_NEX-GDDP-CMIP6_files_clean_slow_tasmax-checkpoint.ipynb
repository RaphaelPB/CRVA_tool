# %% [markdown]
# # User input

# %%
variable_of_interest = 'tasmax' # need hurs, rsds, sfcWind, tas, tasmax
start_year = 1950
stop_year = 2100

# %% [markdown]
# # Import Packages

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

import pandas as pd

import os
import os.path

from netCDF4 import Dataset

import numpy as np
import numpy.ma as ma

import multiprocessing as mp# to download several file in parrallel
from multiprocessing.pool import ThreadPool

# %% [markdown]
# # Define Functions

# %%
# function to extract the name of the file from its url
# the imput is an url
def extract_name_file(url):
    index_before_name=url.rfind('/') # returns the highest index where the last character '/' was found, which is just before the name of the file    
    name = url[index_before_name+1:len(url)] # return the name of the file as a string, with the suffix '.nc'
    return name

# function 'produce_name_list' produce a list of files' name, with the suffix '.nc'
# 'produce_name_list' use the function 'extract_name_file' to have the name of a file from its url
# the input is a list of url, from which we want to extract the corresponding names of files
def produce_name_list(url_list):
    name_list=[] # create empty list
    for file in url_list:
        f_name = extract_name_file(file) # return the name of the file as a string, with the suffix '.nc'
        name_list.append(f_name) # add extracted name in the list
    return name_list # return the list of names in the url_list

# %%
# function download_file download the file in the url given as input
# the input is an url of a file
def download_file(file):
    # find the name of the file
    f_name = extract_name_file(file) # return the name of the file as a string, with the suffix '.nc' at the end of the name
    # check if the file was already downloaded
    #test = os.path.join('//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/',f_name+'.nc')
    #if os.path.isfile(test): # if the file was aleready download
        #continue # continue the for loop without executing the code after this line. The code follonwing download the file
    #    return# if we entered the if, the file was already dowloaded, no need to downloaded it again
    # the file was not downloaded, the following code will permit to download it in the servor for dataset
    
    # this will get the url and retry 10 times in case of requests.exceptions.ConnectionError
    # backoff_factor will help to apply delays between attempts to avoid failing again in case of periodic request quota
    session = requests.Session()
    retry = Retry(connect=10, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    
    with session.get(file) as r:
        # download data in the servor for datasets
        with open(f'//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/{f_name}', 'wb') as f:
            f.write(r.content)
    print('The file '+f_name+' is downloaded')
    return file

# %%
# function 'list_name_corrupted_file' aims to return a list of names, corresponding to the names of the corrupted files
# in the name_list given as input
def list_name_corrupted_file(name_list,out_path):
    ## Hypothesis: some files are corrupted
    # check if files are corrupted and count the corrupted ones
    invalid_files = [] # create an empty list to register the names of the corrupted files
    for name in name_list:
        if not name.endswith('.nc'):
            name = name + '.nc'
        if test_open_file(os.path.join(out_path,name))!=[]:
            invalid_files.append(name) # register name of the corrupted files
    return invalid_files # return a list of names, with suffix '.nc', of corrupted files

# %%
def test_open_file(path):
    try:
        im = Dataset(path)
        name = []
        im.close()
    except (IOError, OSError):
        # the files is corrupted
        name = extract_name_file(path) # return the name of the file as a string, with the suffix '.nc'
    return name

# %%
# list urls that should be downloaded again
def url_to_download_again(url_list,invalid_files):
    url_corrupted_file = []
    for url in url_list:
        f_name = extract_name_file(url) # return the name of the file as a string
        if f_name in invalid_files:
            url_corrupted_file.append(url)

    dict ={' fileUrl':url_corrupted_file}
    df = pd.DataFrame(dict)
    path = os.path.join(out_path,'file_to_download_again.csv')
    df.to_csv(path)
    return url_corrupted_file

# %%
## those three function are used to have the information concerning a file
## information are in the name of the file, so the name of the file is used to find its related information
## information mean variable, time_aggregation, model, scenario, year of the file

### this function permit to extract the word before the first character '_' in the input 'name'
### the input name is in format str
### returning the new_name, without the word found, will permit to re-use the function to find all 
#     the information concerning the studied file
def name_next_boundary(name):
    index_before_name=name.find('_') # returns the lowest index where the character '_' was found
    word = name[0:index_before_name] # first word in the string 'name', before the first character '_'
    new_name = name.replace(word+'_','') # delete the word found from the string 'name'
    return word, new_name # return, in string format, the word found (which is an information of the studied file), 
                    # and the string 'new_name', which is 'name' without the word found

# this function permit to extract the year of the studied file
# the year is always writen at the end of the name's file
# the input name is in format str
def find_year(name):
    index_before_name=name.rfind('_') # returns the highest index where the character '_' was found
    # the last character '_' is just before the year in the string 'name'
    # determine if the string 'name' ends with '.nc'
    if name.endswith('.nc'):
        # 'name' ends with '.nc'
        name_end = 3 # the three last character of the string name will be removed to find the year of the studied file
    else:
        # 'name' does not end with '.nc'
        name_end = 0 # no character will be removed at the end of 'name' to find the year of the studied file
    year = name[index_before_name+1:len(name)-name_end] # the year is extracted from the name of the file studied
    # based on the index_before_name (highest index where the character '_' was found) and the suffix of 'name'
    return year # the year in string format is returned

# This function use the functions 'name_next_boundary' and 'find_year' to extract the information of the file studied
# the input name is in format str, the name of the file from which we want information
def data_information(name):
    #### use of the function 'name_next_boundary': each time it is used, 
    # returns an information, and the name of the studied file without this information
    (variable, shorten_name) = name_next_boundary(name)
    (time_aggregation, shorten_name) = name_next_boundary(shorten_name)
    (model, shorten_name) = name_next_boundary(shorten_name)
    (scenario, shorten_name) = name_next_boundary(shorten_name)
    #### use the function 'find_year' to extract the information 'year' from the string 'shorten_name'
    year = find_year(shorten_name)
    # the function returns all the information of the studied file
    return variable, time_aggregation, model, scenario, year

# %% [markdown]
# # Define Paths

# %%
out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6'

# %% [markdown]
# # Complete list of url with files to download

# %%
# register information from csv file
#all_urls = pd.read_csv(r'C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\outputs\NEX-GDDP-CMIP6\gddp-cmip6-thredds-fileserver.csv')
csv_path = os.path.join(out_path,'gddp-cmip6-thredds-fileserver.csv')
all_urls = pd.read_csv(csv_path)

# %%
### make all elements of the csv into a readable list

temp_list = all_urls[[' fileUrl']].T# transpose csv
temp_list=temp_list.values.tolist()
temp_list=temp_list[0]
url_list=[s.replace(' ', '') for s in temp_list]

# %% [markdown]
# # Interest in temperature files
# Define list of url and files' names corresponding to temperature files between start day and stop day

# %%
url_list_climate_variable = [url for url in url_list if variable_of_interest in url and int(url[len(url)-7:len(url)-3])>=start_year and int(url[len(url)-7:len(url)-3])<=stop_year and 'r1i1p1f1_gn' in url and 'day' in url]

# %%
len(url_list_climate_variable)
# Out:
# 5468

# %%
name_list_climate_variable = produce_name_list(url_list_climate_variable)

# %%
name_list_climate_variable
# Out:
# ['tasmax_day_ACCESS-CM2_historical_r1i1p1f1_gn_
nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2015.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2016.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2017.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2018.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2019.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2020.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2021.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2022.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2024.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2025.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2023.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2027.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2028.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2029.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2030.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2031.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2032.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2033.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2034.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2035.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2036.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2037.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2038.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2039.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2041.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2042.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2043.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2044.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2045.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2047.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2049.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2050.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2051.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2052.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2053.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2055.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2056.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2058.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2059.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2060.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2062.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2063.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2066.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2068.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2070.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2071.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2072.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2073.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2074.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2075.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2076.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2078.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2079.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2080.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2081.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2082.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2083.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2084.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2085.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2086.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2087.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2088.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2089.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2090.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2091.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2092.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2093.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2096.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2097.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2095.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2098.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2099.nc',
#  'tasmax_day_CanESM5_ssp245_r1i1p1f1_gn_2100.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2015.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2016.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2017.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2018.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2019.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2020.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2021.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2022.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2023.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2024.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2025.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2027.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2028.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2029.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2030.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2031.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2032.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2033.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2034.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2035.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2036.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2037.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2038.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2039.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2041.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2042.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2043.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2044.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2045.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2047.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2049.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2050.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2051.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2052.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2053.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2055.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2056.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2058.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2059.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2060.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2062.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2063.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2066.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2068.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2070.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2071.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2072.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2073.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2074.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2075.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2076.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2078.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2079.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2080.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2081.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2082.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2083.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2084.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2085.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2086.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2087.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2088.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2089.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2090.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2091.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2092.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2093.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2095.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2096.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2097.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2098.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2099.nc',
#  'tasmax_day_CanESM5_ssp585_r1i1p1f1_gn_2100.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1950.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1951.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1952.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1953.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1954.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1955.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1956.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1957.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1958.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1959.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1960.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1961.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1962.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1963.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1964.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1965.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1966.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1967.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1968.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1969.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1970.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1971.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1972.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1973.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1974.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1975.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1976.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1977.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1978.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1979.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1980.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1981.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1982.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1983.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1984.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1985.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1986.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1987.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1988.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1989.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1990.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1991.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1992.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1993.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1994.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1995.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1996.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1997.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1998.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1999.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2000.nc',
#  'tasmax_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2001.nc',
#  ...]

# %%
try:
    for file in url_list_climate_variable: # for loop to download the file in each url
        f_name = extract_name_file(file)
        test = os.path.join('//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/',f_name)
        if os.path.isfile(test): # if the file was aleready download
            if test_open_file(test)==[]:
                print('The file '+f_name+' is not corrupted')
                continue # continue the for loop
        # the file was already downloaded but is corrupted
        download_file(file)
except TimeoutError:
    print('TimeoutError')
except MaxRetryError:
    print('MaxRetryError')

# %% [markdown]
# # List of corrupted files to download again

# %%
name_list_climate_variable_corrupted = list_name_corrupted_file(name_list_climate_variable,out_path)
url_corrupted_file=url_to_download_again(url_list_climate_variable,name_list_climate_variable_corrupted)
len(name_list_climate_variable_corrupted) # 2750
# Out:
# 2750

# %%
name_list_climate_variable_corrupted
# Out:
# ['tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2081.nc',
#  'tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2086.nc',
#  'tasmax_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2006.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2075.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2074.nc',
#  'tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2091.nc',
#  'tasmax_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1983.nc',
#  'tasmax_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_NESM3_historical_r1i1p1f1_gn_1993.nc',
#  'tasmax_day_NESM3_historical_r1i1p1f1_gn_2000.nc',
#  'tasmax_day_NESM3_ssp245_r1i1p1f1_gn_2042.nc',
#  'tasmax_day
nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2093.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2084.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2100.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2099.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2098.nc',
#  'tasmax_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2097.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2016.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2017.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2018.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2024.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2025.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2023.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2019.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2022.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2020.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2027.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2021.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2031.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2028.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2029.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2030.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2015.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2034.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2042.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2037.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2041.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2035.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2036.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2039.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2032.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2051.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2033.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2052.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2038.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2047.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2043.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2055.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2053.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2060.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2049.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2058.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2056.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2044.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2045.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2050.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2062.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2070.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2059.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2063.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2071.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2068.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2075.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2066.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2080.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2074.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2083.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2085.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2082.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2076.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2079.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2086.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2072.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2073.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2089.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2081.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2097.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2095.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2096.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2087.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2078.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2099.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2093.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2084.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2098.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2090.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2100.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2088.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2092.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2091.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2021.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2025.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2027.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2028.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2020.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2017.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2015.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2022.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2024.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2019.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2018.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2033.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2030.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2023.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2029.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2032.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2036.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2035.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2016.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2042.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2037.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2038.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2043.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2047.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2041.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2045.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2039.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2031.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2044.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2052.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2051.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2053.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2034.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2058.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2059.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2049.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2056.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2055.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2050.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2072.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2062.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2071.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2073.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2063.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2068.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2070.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2060.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2066.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2083.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2075.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2079.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2081.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2082.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2076.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2074.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2084.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2091.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2080.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2092.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2090.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2085.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2088.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2098.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2086.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2097.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2078.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2095.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2094.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2089.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2093.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2087.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2100.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2096.nc',
#  'tasmax_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2099.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2017.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2016.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2018.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2021.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2025.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2022.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2015.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2027.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2026.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2019.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2024.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2032.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2028.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2029.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2023.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2020.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2041.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2030.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2031.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2038.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2042.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2037.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2034.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2040.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2033.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2044.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2043.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2035.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2046.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2050.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2047.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2045.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2036.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2054.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2039.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2051.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2053.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2058.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2052.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2057.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2049.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2061.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2060.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2056.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2048.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2064.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2065.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2055.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2066.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2063.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2062.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2069.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2077.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2067.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2079.nc',
#  'tasmax_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2075.nc',
#  ...]

# %% [markdown]
# # Download file of interest

# %%
# download with for loop
while len(url_corrupted_file) != 0: # while the list 'url_corrupted_file' is not empty, the following code will continue
    for file in url_corrupted_file: # for loop to download the file in each url
        f_name = extract_name_file(file)
        test = os.path.join('//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/',f_name)
        if os.path.isfile(test): # if the file was aleready download
            if test_open_file(test)==[]:
                # file is not corrupted
                print('The file '+f_name+' exists is not corrupted')
                continue # continue the for loop
        # the file was already downloaded but is corrupted
        download_file(file)
    # check if all downloaded files are not corrupted
    name_list_climate_variable_corrupted = list_name_corrupted_file(name_list_climate_variable,out_path)
    url_corrupted_file=url_to_download_again(url_list_climate_variable,name_list_climate_variable_corrupted)
# Out:
# The file tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2054.nc is downloaded
# The file tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2077.nc is downloaded
# The file tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2081.nc is downloaded
# The file tasmax_day_MIROC6_ssp585_r1i1p1f1_gn_2086.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2006.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2057.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2061.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2065.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2067.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2069.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2075.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2094.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2026.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2046.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2064.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2074.nc is downloaded
# The file tasmax_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2091.nc is downloaded
# The file tasmax_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1983.nc is downloaded
# The file tasmax_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2040.nc is downloaded
# The file tasmax_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2048.nc is downloaded
# The file tasmax_day_NESM3_historical_r1i1p1f1_gn_1993.nc is downloaded
# The file tasmax_day_NESM3_historical_r1i1p1f1_gn_2000.nc is downloaded
# The file tasmax_day_NESM3_ssp245_r1i1p1f1_gn_2042.nc is downloaded
# The file tasmax_day_NESM3_ssp585_r1i1p1f1_gn_2048.nc is downloaded
# The file tasmax_day_NESM3_ssp585_r1i1p1f1_gn_2074.nc is downloaded
# The file tasmax_day_NESM3_ssp585_r1i1p1f1_gn_2082.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1955.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1956.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1970.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1971.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1975.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1987.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1991.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_1997.nc is downloaded
# The file tasmax_day_NorESM2-LM_historical_r1i1p1f1_gn_2011.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2056.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2058.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2064.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2066.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2067.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2068.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2069.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2070.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2071.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2072.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2073.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2074.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2076.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2078.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2079.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2080.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2081.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2082.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2083.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2084.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2085.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2087.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2089.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2090.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2091.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2092.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2094.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2095.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2096.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2097.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2098.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2099.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2015.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2019.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2020.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2021.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2023.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2024.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2025.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2026.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2027.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2028.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2031.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2032.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2033.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2035.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2036.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2037.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2038.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2040.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2042.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2043.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2046.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2048.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2049.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2050.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2052.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2054.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2055.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2056.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2057.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2058.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2059.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2060.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2061.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2063.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2064.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2065.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2066.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2067.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2069.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2070.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2071.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2072.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2074.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2075.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2076.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2077.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2078.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2079.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2080.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2081.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2082.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2083.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2084.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2085.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2086.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2087.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2088.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2089.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2090.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2091.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2092.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2093.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2094.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2095.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2096.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2097.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2098.nc is downloaded
# The file tasmax_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2100.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1950.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1951.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1953.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1954.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1955.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1956.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1957.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1958.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1959.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1960.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1961.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1962.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1963.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1964.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1965.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1966.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1968.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1969.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1970.nc is downloaded
# The file tasmax_day_NorESM2-MM_historical_r1i1p1f1_gn_1971.nc is downloaded
