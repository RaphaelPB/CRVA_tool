# %% [markdown]
# # User input

# %%
variable_of_interest = 'pr_' # add list of available name variable
# the user should indicate the years of the period of interest
start_year = 1950
stop_year = 2100 # if the user only wants one year, the same year as the start_year should be indicated

# %% [markdown]
# # Import Packages and functions

# %%
import requests
import pandas as pd

import os
import os.path

from netCDF4 import Dataset

import xarray as xr

import numpy as np
import numpy.ma as ma

# to measure elapsed time
import time
from timeit import default_timer as timer

import multiprocessing as mp# to download several file in parrallel
from multiprocessing.pool import ThreadPool

# %% [markdown]
# # Functions

# %%
# function to extract the name of the file from its url
# the input is an url
def extract_name_file(url):
    index_before_name=url.rfind('/') # returns the highest index where the last character '/' was found, which is just before the name of the file    
    name = url[index_before_name+1:len(url)] # return the name of the file as a string, with the suffix '.nc'
    return name

# function 'produce_name_list' produce a list of files' name, with the suffix '.nc'
# 'produce_name_list' use the function 'extract_name_file' to have the name of a file from its url
# the input is a list of url, from which we want to extract the corresponding names of files
def produce_name_list(url_list):
    name_list=[] # create empty list
    for file in url_list:
        f_name = extract_name_file(file) # return the name of the file as a string, with the suffix '.nc'
        name_list.append(f_name) # add extracted name in the list
    return name_list # return the list of names in the url_list

# %%
# function produce_year produce:
#      year: a vector containing all the year in the period of interest
#      year_str: a array containing all the year in the period of interest in the string format
#      index: a array containing the index of the year and year_str
#### Parameters of the function
#      first_year: number in int format, of the first year of the period of interest
#      last_year: number in int format, of the last year of the period of interest
def produce_year(first_year,last_year):
    year = np.arange(first_year,(last_year+1),1) # create vector of years
    year_str = [0]*len(year) # create initiale empty vector to convert years in int
    index = np.arange(0,len(year)) # create vector of index for year
    i = 0 # initialize index
    for i in index: # convert all the date in string format
        year_str[i]=str(year[i])
    return (year, year_str, index)

# %%
# this functions aims to regroup all the scenarios, models, time_aggregation and variables in vectors
# the function use the function 'data_information'

def information_files_in_vectors(name_list):
    variables= []
    time_aggregations= []
    models= []
    scenarios= []
    for file_name in name_list:
        (variable, time_aggregation, model, scenario, year) = data_information(file_name) 
        # use function data_information to find information concerning the file_name
        if variable not in variables:
            variables.append(variable)
        if time_aggregation not in time_aggregations:
            time_aggregations.append(time_aggregation)
        if model not in models:
            models.append(model)
        if scenario not in scenarios:
            scenarios.append(scenario)
    return variables, time_aggregations,models,scenarios

# %%
# this functions aims to return the closest latitudes and longitudes to the projects, and the respectives index 
#  in the lat and lon vectors of the file
def _lat_lon(path,lat_projects,lon_projects):
    ds =  xr.open_dataset(path) 
    # ds.indexes['time'] gives back CFTimeIndex format, with hours. The strftime('%d-%m-%Y') permits to have time 
    # as an index, with format '%d-%m-%Y'. The .values permits to have an array
    lat  = ds.lat.values
    lon  = ds.lon.values
    ds.close() # to spare memory
    # preallocate space for the future vectors
    index_closest_lat = []
    index_closest_lon = []
    closest_value_lat = []
    closest_value_lon = []
    for j in np.arange(0,len(lat_projects)):
        (A,B)=closest_lat_lon_to_proj(lat_projects[j],lat)
        index_closest_lat.append(A[0])
        closest_value_lat.append(B[0])
        (C,D)=closest_lat_lon_to_proj(lon_projects[j],lon)
        index_closest_lon.append(C[0])
        closest_value_lon.append(D[0])
    return index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon

# %%
# this function aims to select the closest point to the geographical point of the project
# the function takes as input 
#     location_project, which is a numpy.float64
#     vector, which is a numpy.ndarray
# the function returns
#     closest_value[0], a numpy.float64

def closest_lat_lon_to_proj(location_project,vector):
    # the function any() returns a boolean value. Here, the function test if there are elements in the array 
    # containing the difference between the vector and the location_project, equal to the minimum of the absolute 
    # value of the difference between the vector and the location_project
    if any(np.where((vector - location_project) == min(abs(vector - location_project)))[0]):
        # the function any() returned True
        # there is an element in the vector that is equal to the minimum of the absolute value of the difference 
        # between the vector and the location_project
        
        # the function np.where() returns the index for which (vector - location_project) == min(abs(vector - location_project))
        index_closest = np.where((vector - location_project) == min(abs(vector - location_project)))[0]
        closest_value = vector[index_closest]
    else:
        # the function any() returned False
        # there is NO element in the vector that is equal to the minimum of the absolute value of the difference 
        # between the vector and the location_project
        
        # the function np.where() returns the index for which (vector - location_project) == -min(abs(vector - location_project))
        index_closest = np.where((vector - location_project) == -min(abs(vector - location_project)))[0]
        closest_value = vector[index_closest]
    return index_closest, closest_value 
    # the function returns
    #     first, the value of the index of the element of vector, that is the closest to location_project    
    #     second, the array containing the element of vector, that is the closest to location_project

# %%
## those three function are used to have the information concerning a file
## information are in the name of the file, so the name of the file is used to find its related information
## information mean variable, time_aggregation, model, scenario, year of the file

### this function permit to extract the word before the first character '_' in the input 'name'
### the input name is in format str
### returning the new_name, without the word found, will permit to re-use the function to find all 
#     the information concerning the studied file
def name_next_boundary(name):
    index_before_name=name.find('_') # returns the lowest index where the character '_' was found
    word = name[0:index_before_name] # first word in the string 'name', before the first character '_'
    new_name = name.replace(word+'_','') # delete the word found from the string 'name'
    return word, new_name # return, in string format, the word found (which is an information of the studied file), 
                    # and the string 'new_name', which is 'name' without the word found

# this function permit to extract the year of the studied file
# the year is always writen at the end of the name's file
# the input name is in format str
def find_year(name):
    index_before_name=name.rfind('_') # returns the highest index where the character '_' was found
    # the last character '_' is just before the year in the string 'name'
    # determine if the string 'name' ends with '.nc'
    if name.endswith('.nc'):
        # 'name' ends with '.nc'
        name_end = 3 # the three last character of the string name will be removed to find the year of the studied file
    else:
        # 'name' does not end with '.nc'
        name_end = 0 # no character will be removed at the end of 'name' to find the year of the studied file
    year = name[index_before_name+1:len(name)-name_end] # the year is extracted from the name of the file studied
    # based on the index_before_name (highest index where the character '_' was found) and the suffix of 'name'
    return year # the year in string format is returned

# This function use the functions 'name_next_boundary' and 'find_year' to extract the information of the file studied
# the input name is in format str, the name of the file from which we want information
def data_information(name):
    #### use of the function 'name_next_boundary': each time it is used, 
    # returns an information, and the name of the studied file without this information
    (variable, shorten_name) = name_next_boundary(name)
    (time_aggregation, shorten_name) = name_next_boundary(shorten_name)
    (model, shorten_name) = name_next_boundary(shorten_name)
    (scenario, shorten_name) = name_next_boundary(shorten_name)
    #### use the function 'find_year' to extract the information 'year' from the string 'shorten_name'
    year = find_year(shorten_name)
    # the function returns all the information of the studied file
    return variable, time_aggregation, model, scenario, year

# %%
# this function aims to create the empty dataframe that will be filled

def create_empty_dataframe(name_project,scenarios,models,closest_value_lat,closest_value_lon,name_climate_var,start_year,stop_year):
    df = pd.DataFrame()
    for i in np.arange(0,len(name_project)):
        for scenario in scenarios:
            if scenario == 'historical':
                if (stop_year<2015) and (start_year<2015):
                    time = pd.date_range('01-01-'+str(start_year),'31-12-'+str(stop_year), freq='D').strftime('%d-%m-%Y').values
                    midx = pd.MultiIndex.from_product([(name_project[i],),(scenario,), models, (closest_value_lat[i],),(closest_value_lon[i],),time],names=['Name project','Experiment', 'Model', 'Latitude','Longitude','Date'])
                    cols = [name_climate_var]
                    Variable_dataframe = pd.DataFrame(data = [], 
                                                index = midx,
                                                columns = cols)
                    df = pd.concat([df,Variable_dataframe])
                if (stop_year>2015):
                    time = pd.date_range('01-01-'+str(start_year),'31-12-2014', freq='D').strftime('%d-%m-%Y').values
                    midx = pd.MultiIndex.from_product([(name_project[i],),(scenario,), models, (closest_value_lat[i],),(closest_value_lon[i],),time],names=['Name project','Experiment', 'Model', 'Latitude','Longitude','Date'])
                    cols = [name_climate_var]
                    Variable_dataframe = pd.DataFrame(data = [], 
                                                index = midx,
                                                columns = cols)
                    df = pd.concat([df,Variable_dataframe])                    
                    
            else:
                if (stop_year>2014) and (start_year>2014):
                    time = pd.date_range('01-01-'+str(start_year),'31-12-'+str(stop_year), freq='D').strftime('%d-%m-%Y').values
                    midx = pd.MultiIndex.from_product([(name_project[i],),(scenario,), models, (closest_value_lat[i],),(closest_value_lon[i],),time],names=['Name project','Experiment', 'Model', 'Latitude','Longitude','Date'])
                    cols = [name_climate_var]
                    Variable_dataframe = pd.DataFrame(data = [], 
                                                index = midx,
                                                columns = cols)
                    df = pd.concat([df,Variable_dataframe])
                if (start_year<2014):
                    time = pd.date_range('01-01-2015','31-12-'+str(stop_year), freq='D').strftime('%d-%m-%Y').values
                    midx = pd.MultiIndex.from_product([(name_project[i],),(scenario,), models, (closest_value_lat[i],),(closest_value_lon[i],),time],names=['Name project','Experiment', 'Model', 'Latitude','Longitude','Date'])
                    cols = [name_climate_var]
                    Variable_dataframe = pd.DataFrame(data = [], 
                                                index = midx,
                                                columns = cols)
                    df = pd.concat([df,Variable_dataframe])
                    
    return df

# %%
# this function is used in 'create_dataframe'. The function aims to return the path of the file of interest
# The function looks into a list of name which name in the list has every input 
# The inputs are:
#    out_path: a general file path where the files are registered, 
#    name_file_list: a list of files' names
#    variable: the name of the variable of interest
#    model: the model of interest (example: ACCESS-CM2)
#    scenario: the scenario of interest (example:ssp245)
#    year: the year of interest
#    ensemble: the ensemble of interest (example: r1i1p1f1_gn)
# the output is:
#    the path of the file corresponding to all the parameters indicated in input

def find_path_file(out_path,name_file_list,variable,temporal_resolution,model,scenario,year,ensemble):
    # look into the list of names if find a name with every parameter indicated in inputs
    name_found = [name for name in name_file_list if scenario in name and model in name and year in name and ensemble in name and temporal_resolution in name]
    if name_found == []:
        # no name with all the parameters indicated as inputs was found
        return name_found # return an empty element instead of a path, the function does not run the following lines
    # the name was found, so prepare the path of the file of interest
    print('The name of the file is ' + name_found[0])
    path = os.path.join(out_path,name_found[0])
    return path # return the path of the file of interest

# %%
# the register_data_in_dataframe function aims to test if data with the specific parameters exist in the folder of concern
# As inputs :
#      the list of urls of the files of interest. The name of the file will be extracted from them
#      temporal_resolution: the temporal resolution of the climate variable in question in string format
#      year_str: a vector containing the year of the period of interest in a string format
#      scenarios: a list of the scenorios of interest in string format
#      models: a list of the models of interest in string format
#      out_path: the out_path in a string format
#      name_variable: the name of the variable of interest (example: 'pr' for precipitation)
#      name_project: the list of names of the project of interest
#      index_closest_lat: array containing an index for each project, 
#                           corresponding to the index of the value in latitude vector which is the closest to 
#                           the project latitude
#      index_closest_lat: array containing an index for each project, 
#                           corresponding to the index of the value in longitude vector which is the closest to 
#                           the project longitude
#      closest_value_lat: array containing a value for each project, corresponding to the value in the 
#                           latitude vector which is the closest to the project's latitude
#      closest_value_lon: array containing a value for each project, corresponding to the value in the 
#                           longitude vector which is the closest to the project's longitude
#      df : empty dataframe to fill

# Outputs are:
#      df: the filled dataframe with the values of interest
#      path_file_not_found: the list of files that were not found with the parameters asked
#      ds_did_not_open: the list of files that could not be read

def register_data_in_dataframe(name_list,temporal_resolution,year_str,scenarios,models,out_path, name_variable, name_project,index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon,df):    
    path_file_not_found = [] # create empty list to register names of files that were not found with the corresponding parameters
    ds_did_not_open = [] # create empty list to register names of files that couldn't be opened
    for year in year_str:
        for SSP in scenarios:
            for model_simulation in models:
                # for each year, each scenarios and each models, test if there is a corresponding file existing
                # with function 'find_path_file'
                climate_variable_path = find_path_file(out_path,name_list,name_variable,temporal_resolution,model_simulation,SSP,year,'r1i1p1f1_gn')
                if climate_variable_path!= []:
                    # a name of file with the corresponding parameters were found
                    #try: # to register information from the dataset ds in the dataframe df
                    ds =  xr.open_dataset(climate_variable_path) # open the file corresponding to the parameters
                    print('Le file s''est ouvert')
                    time = ds.indexes['time'].strftime('%d-%m-%Y').values # register the time in the file
                    for i in np.arange(0,len(name_project)):
                        print('For the year '+year+' and project '+name_project[i]+', test with scenario '+SSP+', with model '+model_simulation)
                        # for each year, scenarios, models and each project, the values of the opened dataset ds
                        # are registered in the empty dataframe df, to a specific place corresponding to the parameters of the loop
                        df.loc[(name_project[i],SSP,model_simulation,closest_value_lat[i],closest_value_lon[i],time)] = ds.pr.isel(lat=index_closest_lat[i],lon=index_closest_lon[i]).values.reshape(len(time),1)*86400
                        # units kg.m^(-2).s^(-1)
                        # convert precipitation data from kg.m^(-2).s^(-1) to mm/day :  1 kg/m2/s = 86400 mm/day
                    ds.close() # the opened dataset is closed to spare memory
                    #except: # the dataset ds can not be read
                        # add information of the dataset that can't be read in the empty list ds_did_not_open
                        #ds_did_not_open.append(climate_variable_path)
                        #print(climate_variable_path + ' did not open with ds')
                        #ds.close() # the opened dataset is closed to spare memory
                        #continue # try with next model
                else:
                    # NO file with the corresponding parameters were found
                    # add information of the missing file in the empty list path_file_not_found
                    path_file_not_found.append(name_variable+temporal_resolution+'_'+model_simulation+'_'+SSP+'_'+year+'_'+'r1i1p1f1_gn')
    return df,path_file_not_found,ds_did_not_open

# the function df_to_csv aims to return the filled dataframe in a csv format
# Inputs are:
#       df: the dataframe that should be register in a csv file
#      path_for_csv: this is the path where the csv file should be registered, in a string format
#      title_file: this is the name of the csv file to be created in a string format
#                  CAREFUL --> title_file MUST have the extension of the file in the string (.csv for example)
# Output is:
#      in the case where the dataframe is not empty, the ouput is the full path to the created csv file
#      in the case where the dataframe is empty, the output is an empty list
def df_to_csv(df,path_for_csv,title_file):
    # test if dataframe is empty, if values exist for this period
    if not df.empty: 
        # if dataframe is not empty, value were registered, the first part is run : 
        # a path to register the csv file is created, .....
        if not os.path.isdir(path_for_csv):
            # the path to the file does not exist
            os.makedirs(path_for_csv) # to ensure creation of the folder
            # creation of the path for the csv file, in a string format
        full_name = os.path.join(path_for_csv,title_file)
        # ..... and the dataframe is registered in a csv file
        df.to_csv(full_name) # register dataframe in csv file
        print('Path for csv file is: ' + full_name)
        return full_name # return the full path that leads to the created csv file
    else: # if the dataframe is empty, no value were found, there is no value to register or to return
        print('The dataframe is empty')
        return []

# %% [markdown]
# # Projects information

# %%
import geopandas as gpd
import os
import os.path

data_folder=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets'
project_location_path=os.path.join(data_folder,'Mozambique_PPIS/EIB_locations_few.shp')
#study boundary (optional)
study_area_path=os.path.join(data_folder,'Mozambique_PPIS/mozambique.shp')


#projection CRS (default = 'EPSG:4326')
bCRS='EPSG:4326'

mCRS='EPSG:31983' #metric CRS for buffer in meters (find relevant metric CRS for location!)

#load shapefiles
projects = gpd.read_file(project_location_path).to_crs(bCRS)
project_id='Name' #name of column used as id

study_area = gpd.read_file(study_area_path).to_crs(bCRS)

# prepare name_project for use 
name_project = projects['Name'].str.replace(' ','_') # take off every blank space of project names
name_project = name_project.str.replace('(','') # take off every ( of project names
name_project = name_project.str.replace(')','') # take off every ) of project names
name_project = name_project.str.replace('-','') # take off every - of project names
name_project = name_project.str.replace('/','_') # take off every / of project names
name_project = name_project.str.replace(r'"\"','_') # take off every \ of project names

# register geographic information concerning projects
lon_projects = projects['geometry'].x
lat_projects = projects['geometry'].y
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_23364\3025026928.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# # Define Paths

# %%
out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6'

# %% [markdown]
# # Complete list of url with files to download

# %%
# register information from csv file
#all_urls = pd.read_csv(r'C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\outputs\NEX-GDDP-CMIP6\gddp-cmip6-thredds-fileserver.csv')
csv_path = os.path.join(out_path,'gddp-cmip6-thredds-fileserver.csv')
all_urls = pd.read_csv(csv_path)

# %%
### make all elements of the csv into a readable list

temp_list = all_urls[[' fileUrl']].T# transpose csv
temp_list=temp_list.values.tolist()
temp_list=temp_list[0]
url_list=[s.replace(' ', '') for s in temp_list]

# %%
## download only precipitation data
# select only precipitation files, between 2040 and 2080
url_list_climate_var = [url for url in url_list if variable_of_interest in url and int(url[len(url)-7:len(url)-3])>=start_year and int(url[len(url)-7:len(url)-3])<=stop_year and 'r1i1p1f1_gn' in url]

# %%
len(url_list_climate_var)
# Out:
# 6044

# %%
name_list_climate_var = produce_name_list(url_list_climate_var)

# %%
name_list_climate_var[0]
# Out:
# 'pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc'

# %% [markdown]
# # Produce csv files with data to use

# %%
(year, year_str, index_year) = produce_year(start_year,stop_year)
#time = pd.date_range('01-01-'+str(start_year),'31-12-'+str(stop_year), freq='D').strftime('%d-%m-%Y').values # use to create dataframe

# %%
# variables, time_aggregations,models,scenarios in the name_list_precipitation
(variables, time_aggregations,models,scenarios)=information_files_in_vectors(name_list_climate_var)

# %%
# remove model NESM3 because there is no data associate to this model
models.remove('NESM3')

# %%
scenarios
# Out:
# ['historical', 'ssp245', 'ssp585', 'ssp126', 'ssp370']

# %%
# this cell aims to extract the index in the lat_projects and lon_projects vectors, corresponding to the values of the
# closest latitude and longitude to the projects
index_closest_lat = []
while index_closest_lat == []: # once the information where extracted, no need to continue looking
    for name in name_list_climate_var: # for loop to test the following names if the precedent one did not work
        try: # test to use function '_lat_lon' with this path
            path = os.path.join(out_path,name)
            print(path)
            (index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon)=_lat_lon(path,lat_projects,lon_projects)
            print(index_closest_lat)
            # this function '_lat_lon' use xr.open_dataset(path). If there is a problem with this opening process
            # (because the path given has a problem for example), the function can continue to test with the next 
            # file to extract the information of interest (the index and value of the closest latitude and longitude)
            break
        except:
            continue # the informations where not extracted. Continue the for loop
# Out:
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc
# [175, 175, 180, 180, 169, 188, 187]

# %%
# create the empty dataframe, based on the information from the names' files
df_climate_var=create_empty_dataframe(name_project,scenarios,models,closest_value_lat,closest_value_lon,'Precipitation mm/day',start_year,stop_year)
# test with one project, one scenario, one model with the following line
#df_climate_var=create_empty_dataframe([name_project[0]],[scenarios[0]],[models[0]],[closest_value_lat[0]],[closest_value_lon[0]],'Precipitation mm/day',start_year,stop_year)

# %%
df_climate_var
# Out:
#                                                                           Precipitation mm/day
# Name project          Experiment Model      Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical ACCESS-CM2 -16.125  33.625    01-01-1950                  NaN
#                                                                02-01-1950                  NaN
#                                                                03-01-1950                  NaN
#                                                                04-01-1950                  NaN
#                                                                05-01-1950                  NaN
# ...                                                                                        ...
# PT__Dumping_Site      ssp370     TaiESM1    -13.125  40.375    27-12-2100                  NaN
#                                                                28-12-2100                  NaN
#                                                                29-12-2100                  NaN
#                                                                30-12-2100                  NaN
#                                                                31-12-2100                  NaN
#
# [14639730 rows x 1 columns]

# %%
#df_climate_var=register_data_in_dataframe(name_list_climate_var,time_aggregations[0],year_str,scenarios,models,out_path, variable_of_interest, name_project,lon_projects,lat_projects,index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon,df_climate_var)
start_t = timer()
(df_climate_var,path_file_not_found,ds_did_not_open)=register_data_in_dataframe(name_list_climate_var,time_aggregations[0],year_str,scenarios,models,out_path, variable_of_interest, name_project,index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon,df_climate_var)
# test with one project, one scenario, one model with the following line, takes 1h20
#(df_climate_var,path_file_not_found,ds_did_not_open)=register_data_in_dataframe(name_list_climate_var,time_aggregations[0],year_str,[scenarios[0]],[models[0]],out_path, variable_of_interest, [name_project[0]],[index_closest_lat[0]],[index_closest_lon[0]],[closest_value_lat[0]],[closest_value_lon[0]],df_climate_var)
end_t = timer()
print('It took '+str(round(end_t - start_t,2))+' seconds to register the data of interest in dataframe')
print('It took '+str(round((end_t - start_t)/3600,2))+' hours to register the data of interest in dataframe')
# Out:
# The name of the file is pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc
# Le file sest ouvert
# For the year 1950 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project Mugica_dam_road, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-CM2
# For the year 1950 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-CM2
# The name of the file is pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_CanESM5_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_IITM-ESM_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_MIROC6_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_TaiESM1_historical_r1i1p1f1_gn_1950.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_historical_r1i1p1f1_gn_1950.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-CM2
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-CM2
# The name of the file is pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-ESM1-5
# The name of the file is pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model BCC-CSM2-MR
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model BCC-CSM2-MR
# The name of the file is pr_day_CanESM5_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CanESM5
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model CanESM5
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model CanESM5
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CanESM5
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model CanESM5
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CanESM5
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model CanESM5
# The name of the file is pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model CMCC-CM2-SR5
# The name of the file is pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-ESM2
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model CMCC-ESM2
# The name of the file is pr_day_IITM-ESM_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model IITM-ESM
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model IITM-ESM
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model IITM-ESM
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model IITM-ESM
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model IITM-ESM
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model IITM-ESM
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model IITM-ESM
# The name of the file is pr_day_MIROC6_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MIROC6
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model MIROC6
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model MIROC6
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MIROC6
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model MIROC6
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MIROC6
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model MIROC6
# The name of the file is pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-HR
# The name of the file is pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-LR
# The name of the file is pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MRI-ESM2-0
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model MRI-ESM2-0
# The name of the file is pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-LM
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-LM
# The name of the file is pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-MM
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-MM
# The name of the file is pr_day_TaiESM1_historical_r1i1p1f1_gn_1951.nc
# Le file sest ouvert
# For the year 1951 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model TaiESM1
# For the year 1951 and project WTP_gate_cnr1, test with scenario historical, with model TaiESM1
# For the year 1951 and project Mugica_dam_road, test with scenario historical, with model TaiESM1
# For the year 1951 and project Chimoio_2ML_Reservoir, test with scenario historical, with model TaiESM1
# For the year 1951 and project PT_Nicoadala_F5, test with scenario historical, with model TaiESM1
# For the year 1951 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model TaiESM1
# For the year 1951 and project PT__Dumping_Site, test with scenario historical, with model TaiESM1
# The name of the file is pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-CM2
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-CM2
# The name of the file is pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-ESM1-5
# The name of the file is pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model BCC-CSM2-MR
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model BCC-CSM2-MR
# The name of the file is pr_day_CanESM5_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CanESM5
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model CanESM5
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model CanESM5
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CanESM5
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model CanESM5
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CanESM5
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model CanESM5
# The name of the file is pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model CMCC-CM2-SR5
# The name of the file is pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-ESM2
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model CMCC-ESM2
# The name of the file is pr_day_IITM-ESM_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model IITM-ESM
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model IITM-ESM
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model IITM-ESM
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model IITM-ESM
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model IITM-ESM
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model IITM-ESM
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model IITM-ESM
# The name of the file is pr_day_MIROC6_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MIROC6
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model MIROC6
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model MIROC6
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MIROC6
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model MIROC6
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MIROC6
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model MIROC6
# The name of the file is pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-HR
# The name of the file is pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-LR
# The name of the file is pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MRI-ESM2-0
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model MRI-ESM2-0
# The name of the file is pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-LM
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-LM
# The name of the file is pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-MM
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-MM
# The name of the file is pr_day_TaiESM1_historical_r1i1p1f1_gn_1952.nc
# Le file sest ouvert
# For the year 1952 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model TaiESM1
# For the year 1952 and project WTP_gate_cnr1, test with scenario historical, with model TaiESM1
# For the year 1952 and project Mugica_dam_road, test with scenario historical, with model TaiESM1
# For the year 1952 and project Chimoio_2ML_Reservoir, test with scenario historical, with model TaiESM1
# For the year 1952 and project PT_Nicoadala_F5, test with scenario historical, with model TaiESM1
# For the year 1952 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model TaiESM1
# For the year 1952 and project PT__Dumping_Site, test with scenario historical, with model TaiESM1
# The name of the file is pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-CM2
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-CM2
# The name of the file is pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-ESM1-5
# The name of the file is pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model BCC-CSM2-MR
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model BCC-CSM2-MR
# The name of the file is pr_day_CanESM5_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CanESM5
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model CanESM5
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model CanESM5
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CanESM5
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model CanESM5
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CanESM5
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model CanESM5
# The name of the file is pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model CMCC-CM2-SR5
# The name of the file is pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-ESM2
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model CMCC-ESM2
# The name of the file is pr_day_IITM-ESM_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model IITM-ESM
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model IITM-ESM
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model IITM-ESM
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model IITM-ESM
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model IITM-ESM
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model IITM-ESM
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model IITM-ESM
# The name of the file is pr_day_MIROC6_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MIROC6
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model MIROC6
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model MIROC6
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MIROC6
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model MIROC6
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MIROC6
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model MIROC6
# The name of the file is pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-HR
# The name of the file is pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-LR
# The name of the file is pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MRI-ESM2-0
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model MRI-ESM2-0
# The name of the file is pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-LM
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-LM
# The name of the file is pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-MM
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-MM
# The name of the file is pr_day_TaiESM1_historical_r1i1p1f1_gn_1953.nc
# Le file sest ouvert
# For the year 1953 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model TaiESM1
# For the year 1953 and project WTP_gate_cnr1, test with scenario historical, with model TaiESM1
# For the year 1953 and project Mugica_dam_road, test with scenario historical, with model TaiESM1
# For the year 1953 and project Chimoio_2ML_Reservoir, test with scenario historical, with model TaiESM1
# For the year 1953 and project PT_Nicoadala_F5, test with scenario historical, with model TaiESM1
# For the year 1953 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model TaiESM1
# For the year 1953 and project PT__Dumping_Site, test with scenario historical, with model TaiESM1
# The name of the file is pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-CM2
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-CM2
# The name of the file is pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model ACCESS-ESM1-5
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model ACCESS-ESM1-5
# The name of the file is pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model BCC-CSM2-MR
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model BCC-CSM2-MR
# The name of the file is pr_day_CanESM5_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CanESM5
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model CanESM5
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model CanESM5
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CanESM5
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model CanESM5
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CanESM5
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model CanESM5
# The name of the file is pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-CM2-SR5
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model CMCC-CM2-SR5
# The name of the file is pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model CMCC-ESM2
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model CMCC-ESM2
# The name of the file is pr_day_IITM-ESM_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model IITM-ESM
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model IITM-ESM
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model IITM-ESM
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model IITM-ESM
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model IITM-ESM
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model IITM-ESM
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model IITM-ESM
# The name of the file is pr_day_MIROC6_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MIROC6
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model MIROC6
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model MIROC6
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MIROC6
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model MIROC6
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MIROC6
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model MIROC6
# The name of the file is pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-HR
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-HR
# The name of the file is pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MPI-ESM1-2-LR
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model MPI-ESM1-2-LR
# The name of the file is pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model MRI-ESM2-0
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model MRI-ESM2-0
# The name of the file is pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project Chimoio_2ML_Reservoir, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project PT_Nicoadala_F5, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project PT1_Pemba__Breidge_Paquite, test with scenario historical, with model NorESM2-LM
# For the year 1954 and project PT__Dumping_Site, test with scenario historical, with model NorESM2-LM
# The name of the file is pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1954.nc
# Le file sest ouvert
# For the year 1954 and project PT_Revubue_2_Rev_2_01, test with scenario historical, with model NorESM2-MM
# For the year 1954 and project WTP_gate_cnr1, test with scenario historical, with model NorESM2-MM
# For the year 1954 and project Mugica_dam_road, test with scenario historical, with model NorESM2-MM
# ...
# The name of the file is pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2099.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2099.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CanESM5_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MIROC6_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# The name of the file is pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2100.nc
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2100.nc did not open with ds
# It took 38966.25 seconds to register the data of interest in dataframe
# It took 10.82 hours to register the data of interest in dataframe

# %%
df_climate_var
# Out:
#                                                                           Precipitation mm/day
# Name project          Experiment Model      Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical ACCESS-CM2 -16.125  33.625    01-01-1950              3.47067
#                                                                02-01-1950             3.403428
#                                                                03-01-1950             8.328737
#                                                                04-01-1950             3.916173
#                                                                05-01-1950             22.83637
# ...                                                                                        ...
# PT__Dumping_Site      ssp370     TaiESM1    -13.125  40.375    27-12-2100                  NaN
#                                                                28-12-2100                  NaN
#                                                                29-12-2100                  NaN
#                                                                30-12-2100                  NaN
#                                                                31-12-2100                  NaN
#
# [14639730 rows x 1 columns]

# %%
# Register information

# register dataframe in a csv format
title_file = 'All_projects_moz_'+variable_of_interest+'_'+str(start_year)+'-'+str(stop_year)+'.csv'
path_for_csv = os.path.join(out_path,'csv_file',variable_of_interest+'_'+time_aggregations[0]+'_'+str(start_year)+'-'+str(stop_year))
path_csv = df_to_csv(df_climate_var,path_for_csv,title_file)

# register path_file_not_found in a file format
if path_file_not_found != []:
    txt_file_path = os.path.join(path_for_csv,'Path_file_not_found')
    with open(txt_file_path, 'w') as text_file:
        for item in path_file_not_found:
            text_file.write(item)
    print('Not every files were found')
else:
    print('Every files were found')
        
# register ds_did_not_open in a file format
if ds_did_not_open != []:
    txt_file_path = os.path.join(path_for_csv,'ds_did_not_open')
    with open(txt_file_path, 'w') as text_file:
        for element in ds_did_not_open:
            text_file.write(element)
    print('Not every files were opened successfully')
else:
    print('Every files were opened')
# Out:
# Path for csv file is: \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\csv_file\pr__day_1950-2100\All_projects_moz_pr__1950-2100.csv
# Not every files were found
# Not every files were opened successfully

# %%
len(path_file_not_found)
# Out:
# 4849

# %%
len(ds_did_not_open)
# Out:
# 5317

# %%
len(name_list_climate_var)
# Out:
# 6044

# %%
name_list_path_file_not_found = produce_name_list(path_file_not_found)
(variables_path_file_not_found, time_aggregations_path_file_not_found,models_path_file_not_found,scenarios_path_file_not_found)=information_files_in_vectors(path_file_not_found)

# %%
name_list_path_file_not_found
# Out:
# ['pr__day_ACCESS-CM2_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1950_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1951_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1952_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1953_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1954_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1955_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1956_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1957_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1958_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1959_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1960_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1961_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1962_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1963_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1964_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1965_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp370_1966_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp245_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp585_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_IITM-ESM_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_MIROC6_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-HR_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_MPI-ESM1-2-LR_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_MRI-ESM2-0_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-LM_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_NorESM2-MM_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_TaiESM1_ssp126_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-CM2_ssp370_1967_r1i1p1f1_gn',
#  'pr__day_ACCESS-ESM1-5_ssp370_1967_r1i1p1f1_gn',
#  'pr__day_BCC-CSM2-MR_ssp370_1967_r1i1p1f1_gn',
#  'pr__day_CanESM5_ssp370_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-CM2-SR5_ssp370_1967_r1i1p1f1_gn',
#  'pr__day_CMCC-ESM2_ssp370_1967_r1i1p1f1_gn',
#  ...]

# %%
variables_path_file_not_found
# Out:
# ['pr']

# %%
time_aggregations_path_file_not_found
# Out:
# ['']

# %%
models_path_file_not_found
# Out:
# ['dayACCESS-CM2ssp2451950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451950r1i1p1f1g',
#  'dayCanESM5ssp2451950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451950r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451950r1i1p1f1g',
#  'dayIITM-ESMssp2451950r1i1p1f1g',
#  'dayMIROC6ssp2451950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451950r1i1p1f1g',
#  'dayNorESM2-LMssp2451950r1i1p1f1g',
#  'dayNorESM2-MMssp2451950r1i1p1f1g',
#  'dayTaiESM1ssp2451950r1i1p1f1g',
#  'dayACCESS-CM2ssp5851950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851950r1i1p1f1g',
#  'dayCanESM5ssp5851950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851950r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851950r1i1p1f1g',
#  'dayIITM-ESMssp5851950r1i1p1f1g',
#  'dayMIROC6ssp5851950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851950r1i1p1f1g',
#  'dayNorESM2-LMssp5851950r1i1p1f1g',
#  'dayNorESM2-MMssp5851950r1i1p1f1g',
#  'dayTaiESM1ssp5851950r1i1p1f1g',
#  'dayACCESS-CM2ssp1261950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261950r1i1p1f1g',
#  'dayCanESM5ssp1261950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261950r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261950r1i1p1f1g',
#  'dayIITM-ESMssp1261950r1i1p1f1g',
#  'dayMIROC6ssp1261950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261950r1i1p1f1g',
#  'dayNorESM2-LMssp1261950r1i1p1f1g',
#  'dayNorESM2-MMssp1261950r1i1p1f1g',
#  'dayTaiESM1ssp1261950r1i1p1f1g',
#  'dayACCESS-CM2ssp3701950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701950r1i1p1f1g',
#  'dayCanESM5ssp3701950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701950r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701950r1i1p1f1g',
#  'dayIITM-ESMssp3701950r1i1p1f1g',
#  'dayMIROC6ssp3701950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701950r1i1p1f1g',
#  'dayNorESM2-LMssp3701950r1i1p1f1g',
#  'dayNorESM2-MMssp3701950r1i1p1f1g',
#  'dayTaiESM1ssp3701950r1i1p1f1g',
#  'dayACCESS-CM2ssp2451951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451951r1i1p1f1g',
#  'dayCanESM5ssp2451951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451951r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451951r1i1p1f1g',
#  'dayIITM-ESMssp2451951r1i1p1f1g',
#  'dayMIROC6ssp2451951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451951r1i1p1f1g',
#  'dayNorESM2-LMssp2451951r1i1p1f1g',
#  'dayNorESM2-MMssp2451951r1i1p1f1g',
#  'dayTaiESM1ssp2451951r1i1p1f1g',
#  'dayACCESS-CM2ssp5851951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851951r1i1p1f1g',
#  'dayCanESM5ssp5851951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851951r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851951r1i1p1f1g',
#  'dayIITM-ESMssp5851951r1i1p1f1g',
#  'dayMIROC6ssp5851951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851951r1i1p1f1g',
#  'dayNorESM2-LMssp5851951r1i1p1f1g',
#  'dayNorESM2-MMssp5851951r1i1p1f1g',
#  'dayTaiESM1ssp5851951r1i1p1f1g',
#  'dayACCESS-CM2ssp1261951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261951r1i1p1f1g',
#  'dayCanESM5ssp1261951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261951r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261951r1i1p1f1g',
#  'dayIITM-ESMssp1261951r1i1p1f1g',
#  'dayMIROC6ssp1261951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261951r1i1p1f1g',
#  'dayNorESM2-LMssp1261951r1i1p1f1g',
#  'dayNorESM2-MMssp1261951r1i1p1f1g',
#  'dayTaiESM1ssp1261951r1i1p1f1g',
#  'dayACCESS-CM2ssp3701951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701951r1i1p1f1g',
#  'dayCanESM5ssp3701951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701951r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701951r1i1p1f1g',
#  'dayIITM-ESMssp3701951r1i1p1f1g',
#  'dayMIROC6ssp3701951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701951r1i1p1f1g',
#  'dayNorESM2-LMssp3701951r1i1p1f1g',
#  'dayNorESM2-MMssp3701951r1i1p1f1g',
#  'dayTaiESM1ssp3701951r1i1p1f1g',
#  'dayACCESS-CM2ssp2451952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451952r1i1p1f1g',
#  'dayCanESM5ssp2451952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451952r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451952r1i1p1f1g',
#  'dayIITM-ESMssp2451952r1i1p1f1g',
#  'dayMIROC6ssp2451952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451952r1i1p1f1g',
#  'dayNorESM2-LMssp2451952r1i1p1f1g',
#  'dayNorESM2-MMssp2451952r1i1p1f1g',
#  'dayTaiESM1ssp2451952r1i1p1f1g',
#  'dayACCESS-CM2ssp5851952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851952r1i1p1f1g',
#  'dayCanESM5ssp5851952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851952r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851952r1i1p1f1g',
#  'dayIITM-ESMssp5851952r1i1p1f1g',
#  'dayMIROC6ssp5851952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851952r1i1p1f1g',
#  'dayNorESM2-LMssp5851952r1i1p1f1g',
#  'dayNorESM2-MMssp5851952r1i1p1f1g',
#  'dayTaiESM1ssp5851952r1i1p1f1g',
#  'dayACCESS-CM2ssp1261952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261952r1i1p1f1g',
#  'dayCanESM5ssp1261952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261952r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261952r1i1p1f1g',
#  'dayIITM-ESMssp1261952r1i1p1f1g',
#  'dayMIROC6ssp1261952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261952r1i1p1f1g',
#  'dayNorESM2-LMssp1261952r1i1p1f1g',
#  'dayNorESM2-MMssp1261952r1i1p1f1g',
#  'dayTaiESM1ssp1261952r1i1p1f1g',
#  'dayACCESS-CM2ssp3701952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701952r1i1p1f1g',
#  'dayCanESM5ssp3701952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701952r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701952r1i1p1f1g',
#  'dayIITM-ESMssp3701952r1i1p1f1g',
#  'dayMIROC6ssp3701952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701952r1i1p1f1g',
#  'dayNorESM2-LMssp3701952r1i1p1f1g',
#  'dayNorESM2-MMssp3701952r1i1p1f1g',
#  'dayTaiESM1ssp3701952r1i1p1f1g',
#  'dayACCESS-CM2ssp2451953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451953r1i1p1f1g',
#  'dayCanESM5ssp2451953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451953r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451953r1i1p1f1g',
#  'dayIITM-ESMssp2451953r1i1p1f1g',
#  'dayMIROC6ssp2451953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451953r1i1p1f1g',
#  'dayNorESM2-LMssp2451953r1i1p1f1g',
#  'dayNorESM2-MMssp2451953r1i1p1f1g',
#  'dayTaiESM1ssp2451953r1i1p1f1g',
#  'dayACCESS-CM2ssp5851953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851953r1i1p1f1g',
#  'dayCanESM5ssp5851953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851953r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851953r1i1p1f1g',
#  'dayIITM-ESMssp5851953r1i1p1f1g',
#  'dayMIROC6ssp5851953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851953r1i1p1f1g',
#  'dayNorESM2-LMssp5851953r1i1p1f1g',
#  'dayNorESM2-MMssp5851953r1i1p1f1g',
#  'dayTaiESM1ssp5851953r1i1p1f1g',
#  'dayACCESS-CM2ssp1261953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261953r1i1p1f1g',
#  'dayCanESM5ssp1261953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261953r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261953r1i1p1f1g',
#  'dayIITM-ESMssp1261953r1i1p1f1g',
#  'dayMIROC6ssp1261953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261953r1i1p1f1g',
#  'dayNorESM2-LMssp1261953r1i1p1f1g',
#  'dayNorESM2-MMssp1261953r1i1p1f1g',
#  'dayTaiESM1ssp1261953r1i1p1f1g',
#  'dayACCESS-CM2ssp3701953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701953r1i1p1f1g',
#  'dayCanESM5ssp3701953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701953r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701953r1i1p1f1g',
#  'dayIITM-ESMssp3701953r1i1p1f1g',
#  'dayMIROC6ssp3701953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701953r1i1p1f1g',
#  'dayNorESM2-LMssp3701953r1i1p1f1g',
#  'dayNorESM2-MMssp3701953r1i1p1f1g',
#  'dayTaiESM1ssp3701953r1i1p1f1g',
#  'dayACCESS-CM2ssp2451954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451954r1i1p1f1g',
#  'dayCanESM5ssp2451954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451954r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451954r1i1p1f1g',
#  'dayIITM-ESMssp2451954r1i1p1f1g',
#  'dayMIROC6ssp2451954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451954r1i1p1f1g',
#  'dayNorESM2-LMssp2451954r1i1p1f1g',
#  'dayNorESM2-MMssp2451954r1i1p1f1g',
#  'dayTaiESM1ssp2451954r1i1p1f1g',
#  'dayACCESS-CM2ssp5851954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851954r1i1p1f1g',
#  'dayCanESM5ssp5851954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851954r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851954r1i1p1f1g',
#  'dayIITM-ESMssp5851954r1i1p1f1g',
#  'dayMIROC6ssp5851954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851954r1i1p1f1g',
#  'dayNorESM2-LMssp5851954r1i1p1f1g',
#  'dayNorESM2-MMssp5851954r1i1p1f1g',
#  'dayTaiESM1ssp5851954r1i1p1f1g',
#  'dayACCESS-CM2ssp1261954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261954r1i1p1f1g',
#  'dayCanESM5ssp1261954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261954r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261954r1i1p1f1g',
#  'dayIITM-ESMssp1261954r1i1p1f1g',
#  'dayMIROC6ssp1261954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261954r1i1p1f1g',
#  'dayNorESM2-LMssp1261954r1i1p1f1g',
#  'dayNorESM2-MMssp1261954r1i1p1f1g',
#  'dayTaiESM1ssp1261954r1i1p1f1g',
#  'dayACCESS-CM2ssp3701954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701954r1i1p1f1g',
#  'dayCanESM5ssp3701954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701954r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701954r1i1p1f1g',
#  'dayIITM-ESMssp3701954r1i1p1f1g',
#  'dayMIROC6ssp3701954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701954r1i1p1f1g',
#  'dayNorESM2-LMssp3701954r1i1p1f1g',
#  'dayNorESM2-MMssp3701954r1i1p1f1g',
#  'dayTaiESM1ssp3701954r1i1p1f1g',
#  'dayACCESS-CM2ssp2451955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451955r1i1p1f1g',
#  'dayCanESM5ssp2451955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451955r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451955r1i1p1f1g',
#  'dayIITM-ESMssp2451955r1i1p1f1g',
#  'dayMIROC6ssp2451955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451955r1i1p1f1g',
#  'dayNorESM2-LMssp2451955r1i1p1f1g',
#  'dayNorESM2-MMssp2451955r1i1p1f1g',
#  'dayTaiESM1ssp2451955r1i1p1f1g',
#  'dayACCESS-CM2ssp5851955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851955r1i1p1f1g',
#  'dayCanESM5ssp5851955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851955r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851955r1i1p1f1g',
#  'dayIITM-ESMssp5851955r1i1p1f1g',
#  'dayMIROC6ssp5851955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851955r1i1p1f1g',
#  'dayNorESM2-LMssp5851955r1i1p1f1g',
#  'dayNorESM2-MMssp5851955r1i1p1f1g',
#  'dayTaiESM1ssp5851955r1i1p1f1g',
#  'dayACCESS-CM2ssp1261955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261955r1i1p1f1g',
#  'dayCanESM5ssp1261955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261955r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261955r1i1p1f1g',
#  'dayIITM-ESMssp1261955r1i1p1f1g',
#  'dayMIROC6ssp1261955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261955r1i1p1f1g',
#  'dayNorESM2-LMssp1261955r1i1p1f1g',
#  'dayNorESM2-MMssp1261955r1i1p1f1g',
#  'dayTaiESM1ssp1261955r1i1p1f1g',
#  'dayACCESS-CM2ssp3701955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701955r1i1p1f1g',
#  'dayCanESM5ssp3701955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701955r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701955r1i1p1f1g',
#  'dayIITM-ESMssp3701955r1i1p1f1g',
#  'dayMIROC6ssp3701955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701955r1i1p1f1g',
#  'dayNorESM2-LMssp3701955r1i1p1f1g',
#  'dayNorESM2-MMssp3701955r1i1p1f1g',
#  'dayTaiESM1ssp3701955r1i1p1f1g',
#  'dayACCESS-CM2ssp2451956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451956r1i1p1f1g',
#  'dayCanESM5ssp2451956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451956r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451956r1i1p1f1g',
#  'dayIITM-ESMssp2451956r1i1p1f1g',
#  'dayMIROC6ssp2451956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451956r1i1p1f1g',
#  'dayNorESM2-LMssp2451956r1i1p1f1g',
#  'dayNorESM2-MMssp2451956r1i1p1f1g',
#  'dayTaiESM1ssp2451956r1i1p1f1g',
#  'dayACCESS-CM2ssp5851956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851956r1i1p1f1g',
#  'dayCanESM5ssp5851956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851956r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851956r1i1p1f1g',
#  'dayIITM-ESMssp5851956r1i1p1f1g',
#  'dayMIROC6ssp5851956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851956r1i1p1f1g',
#  'dayNorESM2-LMssp5851956r1i1p1f1g',
#  'dayNorESM2-MMssp5851956r1i1p1f1g',
#  'dayTaiESM1ssp5851956r1i1p1f1g',
#  'dayACCESS-CM2ssp1261956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261956r1i1p1f1g',
#  'dayCanESM5ssp1261956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261956r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261956r1i1p1f1g',
#  'dayIITM-ESMssp1261956r1i1p1f1g',
#  'dayMIROC6ssp1261956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261956r1i1p1f1g',
#  'dayNorESM2-LMssp1261956r1i1p1f1g',
#  'dayNorESM2-MMssp1261956r1i1p1f1g',
#  'dayTaiESM1ssp1261956r1i1p1f1g',
#  'dayACCESS-CM2ssp3701956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701956r1i1p1f1g',
#  'dayCanESM5ssp3701956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701956r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701956r1i1p1f1g',
#  'dayIITM-ESMssp3701956r1i1p1f1g',
#  'dayMIROC6ssp3701956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701956r1i1p1f1g',
#  'dayNorESM2-LMssp3701956r1i1p1f1g',
#  'dayNorESM2-MMssp3701956r1i1p1f1g',
#  'dayTaiESM1ssp3701956r1i1p1f1g',
#  'dayACCESS-CM2ssp2451957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451957r1i1p1f1g',
#  'dayCanESM5ssp2451957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451957r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451957r1i1p1f1g',
#  'dayIITM-ESMssp2451957r1i1p1f1g',
#  'dayMIROC6ssp2451957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451957r1i1p1f1g',
#  'dayNorESM2-LMssp2451957r1i1p1f1g',
#  'dayNorESM2-MMssp2451957r1i1p1f1g',
#  'dayTaiESM1ssp2451957r1i1p1f1g',
#  'dayACCESS-CM2ssp5851957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851957r1i1p1f1g',
#  'dayCanESM5ssp5851957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851957r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851957r1i1p1f1g',
#  'dayIITM-ESMssp5851957r1i1p1f1g',
#  'dayMIROC6ssp5851957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851957r1i1p1f1g',
#  'dayNorESM2-LMssp5851957r1i1p1f1g',
#  'dayNorESM2-MMssp5851957r1i1p1f1g',
#  'dayTaiESM1ssp5851957r1i1p1f1g',
#  'dayACCESS-CM2ssp1261957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261957r1i1p1f1g',
#  'dayCanESM5ssp1261957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261957r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261957r1i1p1f1g',
#  'dayIITM-ESMssp1261957r1i1p1f1g',
#  'dayMIROC6ssp1261957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261957r1i1p1f1g',
#  'dayNorESM2-LMssp1261957r1i1p1f1g',
#  'dayNorESM2-MMssp1261957r1i1p1f1g',
#  'dayTaiESM1ssp1261957r1i1p1f1g',
#  'dayACCESS-CM2ssp3701957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701957r1i1p1f1g',
#  'dayCanESM5ssp3701957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701957r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701957r1i1p1f1g',
#  'dayIITM-ESMssp3701957r1i1p1f1g',
#  'dayMIROC6ssp3701957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701957r1i1p1f1g',
#  'dayNorESM2-LMssp3701957r1i1p1f1g',
#  'dayNorESM2-MMssp3701957r1i1p1f1g',
#  'dayTaiESM1ssp3701957r1i1p1f1g',
#  'dayACCESS-CM2ssp2451958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451958r1i1p1f1g',
#  'dayCanESM5ssp2451958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451958r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451958r1i1p1f1g',
#  'dayIITM-ESMssp2451958r1i1p1f1g',
#  'dayMIROC6ssp2451958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451958r1i1p1f1g',
#  'dayNorESM2-LMssp2451958r1i1p1f1g',
#  'dayNorESM2-MMssp2451958r1i1p1f1g',
#  'dayTaiESM1ssp2451958r1i1p1f1g',
#  'dayACCESS-CM2ssp5851958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851958r1i1p1f1g',
#  'dayCanESM5ssp5851958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851958r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851958r1i1p1f1g',
#  'dayIITM-ESMssp5851958r1i1p1f1g',
#  'dayMIROC6ssp5851958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851958r1i1p1f1g',
#  'dayNorESM2-LMssp5851958r1i1p1f1g',
#  'dayNorESM2-MMssp5851958r1i1p1f1g',
#  'dayTaiESM1ssp5851958r1i1p1f1g',
#  'dayACCESS-CM2ssp1261958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261958r1i1p1f1g',
#  'dayCanESM5ssp1261958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261958r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261958r1i1p1f1g',
#  'dayIITM-ESMssp1261958r1i1p1f1g',
#  'dayMIROC6ssp1261958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261958r1i1p1f1g',
#  'dayNorESM2-LMssp1261958r1i1p1f1g',
#  'dayNorESM2-MMssp1261958r1i1p1f1g',
#  'dayTaiESM1ssp1261958r1i1p1f1g',
#  'dayACCESS-CM2ssp3701958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701958r1i1p1f1g',
#  'dayCanESM5ssp3701958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701958r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701958r1i1p1f1g',
#  'dayIITM-ESMssp3701958r1i1p1f1g',
#  'dayMIROC6ssp3701958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701958r1i1p1f1g',
#  'dayNorESM2-LMssp3701958r1i1p1f1g',
#  'dayNorESM2-MMssp3701958r1i1p1f1g',
#  'dayTaiESM1ssp3701958r1i1p1f1g',
#  'dayACCESS-CM2ssp2451959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451959r1i1p1f1g',
#  'dayCanESM5ssp2451959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451959r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451959r1i1p1f1g',
#  'dayIITM-ESMssp2451959r1i1p1f1g',
#  'dayMIROC6ssp2451959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451959r1i1p1f1g',
#  'dayNorESM2-LMssp2451959r1i1p1f1g',
#  'dayNorESM2-MMssp2451959r1i1p1f1g',
#  'dayTaiESM1ssp2451959r1i1p1f1g',
#  'dayACCESS-CM2ssp5851959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851959r1i1p1f1g',
#  'dayCanESM5ssp5851959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851959r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851959r1i1p1f1g',
#  'dayIITM-ESMssp5851959r1i1p1f1g',
#  'dayMIROC6ssp5851959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851959r1i1p1f1g',
#  'dayNorESM2-LMssp5851959r1i1p1f1g',
#  'dayNorESM2-MMssp5851959r1i1p1f1g',
#  'dayTaiESM1ssp5851959r1i1p1f1g',
#  'dayACCESS-CM2ssp1261959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261959r1i1p1f1g',
#  'dayCanESM5ssp1261959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261959r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261959r1i1p1f1g',
#  'dayIITM-ESMssp1261959r1i1p1f1g',
#  'dayMIROC6ssp1261959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261959r1i1p1f1g',
#  'dayNorESM2-LMssp1261959r1i1p1f1g',
#  'dayNorESM2-MMssp1261959r1i1p1f1g',
#  'dayTaiESM1ssp1261959r1i1p1f1g',
#  'dayACCESS-CM2ssp3701959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701959r1i1p1f1g',
#  'dayCanESM5ssp3701959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701959r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701959r1i1p1f1g',
#  'dayIITM-ESMssp3701959r1i1p1f1g',
#  'dayMIROC6ssp3701959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701959r1i1p1f1g',
#  'dayNorESM2-LMssp3701959r1i1p1f1g',
#  'dayNorESM2-MMssp3701959r1i1p1f1g',
#  'dayTaiESM1ssp3701959r1i1p1f1g',
#  'dayACCESS-CM2ssp2451960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451960r1i1p1f1g',
#  'dayCanESM5ssp2451960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451960r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451960r1i1p1f1g',
#  'dayIITM-ESMssp2451960r1i1p1f1g',
#  'dayMIROC6ssp2451960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451960r1i1p1f1g',
#  'dayNorESM2-LMssp2451960r1i1p1f1g',
#  'dayNorESM2-MMssp2451960r1i1p1f1g',
#  'dayTaiESM1ssp2451960r1i1p1f1g',
#  'dayACCESS-CM2ssp5851960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851960r1i1p1f1g',
#  'dayCanESM5ssp5851960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851960r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851960r1i1p1f1g',
#  'dayIITM-ESMssp5851960r1i1p1f1g',
#  'dayMIROC6ssp5851960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851960r1i1p1f1g',
#  'dayNorESM2-LMssp5851960r1i1p1f1g',
#  'dayNorESM2-MMssp5851960r1i1p1f1g',
#  'dayTaiESM1ssp5851960r1i1p1f1g',
#  'dayACCESS-CM2ssp1261960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261960r1i1p1f1g',
#  'dayCanESM5ssp1261960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261960r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261960r1i1p1f1g',
#  'dayIITM-ESMssp1261960r1i1p1f1g',
#  'dayMIROC6ssp1261960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261960r1i1p1f1g',
#  'dayNorESM2-LMssp1261960r1i1p1f1g',
#  'dayNorESM2-MMssp1261960r1i1p1f1g',
#  'dayTaiESM1ssp1261960r1i1p1f1g',
#  'dayACCESS-CM2ssp3701960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701960r1i1p1f1g',
#  'dayCanESM5ssp3701960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701960r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701960r1i1p1f1g',
#  'dayIITM-ESMssp3701960r1i1p1f1g',
#  'dayMIROC6ssp3701960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701960r1i1p1f1g',
#  'dayNorESM2-LMssp3701960r1i1p1f1g',
#  'dayNorESM2-MMssp3701960r1i1p1f1g',
#  'dayTaiESM1ssp3701960r1i1p1f1g',
#  'dayACCESS-CM2ssp2451961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451961r1i1p1f1g',
#  'dayCanESM5ssp2451961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451961r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451961r1i1p1f1g',
#  'dayIITM-ESMssp2451961r1i1p1f1g',
#  'dayMIROC6ssp2451961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451961r1i1p1f1g',
#  'dayNorESM2-LMssp2451961r1i1p1f1g',
#  'dayNorESM2-MMssp2451961r1i1p1f1g',
#  'dayTaiESM1ssp2451961r1i1p1f1g',
#  'dayACCESS-CM2ssp5851961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851961r1i1p1f1g',
#  'dayCanESM5ssp5851961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851961r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851961r1i1p1f1g',
#  'dayIITM-ESMssp5851961r1i1p1f1g',
#  'dayMIROC6ssp5851961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851961r1i1p1f1g',
#  'dayNorESM2-LMssp5851961r1i1p1f1g',
#  'dayNorESM2-MMssp5851961r1i1p1f1g',
#  'dayTaiESM1ssp5851961r1i1p1f1g',
#  'dayACCESS-CM2ssp1261961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261961r1i1p1f1g',
#  'dayCanESM5ssp1261961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261961r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261961r1i1p1f1g',
#  'dayIITM-ESMssp1261961r1i1p1f1g',
#  'dayMIROC6ssp1261961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261961r1i1p1f1g',
#  'dayNorESM2-LMssp1261961r1i1p1f1g',
#  'dayNorESM2-MMssp1261961r1i1p1f1g',
#  'dayTaiESM1ssp1261961r1i1p1f1g',
#  'dayACCESS-CM2ssp3701961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701961r1i1p1f1g',
#  'dayCanESM5ssp3701961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701961r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701961r1i1p1f1g',
#  'dayIITM-ESMssp3701961r1i1p1f1g',
#  'dayMIROC6ssp3701961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701961r1i1p1f1g',
#  'dayNorESM2-LMssp3701961r1i1p1f1g',
#  'dayNorESM2-MMssp3701961r1i1p1f1g',
#  'dayTaiESM1ssp3701961r1i1p1f1g',
#  'dayACCESS-CM2ssp2451962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451962r1i1p1f1g',
#  'dayCanESM5ssp2451962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451962r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451962r1i1p1f1g',
#  'dayIITM-ESMssp2451962r1i1p1f1g',
#  'dayMIROC6ssp2451962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451962r1i1p1f1g',
#  'dayNorESM2-LMssp2451962r1i1p1f1g',
#  'dayNorESM2-MMssp2451962r1i1p1f1g',
#  'dayTaiESM1ssp2451962r1i1p1f1g',
#  'dayACCESS-CM2ssp5851962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851962r1i1p1f1g',
#  'dayCanESM5ssp5851962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851962r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851962r1i1p1f1g',
#  'dayIITM-ESMssp5851962r1i1p1f1g',
#  'dayMIROC6ssp5851962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851962r1i1p1f1g',
#  'dayNorESM2-LMssp5851962r1i1p1f1g',
#  'dayNorESM2-MMssp5851962r1i1p1f1g',
#  'dayTaiESM1ssp5851962r1i1p1f1g',
#  'dayACCESS-CM2ssp1261962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261962r1i1p1f1g',
#  'dayCanESM5ssp1261962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261962r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261962r1i1p1f1g',
#  'dayIITM-ESMssp1261962r1i1p1f1g',
#  'dayMIROC6ssp1261962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261962r1i1p1f1g',
#  'dayNorESM2-LMssp1261962r1i1p1f1g',
#  'dayNorESM2-MMssp1261962r1i1p1f1g',
#  'dayTaiESM1ssp1261962r1i1p1f1g',
#  'dayACCESS-CM2ssp3701962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701962r1i1p1f1g',
#  'dayCanESM5ssp3701962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701962r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701962r1i1p1f1g',
#  'dayIITM-ESMssp3701962r1i1p1f1g',
#  'dayMIROC6ssp3701962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701962r1i1p1f1g',
#  'dayNorESM2-LMssp3701962r1i1p1f1g',
#  'dayNorESM2-MMssp3701962r1i1p1f1g',
#  'dayTaiESM1ssp3701962r1i1p1f1g',
#  'dayACCESS-CM2ssp2451963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451963r1i1p1f1g',
#  'dayCanESM5ssp2451963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451963r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451963r1i1p1f1g',
#  'dayIITM-ESMssp2451963r1i1p1f1g',
#  'dayMIROC6ssp2451963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451963r1i1p1f1g',
#  'dayNorESM2-LMssp2451963r1i1p1f1g',
#  'dayNorESM2-MMssp2451963r1i1p1f1g',
#  'dayTaiESM1ssp2451963r1i1p1f1g',
#  'dayACCESS-CM2ssp5851963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851963r1i1p1f1g',
#  'dayCanESM5ssp5851963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851963r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851963r1i1p1f1g',
#  'dayIITM-ESMssp5851963r1i1p1f1g',
#  'dayMIROC6ssp5851963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851963r1i1p1f1g',
#  'dayNorESM2-LMssp5851963r1i1p1f1g',
#  'dayNorESM2-MMssp5851963r1i1p1f1g',
#  'dayTaiESM1ssp5851963r1i1p1f1g',
#  'dayACCESS-CM2ssp1261963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261963r1i1p1f1g',
#  'dayCanESM5ssp1261963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261963r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261963r1i1p1f1g',
#  'dayIITM-ESMssp1261963r1i1p1f1g',
#  'dayMIROC6ssp1261963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261963r1i1p1f1g',
#  'dayNorESM2-LMssp1261963r1i1p1f1g',
#  'dayNorESM2-MMssp1261963r1i1p1f1g',
#  'dayTaiESM1ssp1261963r1i1p1f1g',
#  'dayACCESS-CM2ssp3701963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701963r1i1p1f1g',
#  'dayCanESM5ssp3701963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701963r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701963r1i1p1f1g',
#  'dayIITM-ESMssp3701963r1i1p1f1g',
#  'dayMIROC6ssp3701963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701963r1i1p1f1g',
#  'dayNorESM2-LMssp3701963r1i1p1f1g',
#  'dayNorESM2-MMssp3701963r1i1p1f1g',
#  'dayTaiESM1ssp3701963r1i1p1f1g',
#  'dayACCESS-CM2ssp2451964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451964r1i1p1f1g',
#  'dayCanESM5ssp2451964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451964r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451964r1i1p1f1g',
#  'dayIITM-ESMssp2451964r1i1p1f1g',
#  'dayMIROC6ssp2451964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451964r1i1p1f1g',
#  'dayNorESM2-LMssp2451964r1i1p1f1g',
#  'dayNorESM2-MMssp2451964r1i1p1f1g',
#  'dayTaiESM1ssp2451964r1i1p1f1g',
#  'dayACCESS-CM2ssp5851964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851964r1i1p1f1g',
#  'dayCanESM5ssp5851964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851964r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851964r1i1p1f1g',
#  'dayIITM-ESMssp5851964r1i1p1f1g',
#  'dayMIROC6ssp5851964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851964r1i1p1f1g',
#  'dayNorESM2-LMssp5851964r1i1p1f1g',
#  'dayNorESM2-MMssp5851964r1i1p1f1g',
#  'dayTaiESM1ssp5851964r1i1p1f1g',
#  'dayACCESS-CM2ssp1261964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261964r1i1p1f1g',
#  'dayCanESM5ssp1261964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261964r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261964r1i1p1f1g',
#  'dayIITM-ESMssp1261964r1i1p1f1g',
#  'dayMIROC6ssp1261964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261964r1i1p1f1g',
#  'dayNorESM2-LMssp1261964r1i1p1f1g',
#  'dayNorESM2-MMssp1261964r1i1p1f1g',
#  'dayTaiESM1ssp1261964r1i1p1f1g',
#  'dayACCESS-CM2ssp3701964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701964r1i1p1f1g',
#  'dayCanESM5ssp3701964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701964r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701964r1i1p1f1g',
#  'dayIITM-ESMssp3701964r1i1p1f1g',
#  'dayMIROC6ssp3701964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701964r1i1p1f1g',
#  'dayNorESM2-LMssp3701964r1i1p1f1g',
#  'dayNorESM2-MMssp3701964r1i1p1f1g',
#  'dayTaiESM1ssp3701964r1i1p1f1g',
#  'dayACCESS-CM2ssp2451965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451965r1i1p1f1g',
#  'dayCanESM5ssp2451965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451965r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451965r1i1p1f1g',
#  'dayIITM-ESMssp2451965r1i1p1f1g',
#  'dayMIROC6ssp2451965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451965r1i1p1f1g',
#  'dayNorESM2-LMssp2451965r1i1p1f1g',
#  'dayNorESM2-MMssp2451965r1i1p1f1g',
#  'dayTaiESM1ssp2451965r1i1p1f1g',
#  'dayACCESS-CM2ssp5851965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851965r1i1p1f1g',
#  'dayCanESM5ssp5851965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851965r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851965r1i1p1f1g',
#  'dayIITM-ESMssp5851965r1i1p1f1g',
#  'dayMIROC6ssp5851965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851965r1i1p1f1g',
#  'dayNorESM2-LMssp5851965r1i1p1f1g',
#  'dayNorESM2-MMssp5851965r1i1p1f1g',
#  'dayTaiESM1ssp5851965r1i1p1f1g',
#  'dayACCESS-CM2ssp1261965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261965r1i1p1f1g',
#  'dayCanESM5ssp1261965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261965r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261965r1i1p1f1g',
#  'dayIITM-ESMssp1261965r1i1p1f1g',
#  'dayMIROC6ssp1261965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261965r1i1p1f1g',
#  'dayNorESM2-LMssp1261965r1i1p1f1g',
#  'dayNorESM2-MMssp1261965r1i1p1f1g',
#  'dayTaiESM1ssp1261965r1i1p1f1g',
#  'dayACCESS-CM2ssp3701965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701965r1i1p1f1g',
#  'dayCanESM5ssp3701965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701965r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701965r1i1p1f1g',
#  'dayIITM-ESMssp3701965r1i1p1f1g',
#  'dayMIROC6ssp3701965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701965r1i1p1f1g',
#  'dayNorESM2-LMssp3701965r1i1p1f1g',
#  'dayNorESM2-MMssp3701965r1i1p1f1g',
#  'dayTaiESM1ssp3701965r1i1p1f1g',
#  'dayACCESS-CM2ssp2451966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451966r1i1p1f1g',
#  'dayCanESM5ssp2451966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451966r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451966r1i1p1f1g',
#  'dayIITM-ESMssp2451966r1i1p1f1g',
#  'dayMIROC6ssp2451966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451966r1i1p1f1g',
#  'dayNorESM2-LMssp2451966r1i1p1f1g',
#  'dayNorESM2-MMssp2451966r1i1p1f1g',
#  'dayTaiESM1ssp2451966r1i1p1f1g',
#  'dayACCESS-CM2ssp5851966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851966r1i1p1f1g',
#  'dayCanESM5ssp5851966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851966r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851966r1i1p1f1g',
#  'dayIITM-ESMssp5851966r1i1p1f1g',
#  'dayMIROC6ssp5851966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851966r1i1p1f1g',
#  'dayNorESM2-LMssp5851966r1i1p1f1g',
#  'dayNorESM2-MMssp5851966r1i1p1f1g',
#  'dayTaiESM1ssp5851966r1i1p1f1g',
#  'dayACCESS-CM2ssp1261966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261966r1i1p1f1g',
#  'dayCanESM5ssp1261966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261966r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261966r1i1p1f1g',
#  'dayIITM-ESMssp1261966r1i1p1f1g',
#  'dayMIROC6ssp1261966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261966r1i1p1f1g',
#  'dayNorESM2-LMssp1261966r1i1p1f1g',
#  'dayNorESM2-MMssp1261966r1i1p1f1g',
#  'dayTaiESM1ssp1261966r1i1p1f1g',
#  'dayACCESS-CM2ssp3701966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701966r1i1p1f1g',
#  'dayCanESM5ssp3701966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701966r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701966r1i1p1f1g',
#  'dayIITM-ESMssp3701966r1i1p1f1g',
#  'dayMIROC6ssp3701966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701966r1i1p1f1g',
#  'dayNorESM2-LMssp3701966r1i1p1f1g',
#  'dayNorESM2-MMssp3701966r1i1p1f1g',
#  'dayTaiESM1ssp3701966r1i1p1f1g',
#  'dayACCESS-CM2ssp2451967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451967r1i1p1f1g',
#  'dayCanESM5ssp2451967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451967r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451967r1i1p1f1g',
#  'dayIITM-ESMssp2451967r1i1p1f1g',
#  'dayMIROC6ssp2451967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451967r1i1p1f1g',
#  'dayNorESM2-LMssp2451967r1i1p1f1g',
#  'dayNorESM2-MMssp2451967r1i1p1f1g',
#  'dayTaiESM1ssp2451967r1i1p1f1g',
#  'dayACCESS-CM2ssp5851967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851967r1i1p1f1g',
#  'dayCanESM5ssp5851967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851967r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851967r1i1p1f1g',
#  'dayIITM-ESMssp5851967r1i1p1f1g',
#  'dayMIROC6ssp5851967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851967r1i1p1f1g',
#  'dayNorESM2-LMssp5851967r1i1p1f1g',
#  'dayNorESM2-MMssp5851967r1i1p1f1g',
#  'dayTaiESM1ssp5851967r1i1p1f1g',
#  'dayACCESS-CM2ssp1261967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261967r1i1p1f1g',
#  'dayCanESM5ssp1261967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261967r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261967r1i1p1f1g',
#  'dayIITM-ESMssp1261967r1i1p1f1g',
#  'dayMIROC6ssp1261967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261967r1i1p1f1g',
#  'dayNorESM2-LMssp1261967r1i1p1f1g',
#  'dayNorESM2-MMssp1261967r1i1p1f1g',
#  'dayTaiESM1ssp1261967r1i1p1f1g',
#  'dayACCESS-CM2ssp3701967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701967r1i1p1f1g',
#  'dayCanESM5ssp3701967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701967r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701967r1i1p1f1g',
#  ...]

# %%
scenarios_path_file_not_found
# Out:
# ['dayACCESS-CM2ssp2451950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451950r1i1p1f1g',
#  'dayCanESM5ssp2451950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451950r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451950r1i1p1f1g',
#  'dayIITM-ESMssp2451950r1i1p1f1g',
#  'dayMIROC6ssp2451950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451950r1i1p1f1g',
#  'dayNorESM2-LMssp2451950r1i1p1f1g',
#  'dayNorESM2-MMssp2451950r1i1p1f1g',
#  'dayTaiESM1ssp2451950r1i1p1f1g',
#  'dayACCESS-CM2ssp5851950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851950r1i1p1f1g',
#  'dayCanESM5ssp5851950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851950r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851950r1i1p1f1g',
#  'dayIITM-ESMssp5851950r1i1p1f1g',
#  'dayMIROC6ssp5851950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851950r1i1p1f1g',
#  'dayNorESM2-LMssp5851950r1i1p1f1g',
#  'dayNorESM2-MMssp5851950r1i1p1f1g',
#  'dayTaiESM1ssp5851950r1i1p1f1g',
#  'dayACCESS-CM2ssp1261950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261950r1i1p1f1g',
#  'dayCanESM5ssp1261950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261950r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261950r1i1p1f1g',
#  'dayIITM-ESMssp1261950r1i1p1f1g',
#  'dayMIROC6ssp1261950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261950r1i1p1f1g',
#  'dayNorESM2-LMssp1261950r1i1p1f1g',
#  'dayNorESM2-MMssp1261950r1i1p1f1g',
#  'dayTaiESM1ssp1261950r1i1p1f1g',
#  'dayACCESS-CM2ssp3701950r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701950r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701950r1i1p1f1g',
#  'dayCanESM5ssp3701950r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701950r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701950r1i1p1f1g',
#  'dayIITM-ESMssp3701950r1i1p1f1g',
#  'dayMIROC6ssp3701950r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701950r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701950r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701950r1i1p1f1g',
#  'dayNorESM2-LMssp3701950r1i1p1f1g',
#  'dayNorESM2-MMssp3701950r1i1p1f1g',
#  'dayTaiESM1ssp3701950r1i1p1f1g',
#  'dayACCESS-CM2ssp2451951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451951r1i1p1f1g',
#  'dayCanESM5ssp2451951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451951r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451951r1i1p1f1g',
#  'dayIITM-ESMssp2451951r1i1p1f1g',
#  'dayMIROC6ssp2451951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451951r1i1p1f1g',
#  'dayNorESM2-LMssp2451951r1i1p1f1g',
#  'dayNorESM2-MMssp2451951r1i1p1f1g',
#  'dayTaiESM1ssp2451951r1i1p1f1g',
#  'dayACCESS-CM2ssp5851951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851951r1i1p1f1g',
#  'dayCanESM5ssp5851951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851951r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851951r1i1p1f1g',
#  'dayIITM-ESMssp5851951r1i1p1f1g',
#  'dayMIROC6ssp5851951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851951r1i1p1f1g',
#  'dayNorESM2-LMssp5851951r1i1p1f1g',
#  'dayNorESM2-MMssp5851951r1i1p1f1g',
#  'dayTaiESM1ssp5851951r1i1p1f1g',
#  'dayACCESS-CM2ssp1261951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261951r1i1p1f1g',
#  'dayCanESM5ssp1261951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261951r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261951r1i1p1f1g',
#  'dayIITM-ESMssp1261951r1i1p1f1g',
#  'dayMIROC6ssp1261951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261951r1i1p1f1g',
#  'dayNorESM2-LMssp1261951r1i1p1f1g',
#  'dayNorESM2-MMssp1261951r1i1p1f1g',
#  'dayTaiESM1ssp1261951r1i1p1f1g',
#  'dayACCESS-CM2ssp3701951r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701951r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701951r1i1p1f1g',
#  'dayCanESM5ssp3701951r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701951r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701951r1i1p1f1g',
#  'dayIITM-ESMssp3701951r1i1p1f1g',
#  'dayMIROC6ssp3701951r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701951r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701951r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701951r1i1p1f1g',
#  'dayNorESM2-LMssp3701951r1i1p1f1g',
#  'dayNorESM2-MMssp3701951r1i1p1f1g',
#  'dayTaiESM1ssp3701951r1i1p1f1g',
#  'dayACCESS-CM2ssp2451952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451952r1i1p1f1g',
#  'dayCanESM5ssp2451952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451952r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451952r1i1p1f1g',
#  'dayIITM-ESMssp2451952r1i1p1f1g',
#  'dayMIROC6ssp2451952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451952r1i1p1f1g',
#  'dayNorESM2-LMssp2451952r1i1p1f1g',
#  'dayNorESM2-MMssp2451952r1i1p1f1g',
#  'dayTaiESM1ssp2451952r1i1p1f1g',
#  'dayACCESS-CM2ssp5851952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851952r1i1p1f1g',
#  'dayCanESM5ssp5851952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851952r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851952r1i1p1f1g',
#  'dayIITM-ESMssp5851952r1i1p1f1g',
#  'dayMIROC6ssp5851952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851952r1i1p1f1g',
#  'dayNorESM2-LMssp5851952r1i1p1f1g',
#  'dayNorESM2-MMssp5851952r1i1p1f1g',
#  'dayTaiESM1ssp5851952r1i1p1f1g',
#  'dayACCESS-CM2ssp1261952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261952r1i1p1f1g',
#  'dayCanESM5ssp1261952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261952r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261952r1i1p1f1g',
#  'dayIITM-ESMssp1261952r1i1p1f1g',
#  'dayMIROC6ssp1261952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261952r1i1p1f1g',
#  'dayNorESM2-LMssp1261952r1i1p1f1g',
#  'dayNorESM2-MMssp1261952r1i1p1f1g',
#  'dayTaiESM1ssp1261952r1i1p1f1g',
#  'dayACCESS-CM2ssp3701952r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701952r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701952r1i1p1f1g',
#  'dayCanESM5ssp3701952r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701952r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701952r1i1p1f1g',
#  'dayIITM-ESMssp3701952r1i1p1f1g',
#  'dayMIROC6ssp3701952r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701952r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701952r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701952r1i1p1f1g',
#  'dayNorESM2-LMssp3701952r1i1p1f1g',
#  'dayNorESM2-MMssp3701952r1i1p1f1g',
#  'dayTaiESM1ssp3701952r1i1p1f1g',
#  'dayACCESS-CM2ssp2451953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451953r1i1p1f1g',
#  'dayCanESM5ssp2451953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451953r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451953r1i1p1f1g',
#  'dayIITM-ESMssp2451953r1i1p1f1g',
#  'dayMIROC6ssp2451953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451953r1i1p1f1g',
#  'dayNorESM2-LMssp2451953r1i1p1f1g',
#  'dayNorESM2-MMssp2451953r1i1p1f1g',
#  'dayTaiESM1ssp2451953r1i1p1f1g',
#  'dayACCESS-CM2ssp5851953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851953r1i1p1f1g',
#  'dayCanESM5ssp5851953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851953r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851953r1i1p1f1g',
#  'dayIITM-ESMssp5851953r1i1p1f1g',
#  'dayMIROC6ssp5851953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851953r1i1p1f1g',
#  'dayNorESM2-LMssp5851953r1i1p1f1g',
#  'dayNorESM2-MMssp5851953r1i1p1f1g',
#  'dayTaiESM1ssp5851953r1i1p1f1g',
#  'dayACCESS-CM2ssp1261953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261953r1i1p1f1g',
#  'dayCanESM5ssp1261953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261953r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261953r1i1p1f1g',
#  'dayIITM-ESMssp1261953r1i1p1f1g',
#  'dayMIROC6ssp1261953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261953r1i1p1f1g',
#  'dayNorESM2-LMssp1261953r1i1p1f1g',
#  'dayNorESM2-MMssp1261953r1i1p1f1g',
#  'dayTaiESM1ssp1261953r1i1p1f1g',
#  'dayACCESS-CM2ssp3701953r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701953r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701953r1i1p1f1g',
#  'dayCanESM5ssp3701953r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701953r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701953r1i1p1f1g',
#  'dayIITM-ESMssp3701953r1i1p1f1g',
#  'dayMIROC6ssp3701953r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701953r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701953r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701953r1i1p1f1g',
#  'dayNorESM2-LMssp3701953r1i1p1f1g',
#  'dayNorESM2-MMssp3701953r1i1p1f1g',
#  'dayTaiESM1ssp3701953r1i1p1f1g',
#  'dayACCESS-CM2ssp2451954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451954r1i1p1f1g',
#  'dayCanESM5ssp2451954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451954r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451954r1i1p1f1g',
#  'dayIITM-ESMssp2451954r1i1p1f1g',
#  'dayMIROC6ssp2451954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451954r1i1p1f1g',
#  'dayNorESM2-LMssp2451954r1i1p1f1g',
#  'dayNorESM2-MMssp2451954r1i1p1f1g',
#  'dayTaiESM1ssp2451954r1i1p1f1g',
#  'dayACCESS-CM2ssp5851954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851954r1i1p1f1g',
#  'dayCanESM5ssp5851954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851954r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851954r1i1p1f1g',
#  'dayIITM-ESMssp5851954r1i1p1f1g',
#  'dayMIROC6ssp5851954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851954r1i1p1f1g',
#  'dayNorESM2-LMssp5851954r1i1p1f1g',
#  'dayNorESM2-MMssp5851954r1i1p1f1g',
#  'dayTaiESM1ssp5851954r1i1p1f1g',
#  'dayACCESS-CM2ssp1261954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261954r1i1p1f1g',
#  'dayCanESM5ssp1261954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261954r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261954r1i1p1f1g',
#  'dayIITM-ESMssp1261954r1i1p1f1g',
#  'dayMIROC6ssp1261954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261954r1i1p1f1g',
#  'dayNorESM2-LMssp1261954r1i1p1f1g',
#  'dayNorESM2-MMssp1261954r1i1p1f1g',
#  'dayTaiESM1ssp1261954r1i1p1f1g',
#  'dayACCESS-CM2ssp3701954r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701954r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701954r1i1p1f1g',
#  'dayCanESM5ssp3701954r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701954r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701954r1i1p1f1g',
#  'dayIITM-ESMssp3701954r1i1p1f1g',
#  'dayMIROC6ssp3701954r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701954r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701954r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701954r1i1p1f1g',
#  'dayNorESM2-LMssp3701954r1i1p1f1g',
#  'dayNorESM2-MMssp3701954r1i1p1f1g',
#  'dayTaiESM1ssp3701954r1i1p1f1g',
#  'dayACCESS-CM2ssp2451955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451955r1i1p1f1g',
#  'dayCanESM5ssp2451955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451955r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451955r1i1p1f1g',
#  'dayIITM-ESMssp2451955r1i1p1f1g',
#  'dayMIROC6ssp2451955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451955r1i1p1f1g',
#  'dayNorESM2-LMssp2451955r1i1p1f1g',
#  'dayNorESM2-MMssp2451955r1i1p1f1g',
#  'dayTaiESM1ssp2451955r1i1p1f1g',
#  'dayACCESS-CM2ssp5851955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851955r1i1p1f1g',
#  'dayCanESM5ssp5851955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851955r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851955r1i1p1f1g',
#  'dayIITM-ESMssp5851955r1i1p1f1g',
#  'dayMIROC6ssp5851955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851955r1i1p1f1g',
#  'dayNorESM2-LMssp5851955r1i1p1f1g',
#  'dayNorESM2-MMssp5851955r1i1p1f1g',
#  'dayTaiESM1ssp5851955r1i1p1f1g',
#  'dayACCESS-CM2ssp1261955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261955r1i1p1f1g',
#  'dayCanESM5ssp1261955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261955r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261955r1i1p1f1g',
#  'dayIITM-ESMssp1261955r1i1p1f1g',
#  'dayMIROC6ssp1261955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261955r1i1p1f1g',
#  'dayNorESM2-LMssp1261955r1i1p1f1g',
#  'dayNorESM2-MMssp1261955r1i1p1f1g',
#  'dayTaiESM1ssp1261955r1i1p1f1g',
#  'dayACCESS-CM2ssp3701955r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701955r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701955r1i1p1f1g',
#  'dayCanESM5ssp3701955r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701955r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701955r1i1p1f1g',
#  'dayIITM-ESMssp3701955r1i1p1f1g',
#  'dayMIROC6ssp3701955r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701955r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701955r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701955r1i1p1f1g',
#  'dayNorESM2-LMssp3701955r1i1p1f1g',
#  'dayNorESM2-MMssp3701955r1i1p1f1g',
#  'dayTaiESM1ssp3701955r1i1p1f1g',
#  'dayACCESS-CM2ssp2451956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451956r1i1p1f1g',
#  'dayCanESM5ssp2451956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451956r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451956r1i1p1f1g',
#  'dayIITM-ESMssp2451956r1i1p1f1g',
#  'dayMIROC6ssp2451956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451956r1i1p1f1g',
#  'dayNorESM2-LMssp2451956r1i1p1f1g',
#  'dayNorESM2-MMssp2451956r1i1p1f1g',
#  'dayTaiESM1ssp2451956r1i1p1f1g',
#  'dayACCESS-CM2ssp5851956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851956r1i1p1f1g',
#  'dayCanESM5ssp5851956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851956r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851956r1i1p1f1g',
#  'dayIITM-ESMssp5851956r1i1p1f1g',
#  'dayMIROC6ssp5851956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851956r1i1p1f1g',
#  'dayNorESM2-LMssp5851956r1i1p1f1g',
#  'dayNorESM2-MMssp5851956r1i1p1f1g',
#  'dayTaiESM1ssp5851956r1i1p1f1g',
#  'dayACCESS-CM2ssp1261956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261956r1i1p1f1g',
#  'dayCanESM5ssp1261956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261956r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261956r1i1p1f1g',
#  'dayIITM-ESMssp1261956r1i1p1f1g',
#  'dayMIROC6ssp1261956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261956r1i1p1f1g',
#  'dayNorESM2-LMssp1261956r1i1p1f1g',
#  'dayNorESM2-MMssp1261956r1i1p1f1g',
#  'dayTaiESM1ssp1261956r1i1p1f1g',
#  'dayACCESS-CM2ssp3701956r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701956r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701956r1i1p1f1g',
#  'dayCanESM5ssp3701956r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701956r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701956r1i1p1f1g',
#  'dayIITM-ESMssp3701956r1i1p1f1g',
#  'dayMIROC6ssp3701956r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701956r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701956r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701956r1i1p1f1g',
#  'dayNorESM2-LMssp3701956r1i1p1f1g',
#  'dayNorESM2-MMssp3701956r1i1p1f1g',
#  'dayTaiESM1ssp3701956r1i1p1f1g',
#  'dayACCESS-CM2ssp2451957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451957r1i1p1f1g',
#  'dayCanESM5ssp2451957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451957r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451957r1i1p1f1g',
#  'dayIITM-ESMssp2451957r1i1p1f1g',
#  'dayMIROC6ssp2451957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451957r1i1p1f1g',
#  'dayNorESM2-LMssp2451957r1i1p1f1g',
#  'dayNorESM2-MMssp2451957r1i1p1f1g',
#  'dayTaiESM1ssp2451957r1i1p1f1g',
#  'dayACCESS-CM2ssp5851957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851957r1i1p1f1g',
#  'dayCanESM5ssp5851957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851957r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851957r1i1p1f1g',
#  'dayIITM-ESMssp5851957r1i1p1f1g',
#  'dayMIROC6ssp5851957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851957r1i1p1f1g',
#  'dayNorESM2-LMssp5851957r1i1p1f1g',
#  'dayNorESM2-MMssp5851957r1i1p1f1g',
#  'dayTaiESM1ssp5851957r1i1p1f1g',
#  'dayACCESS-CM2ssp1261957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261957r1i1p1f1g',
#  'dayCanESM5ssp1261957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261957r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261957r1i1p1f1g',
#  'dayIITM-ESMssp1261957r1i1p1f1g',
#  'dayMIROC6ssp1261957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261957r1i1p1f1g',
#  'dayNorESM2-LMssp1261957r1i1p1f1g',
#  'dayNorESM2-MMssp1261957r1i1p1f1g',
#  'dayTaiESM1ssp1261957r1i1p1f1g',
#  'dayACCESS-CM2ssp3701957r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701957r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701957r1i1p1f1g',
#  'dayCanESM5ssp3701957r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701957r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701957r1i1p1f1g',
#  'dayIITM-ESMssp3701957r1i1p1f1g',
#  'dayMIROC6ssp3701957r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701957r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701957r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701957r1i1p1f1g',
#  'dayNorESM2-LMssp3701957r1i1p1f1g',
#  'dayNorESM2-MMssp3701957r1i1p1f1g',
#  'dayTaiESM1ssp3701957r1i1p1f1g',
#  'dayACCESS-CM2ssp2451958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451958r1i1p1f1g',
#  'dayCanESM5ssp2451958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451958r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451958r1i1p1f1g',
#  'dayIITM-ESMssp2451958r1i1p1f1g',
#  'dayMIROC6ssp2451958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451958r1i1p1f1g',
#  'dayNorESM2-LMssp2451958r1i1p1f1g',
#  'dayNorESM2-MMssp2451958r1i1p1f1g',
#  'dayTaiESM1ssp2451958r1i1p1f1g',
#  'dayACCESS-CM2ssp5851958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851958r1i1p1f1g',
#  'dayCanESM5ssp5851958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851958r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851958r1i1p1f1g',
#  'dayIITM-ESMssp5851958r1i1p1f1g',
#  'dayMIROC6ssp5851958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851958r1i1p1f1g',
#  'dayNorESM2-LMssp5851958r1i1p1f1g',
#  'dayNorESM2-MMssp5851958r1i1p1f1g',
#  'dayTaiESM1ssp5851958r1i1p1f1g',
#  'dayACCESS-CM2ssp1261958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261958r1i1p1f1g',
#  'dayCanESM5ssp1261958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261958r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261958r1i1p1f1g',
#  'dayIITM-ESMssp1261958r1i1p1f1g',
#  'dayMIROC6ssp1261958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261958r1i1p1f1g',
#  'dayNorESM2-LMssp1261958r1i1p1f1g',
#  'dayNorESM2-MMssp1261958r1i1p1f1g',
#  'dayTaiESM1ssp1261958r1i1p1f1g',
#  'dayACCESS-CM2ssp3701958r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701958r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701958r1i1p1f1g',
#  'dayCanESM5ssp3701958r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701958r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701958r1i1p1f1g',
#  'dayIITM-ESMssp3701958r1i1p1f1g',
#  'dayMIROC6ssp3701958r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701958r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701958r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701958r1i1p1f1g',
#  'dayNorESM2-LMssp3701958r1i1p1f1g',
#  'dayNorESM2-MMssp3701958r1i1p1f1g',
#  'dayTaiESM1ssp3701958r1i1p1f1g',
#  'dayACCESS-CM2ssp2451959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451959r1i1p1f1g',
#  'dayCanESM5ssp2451959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451959r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451959r1i1p1f1g',
#  'dayIITM-ESMssp2451959r1i1p1f1g',
#  'dayMIROC6ssp2451959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451959r1i1p1f1g',
#  'dayNorESM2-LMssp2451959r1i1p1f1g',
#  'dayNorESM2-MMssp2451959r1i1p1f1g',
#  'dayTaiESM1ssp2451959r1i1p1f1g',
#  'dayACCESS-CM2ssp5851959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851959r1i1p1f1g',
#  'dayCanESM5ssp5851959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851959r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851959r1i1p1f1g',
#  'dayIITM-ESMssp5851959r1i1p1f1g',
#  'dayMIROC6ssp5851959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851959r1i1p1f1g',
#  'dayNorESM2-LMssp5851959r1i1p1f1g',
#  'dayNorESM2-MMssp5851959r1i1p1f1g',
#  'dayTaiESM1ssp5851959r1i1p1f1g',
#  'dayACCESS-CM2ssp1261959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261959r1i1p1f1g',
#  'dayCanESM5ssp1261959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261959r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261959r1i1p1f1g',
#  'dayIITM-ESMssp1261959r1i1p1f1g',
#  'dayMIROC6ssp1261959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261959r1i1p1f1g',
#  'dayNorESM2-LMssp1261959r1i1p1f1g',
#  'dayNorESM2-MMssp1261959r1i1p1f1g',
#  'dayTaiESM1ssp1261959r1i1p1f1g',
#  'dayACCESS-CM2ssp3701959r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701959r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701959r1i1p1f1g',
#  'dayCanESM5ssp3701959r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701959r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701959r1i1p1f1g',
#  'dayIITM-ESMssp3701959r1i1p1f1g',
#  'dayMIROC6ssp3701959r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701959r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701959r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701959r1i1p1f1g',
#  'dayNorESM2-LMssp3701959r1i1p1f1g',
#  'dayNorESM2-MMssp3701959r1i1p1f1g',
#  'dayTaiESM1ssp3701959r1i1p1f1g',
#  'dayACCESS-CM2ssp2451960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451960r1i1p1f1g',
#  'dayCanESM5ssp2451960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451960r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451960r1i1p1f1g',
#  'dayIITM-ESMssp2451960r1i1p1f1g',
#  'dayMIROC6ssp2451960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451960r1i1p1f1g',
#  'dayNorESM2-LMssp2451960r1i1p1f1g',
#  'dayNorESM2-MMssp2451960r1i1p1f1g',
#  'dayTaiESM1ssp2451960r1i1p1f1g',
#  'dayACCESS-CM2ssp5851960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851960r1i1p1f1g',
#  'dayCanESM5ssp5851960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851960r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851960r1i1p1f1g',
#  'dayIITM-ESMssp5851960r1i1p1f1g',
#  'dayMIROC6ssp5851960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851960r1i1p1f1g',
#  'dayNorESM2-LMssp5851960r1i1p1f1g',
#  'dayNorESM2-MMssp5851960r1i1p1f1g',
#  'dayTaiESM1ssp5851960r1i1p1f1g',
#  'dayACCESS-CM2ssp1261960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261960r1i1p1f1g',
#  'dayCanESM5ssp1261960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261960r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261960r1i1p1f1g',
#  'dayIITM-ESMssp1261960r1i1p1f1g',
#  'dayMIROC6ssp1261960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261960r1i1p1f1g',
#  'dayNorESM2-LMssp1261960r1i1p1f1g',
#  'dayNorESM2-MMssp1261960r1i1p1f1g',
#  'dayTaiESM1ssp1261960r1i1p1f1g',
#  'dayACCESS-CM2ssp3701960r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701960r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701960r1i1p1f1g',
#  'dayCanESM5ssp3701960r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701960r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701960r1i1p1f1g',
#  'dayIITM-ESMssp3701960r1i1p1f1g',
#  'dayMIROC6ssp3701960r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701960r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701960r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701960r1i1p1f1g',
#  'dayNorESM2-LMssp3701960r1i1p1f1g',
#  'dayNorESM2-MMssp3701960r1i1p1f1g',
#  'dayTaiESM1ssp3701960r1i1p1f1g',
#  'dayACCESS-CM2ssp2451961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451961r1i1p1f1g',
#  'dayCanESM5ssp2451961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451961r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451961r1i1p1f1g',
#  'dayIITM-ESMssp2451961r1i1p1f1g',
#  'dayMIROC6ssp2451961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451961r1i1p1f1g',
#  'dayNorESM2-LMssp2451961r1i1p1f1g',
#  'dayNorESM2-MMssp2451961r1i1p1f1g',
#  'dayTaiESM1ssp2451961r1i1p1f1g',
#  'dayACCESS-CM2ssp5851961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851961r1i1p1f1g',
#  'dayCanESM5ssp5851961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851961r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851961r1i1p1f1g',
#  'dayIITM-ESMssp5851961r1i1p1f1g',
#  'dayMIROC6ssp5851961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851961r1i1p1f1g',
#  'dayNorESM2-LMssp5851961r1i1p1f1g',
#  'dayNorESM2-MMssp5851961r1i1p1f1g',
#  'dayTaiESM1ssp5851961r1i1p1f1g',
#  'dayACCESS-CM2ssp1261961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261961r1i1p1f1g',
#  'dayCanESM5ssp1261961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261961r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261961r1i1p1f1g',
#  'dayIITM-ESMssp1261961r1i1p1f1g',
#  'dayMIROC6ssp1261961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261961r1i1p1f1g',
#  'dayNorESM2-LMssp1261961r1i1p1f1g',
#  'dayNorESM2-MMssp1261961r1i1p1f1g',
#  'dayTaiESM1ssp1261961r1i1p1f1g',
#  'dayACCESS-CM2ssp3701961r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701961r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701961r1i1p1f1g',
#  'dayCanESM5ssp3701961r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701961r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701961r1i1p1f1g',
#  'dayIITM-ESMssp3701961r1i1p1f1g',
#  'dayMIROC6ssp3701961r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701961r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701961r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701961r1i1p1f1g',
#  'dayNorESM2-LMssp3701961r1i1p1f1g',
#  'dayNorESM2-MMssp3701961r1i1p1f1g',
#  'dayTaiESM1ssp3701961r1i1p1f1g',
#  'dayACCESS-CM2ssp2451962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451962r1i1p1f1g',
#  'dayCanESM5ssp2451962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451962r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451962r1i1p1f1g',
#  'dayIITM-ESMssp2451962r1i1p1f1g',
#  'dayMIROC6ssp2451962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451962r1i1p1f1g',
#  'dayNorESM2-LMssp2451962r1i1p1f1g',
#  'dayNorESM2-MMssp2451962r1i1p1f1g',
#  'dayTaiESM1ssp2451962r1i1p1f1g',
#  'dayACCESS-CM2ssp5851962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851962r1i1p1f1g',
#  'dayCanESM5ssp5851962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851962r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851962r1i1p1f1g',
#  'dayIITM-ESMssp5851962r1i1p1f1g',
#  'dayMIROC6ssp5851962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851962r1i1p1f1g',
#  'dayNorESM2-LMssp5851962r1i1p1f1g',
#  'dayNorESM2-MMssp5851962r1i1p1f1g',
#  'dayTaiESM1ssp5851962r1i1p1f1g',
#  'dayACCESS-CM2ssp1261962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261962r1i1p1f1g',
#  'dayCanESM5ssp1261962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261962r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261962r1i1p1f1g',
#  'dayIITM-ESMssp1261962r1i1p1f1g',
#  'dayMIROC6ssp1261962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261962r1i1p1f1g',
#  'dayNorESM2-LMssp1261962r1i1p1f1g',
#  'dayNorESM2-MMssp1261962r1i1p1f1g',
#  'dayTaiESM1ssp1261962r1i1p1f1g',
#  'dayACCESS-CM2ssp3701962r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701962r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701962r1i1p1f1g',
#  'dayCanESM5ssp3701962r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701962r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701962r1i1p1f1g',
#  'dayIITM-ESMssp3701962r1i1p1f1g',
#  'dayMIROC6ssp3701962r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701962r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701962r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701962r1i1p1f1g',
#  'dayNorESM2-LMssp3701962r1i1p1f1g',
#  'dayNorESM2-MMssp3701962r1i1p1f1g',
#  'dayTaiESM1ssp3701962r1i1p1f1g',
#  'dayACCESS-CM2ssp2451963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451963r1i1p1f1g',
#  'dayCanESM5ssp2451963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451963r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451963r1i1p1f1g',
#  'dayIITM-ESMssp2451963r1i1p1f1g',
#  'dayMIROC6ssp2451963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451963r1i1p1f1g',
#  'dayNorESM2-LMssp2451963r1i1p1f1g',
#  'dayNorESM2-MMssp2451963r1i1p1f1g',
#  'dayTaiESM1ssp2451963r1i1p1f1g',
#  'dayACCESS-CM2ssp5851963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851963r1i1p1f1g',
#  'dayCanESM5ssp5851963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851963r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851963r1i1p1f1g',
#  'dayIITM-ESMssp5851963r1i1p1f1g',
#  'dayMIROC6ssp5851963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851963r1i1p1f1g',
#  'dayNorESM2-LMssp5851963r1i1p1f1g',
#  'dayNorESM2-MMssp5851963r1i1p1f1g',
#  'dayTaiESM1ssp5851963r1i1p1f1g',
#  'dayACCESS-CM2ssp1261963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261963r1i1p1f1g',
#  'dayCanESM5ssp1261963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261963r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261963r1i1p1f1g',
#  'dayIITM-ESMssp1261963r1i1p1f1g',
#  'dayMIROC6ssp1261963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261963r1i1p1f1g',
#  'dayNorESM2-LMssp1261963r1i1p1f1g',
#  'dayNorESM2-MMssp1261963r1i1p1f1g',
#  'dayTaiESM1ssp1261963r1i1p1f1g',
#  'dayACCESS-CM2ssp3701963r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701963r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701963r1i1p1f1g',
#  'dayCanESM5ssp3701963r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701963r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701963r1i1p1f1g',
#  'dayIITM-ESMssp3701963r1i1p1f1g',
#  'dayMIROC6ssp3701963r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701963r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701963r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701963r1i1p1f1g',
#  'dayNorESM2-LMssp3701963r1i1p1f1g',
#  'dayNorESM2-MMssp3701963r1i1p1f1g',
#  'dayTaiESM1ssp3701963r1i1p1f1g',
#  'dayACCESS-CM2ssp2451964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451964r1i1p1f1g',
#  'dayCanESM5ssp2451964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451964r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451964r1i1p1f1g',
#  'dayIITM-ESMssp2451964r1i1p1f1g',
#  'dayMIROC6ssp2451964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451964r1i1p1f1g',
#  'dayNorESM2-LMssp2451964r1i1p1f1g',
#  'dayNorESM2-MMssp2451964r1i1p1f1g',
#  'dayTaiESM1ssp2451964r1i1p1f1g',
#  'dayACCESS-CM2ssp5851964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851964r1i1p1f1g',
#  'dayCanESM5ssp5851964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851964r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851964r1i1p1f1g',
#  'dayIITM-ESMssp5851964r1i1p1f1g',
#  'dayMIROC6ssp5851964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851964r1i1p1f1g',
#  'dayNorESM2-LMssp5851964r1i1p1f1g',
#  'dayNorESM2-MMssp5851964r1i1p1f1g',
#  'dayTaiESM1ssp5851964r1i1p1f1g',
#  'dayACCESS-CM2ssp1261964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261964r1i1p1f1g',
#  'dayCanESM5ssp1261964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261964r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261964r1i1p1f1g',
#  'dayIITM-ESMssp1261964r1i1p1f1g',
#  'dayMIROC6ssp1261964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261964r1i1p1f1g',
#  'dayNorESM2-LMssp1261964r1i1p1f1g',
#  'dayNorESM2-MMssp1261964r1i1p1f1g',
#  'dayTaiESM1ssp1261964r1i1p1f1g',
#  'dayACCESS-CM2ssp3701964r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701964r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701964r1i1p1f1g',
#  'dayCanESM5ssp3701964r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701964r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701964r1i1p1f1g',
#  'dayIITM-ESMssp3701964r1i1p1f1g',
#  'dayMIROC6ssp3701964r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701964r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701964r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701964r1i1p1f1g',
#  'dayNorESM2-LMssp3701964r1i1p1f1g',
#  'dayNorESM2-MMssp3701964r1i1p1f1g',
#  'dayTaiESM1ssp3701964r1i1p1f1g',
#  'dayACCESS-CM2ssp2451965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451965r1i1p1f1g',
#  'dayCanESM5ssp2451965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451965r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451965r1i1p1f1g',
#  'dayIITM-ESMssp2451965r1i1p1f1g',
#  'dayMIROC6ssp2451965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451965r1i1p1f1g',
#  'dayNorESM2-LMssp2451965r1i1p1f1g',
#  'dayNorESM2-MMssp2451965r1i1p1f1g',
#  'dayTaiESM1ssp2451965r1i1p1f1g',
#  'dayACCESS-CM2ssp5851965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851965r1i1p1f1g',
#  'dayCanESM5ssp5851965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851965r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851965r1i1p1f1g',
#  'dayIITM-ESMssp5851965r1i1p1f1g',
#  'dayMIROC6ssp5851965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851965r1i1p1f1g',
#  'dayNorESM2-LMssp5851965r1i1p1f1g',
#  'dayNorESM2-MMssp5851965r1i1p1f1g',
#  'dayTaiESM1ssp5851965r1i1p1f1g',
#  'dayACCESS-CM2ssp1261965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261965r1i1p1f1g',
#  'dayCanESM5ssp1261965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261965r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261965r1i1p1f1g',
#  'dayIITM-ESMssp1261965r1i1p1f1g',
#  'dayMIROC6ssp1261965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261965r1i1p1f1g',
#  'dayNorESM2-LMssp1261965r1i1p1f1g',
#  'dayNorESM2-MMssp1261965r1i1p1f1g',
#  'dayTaiESM1ssp1261965r1i1p1f1g',
#  'dayACCESS-CM2ssp3701965r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701965r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701965r1i1p1f1g',
#  'dayCanESM5ssp3701965r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701965r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701965r1i1p1f1g',
#  'dayIITM-ESMssp3701965r1i1p1f1g',
#  'dayMIROC6ssp3701965r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701965r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701965r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701965r1i1p1f1g',
#  'dayNorESM2-LMssp3701965r1i1p1f1g',
#  'dayNorESM2-MMssp3701965r1i1p1f1g',
#  'dayTaiESM1ssp3701965r1i1p1f1g',
#  'dayACCESS-CM2ssp2451966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451966r1i1p1f1g',
#  'dayCanESM5ssp2451966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451966r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451966r1i1p1f1g',
#  'dayIITM-ESMssp2451966r1i1p1f1g',
#  'dayMIROC6ssp2451966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451966r1i1p1f1g',
#  'dayNorESM2-LMssp2451966r1i1p1f1g',
#  'dayNorESM2-MMssp2451966r1i1p1f1g',
#  'dayTaiESM1ssp2451966r1i1p1f1g',
#  'dayACCESS-CM2ssp5851966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851966r1i1p1f1g',
#  'dayCanESM5ssp5851966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851966r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851966r1i1p1f1g',
#  'dayIITM-ESMssp5851966r1i1p1f1g',
#  'dayMIROC6ssp5851966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851966r1i1p1f1g',
#  'dayNorESM2-LMssp5851966r1i1p1f1g',
#  'dayNorESM2-MMssp5851966r1i1p1f1g',
#  'dayTaiESM1ssp5851966r1i1p1f1g',
#  'dayACCESS-CM2ssp1261966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261966r1i1p1f1g',
#  'dayCanESM5ssp1261966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261966r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261966r1i1p1f1g',
#  'dayIITM-ESMssp1261966r1i1p1f1g',
#  'dayMIROC6ssp1261966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261966r1i1p1f1g',
#  'dayNorESM2-LMssp1261966r1i1p1f1g',
#  'dayNorESM2-MMssp1261966r1i1p1f1g',
#  'dayTaiESM1ssp1261966r1i1p1f1g',
#  'dayACCESS-CM2ssp3701966r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701966r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701966r1i1p1f1g',
#  'dayCanESM5ssp3701966r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701966r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701966r1i1p1f1g',
#  'dayIITM-ESMssp3701966r1i1p1f1g',
#  'dayMIROC6ssp3701966r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp3701966r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp3701966r1i1p1f1g',
#  'dayMRI-ESM2-0ssp3701966r1i1p1f1g',
#  'dayNorESM2-LMssp3701966r1i1p1f1g',
#  'dayNorESM2-MMssp3701966r1i1p1f1g',
#  'dayTaiESM1ssp3701966r1i1p1f1g',
#  'dayACCESS-CM2ssp2451967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp2451967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp2451967r1i1p1f1g',
#  'dayCanESM5ssp2451967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp2451967r1i1p1f1g',
#  'dayCMCC-ESM2ssp2451967r1i1p1f1g',
#  'dayIITM-ESMssp2451967r1i1p1f1g',
#  'dayMIROC6ssp2451967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp2451967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp2451967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp2451967r1i1p1f1g',
#  'dayNorESM2-LMssp2451967r1i1p1f1g',
#  'dayNorESM2-MMssp2451967r1i1p1f1g',
#  'dayTaiESM1ssp2451967r1i1p1f1g',
#  'dayACCESS-CM2ssp5851967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp5851967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp5851967r1i1p1f1g',
#  'dayCanESM5ssp5851967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp5851967r1i1p1f1g',
#  'dayCMCC-ESM2ssp5851967r1i1p1f1g',
#  'dayIITM-ESMssp5851967r1i1p1f1g',
#  'dayMIROC6ssp5851967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp5851967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp5851967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp5851967r1i1p1f1g',
#  'dayNorESM2-LMssp5851967r1i1p1f1g',
#  'dayNorESM2-MMssp5851967r1i1p1f1g',
#  'dayTaiESM1ssp5851967r1i1p1f1g',
#  'dayACCESS-CM2ssp1261967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp1261967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp1261967r1i1p1f1g',
#  'dayCanESM5ssp1261967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp1261967r1i1p1f1g',
#  'dayCMCC-ESM2ssp1261967r1i1p1f1g',
#  'dayIITM-ESMssp1261967r1i1p1f1g',
#  'dayMIROC6ssp1261967r1i1p1f1g',
#  'dayMPI-ESM1-2-HRssp1261967r1i1p1f1g',
#  'dayMPI-ESM1-2-LRssp1261967r1i1p1f1g',
#  'dayMRI-ESM2-0ssp1261967r1i1p1f1g',
#  'dayNorESM2-LMssp1261967r1i1p1f1g',
#  'dayNorESM2-MMssp1261967r1i1p1f1g',
#  'dayTaiESM1ssp1261967r1i1p1f1g',
#  'dayACCESS-CM2ssp3701967r1i1p1f1g',
#  'dayACCESS-ESM1-5ssp3701967r1i1p1f1g',
#  'dayBCC-CSM2-MRssp3701967r1i1p1f1g',
#  'dayCanESM5ssp3701967r1i1p1f1g',
#  'dayCMCC-CM2-SR5ssp3701967r1i1p1f1g',
#  'dayCMCC-ESM2ssp3701967r1i1p1f1g',
#  ...]

# %%
ds = xr.open_dataset(r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1980.nc')

# %%
if np.isnan(ds.pr.values).any():
    print('Il y a des valeurs NaN')
if ~np.isnan(ds.pr.values).any():
    print('Il n y a pas que des valeurs NaN')
# Out:
# Il y a des valeurs NaN

# %%
i=0
time = ds.indexes['time'].strftime('%d-%m-%Y').values # register the time in the file
df_climate_var.loc[(name_project[i],'historical','NorESM2-LM',closest_value_lat[i],closest_value_lon[i],time)] = ds.pr.isel(lat=index_closest_lat[i],lon=index_closest_lon[i]).values.reshape(len(time),1)*86400

# %%
df_climate_var.loc[(name_project[i],'historical',models[0],closest_value_lat[i],closest_value_lon[i],time)]
# Out:
#                                                                           Precipitation mm/day
# Name project          Experiment Model      Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical ACCESS-CM2 -16.125  33.625    01-01-1980                  0.0
#                                                                02-01-1980                  0.0
#                                                                03-01-1980                  0.0
#                                                                04-01-1980                  0.0
#                                                                05-01-1980                  0.0
# ...                                                                                        ...
#                                                                27-12-1980             8.235041
#                                                                28-12-1980             8.231319
#                                                                29-12-1980                  0.0
#                                                                30-12-1980                  0.0
#                                                                31-12-1980             0.692527
#
# [365 rows x 1 columns]

# %%
ds_did_not_open
# Out:
# ['\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1950.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1979.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1979.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1979.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1980.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1981.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1982.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1983.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1984.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1985.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1986.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1987.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1988.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1989.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1990.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1991.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1992.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1993.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1994.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1995.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1996.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1997.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1998.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_1999.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_2000.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_2001.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_2002.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_2003.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_historical_r1i1p1f1_gn_2004.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_historical_r1i1p1f1_gn_2005.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_historical_r1i1p1f1_gn_2005.nc',
# ...
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2023.nc',
#  ...]

# %%
df_climate_var.loc[(name_project[i],'historical',models[2],closest_value_lat[i],closest_value_lon[i],time)]
# Out:
#                                                                            Precipitation mm/day
# Name project          Experiment Model       Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical BCC-CSM2-MR -16.125  33.625    01-01-1980                  NaN
#                                                                 02-01-1980                  NaN
#                                                                 03-01-1980                  NaN
#                                                                 04-01-1980                  NaN
#                                                                 05-01-1980                  NaN
# ...                                                                                         ...
#                                                                 27-12-1980                  NaN
#                                                                 28-12-1980                  NaN
#                                                                 29-12-1980                  NaN
#                                                                 30-12-1980                  NaN
#                                                                 31-12-1980                  NaN
#
# [365 rows x 1 columns]

# %%
df_climate_var.loc[(name_project[i],'historical',models[3],closest_value_lat[i],closest_value_lon[i],time)]
# Out:
#                                                                        Precipitation mm/day
# Name project          Experiment Model   Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical CanESM5 -16.125  33.625    01-01-1980                  NaN
#                                                             02-01-1980                  NaN
#                                                             03-01-1980                  NaN
#                                                             04-01-1980                  NaN
#                                                             05-01-1980                  NaN
# ...                                                                                     ...
#                                                             27-12-1980                  NaN
#                                                             28-12-1980                  NaN
#                                                             29-12-1980                  NaN
#                                                             30-12-1980                  NaN
#                                                             31-12-1980                  NaN
#
# [365 rows x 1 columns]

# %%
df_climate_var.loc[(name_project[i],'historical',models[4],closest_value_lat[i],closest_value_lon[i],time)]
# Out:
#                                                                             Precipitation mm/day
# Name project          Experiment Model        Latitude Longitude Date
# PT_Revubue_2_Rev_2_01 historical CMCC-CM2-SR5 -16.125  33.625    01-01-1980                  NaN
#                                                                  02-01-1980                  NaN
#                                                                  03-01-1980                  NaN
#                                                                  04-01-1980                  NaN
#                                                                  05-01-1980                  NaN
# ...                                                                                          ...
#                                                                  27-12-1980                  NaN
#                                                                  28-12-1980                  NaN
#                                                                  29-12-1980                  NaN
#                                                                  30-12-1980                  NaN
#                                                                  31-12-1980                  NaN
#
# [365 rows x 1 columns]

# %%
import io
import sys
import builtins
import traceback
from functools import wraps


def opener(old_open):
    @wraps(old_open)
    def tracking_open(*args, **kw):
        file = old_open(*args, **kw)

        old_close = file.close
        @wraps(old_close)
        def close():
            old_close()
            open_files.remove(file)
        file.close = close
        file.stack = traceback.extract_stack()

        open_files.add(file)
        return file
    return tracking_open


def print_open_files():
    print(f'### {len(open_files)} OPEN FILES: [{", ".join(f.name for f in open_files)}]', file=sys.stderr)
    for file in open_files:
        print(f'Open file {file.name}:\n{"".join(traceback.format_list(file.stack))}', file=sys.stderr)


open_files = set()
io.open = opener(io.open)
builtins.open = opener(builtins.open)

# %%
open_files
# Out:
# set()
