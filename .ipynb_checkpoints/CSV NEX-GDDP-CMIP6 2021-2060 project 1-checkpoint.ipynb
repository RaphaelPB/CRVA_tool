# %% [markdown]
# # Import Packages and functions

# %%
import requests
import pandas as pd

import os
import os.path

from netCDF4 import Dataset

import xarray as xr

import numpy as np
import numpy.ma as ma

# to measure elapsed time
import time
from timeit import default_timer as timer

import multiprocessing as mp# to download several file in parrallel
from multiprocessing.pool import ThreadPool

from FileManagement2 import produce_name_list
from FunctionsAndClass import year_copernicus
from FileManagement2 import find_path_file
from FileManagement2 import find_column_name
from FileManagement2 import time_vector_conversion
from FileManagement2 import data_information
from FileManagement2 import df_to_csv
from FileManagement2 import read_nc_file
from FileManagement2 import information_files_in_vectors
from FileManagement2 import _lat_lon
from FileManagement2 import create_empty_dataframe
from FileManagement2 import register_data_in_dataframe
# Out:
# C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\FunctionsAndClass.py:12: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# # Projects information

# %%
import geopandas as gpd
import os
import os.path

data_folder=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets'
project_location_path=os.path.join(data_folder,'Mozambique_PPIS/EIB_locations_few.shp')
#study boundary (optional)
study_area_path=os.path.join(data_folder,'Mozambique_PPIS/mozambique.shp')


#projection CRS (default = 'EPSG:4326')
bCRS='EPSG:4326'

#buffer for climate/grid variables
buffer=40000 #buffer in meters, 0 = no buffer is computed

mCRS='EPSG:31983' #metric CRS for buffer in meters (find relevant metric CRS for location!)

#load shapefiles
projects = gpd.read_file(project_location_path).to_crs(bCRS)
project_id='Name' #name of column used as id

study_area = gpd.read_file(study_area_path).to_crs(bCRS)

#calculate buffer around points/shape
if buffer != 0:
    projects_buf=projects.to_crs(mCRS)  #project to crs with metric units to get buffer in meters
    projects_buf['geometry']=projects.to_crs(mCRS).buffer(buffer) #assign the buffer as the new geometry - 
    projects_buf=projects_buf.to_crs(bCRS)#project back to orginal crs

    
#plot shapefiles
study_area.plot()
projects.plot()
projects_buf.plot() 


#show table
projects[[project_id]]
# prepare name_project for use 
name_project = projects['Name'].str.replace(' ','_') # take off every blank space of project names
name_project = name_project.str.replace('(','') # take off every ( of project names
name_project = name_project.str.replace(')','') # take off every ) of project names
name_project = name_project.str.replace('-','') # take off every - of project names
name_project = name_project.str.replace('/','_') # take off every / of project names
name_project = name_project.str.replace(r'"\"','_') # take off every \ of project names

# register geographic information concerning projects
lon_projects = projects['geometry'].x
lat_projects = projects['geometry'].y
buf_projects = 0.3
area_projects = [lat_projects - buf_projects, lat_projects+buf_projects, lon_projects-buf_projects,lon_projects+buf_projects] # list format
#### determination of the geographical zone of interest 
lat_min_wanted = min(study_area['LAT'])-10
lat_max_wanted = max(study_area['LAT'])+10
lon_min_wanted = min(study_area['LON'])-20
lon_max_wanted = max(study_area['LON'])+20
# addind and substracting to lon and lat to have margin
# substracting more to longitude because the range of longitude is -180 to 180. The range of latitude is -90 to 90

# %% [markdown]
# # Define Paths

# %%
out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6'

# %% [markdown]
# # Complete list of url with files to download

# %%
# register information from csv file
#all_urls = pd.read_csv(r'C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\outputs\NEX-GDDP-CMIP6\gddp-cmip6-thredds-fileserver.csv')
csv_path = os.path.join(out_path,'gddp-cmip6-thredds-fileserver.csv')
all_urls = pd.read_csv(csv_path)

# %%
### make all elements of the csv into a readable list

temp_list = all_urls[[' fileUrl']].T# transpose csv
temp_list=temp_list.values.tolist()
temp_list=temp_list[0]
url_list=[s.replace(' ', '') for s in temp_list]

# %%
## download only precipitation data
# select only precipitation files, between 2040 and 2080
url_list_precipitation = [url for url in url_list if 'pr_day_' in url and int(url[len(url)-7:len(url)-3])>2020 and int(url[len(url)-7:len(url)-3])<2061 and 'r1i1p1f1_gn' in url]

# %%
len(url_list_precipitation)
# Out:
# 2360

# %%
name_list_precipitation = produce_name_list(url_list_precipitation)

# %% [markdown]
# # Produce csv files with data to use

# %%
start_year = 2030
stop_year = 2040
(year, year_str, index_year) = year_copernicus(start_year,stop_year)
time = pd.date_range('01-01-2030','31-12-2040', freq='D').strftime('%d-%m-%Y').values

# %%
# variables, time_aggregations,models,scenarios in the name_list_precipitation
(variables, time_aggregations,models,scenarios)=information_files_in_vectors(name_list_precipitation)

# %%
path_test1 = os.path.join(out_path,'pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2050.nc')

# %%
(index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon)=_lat_lon(path_test1,lat_projects,lon_projects)

# %%
df_precipitation=create_empty_dataframe([name_project[0]],scenarios,models,time,closest_value_lat,closest_value_lon)

# %%
name_variable= 'pr'
(df_precipitation,path_file_not_found,ds_did_not_open)=register_data_in_dataframe(name_list_precipitation,time_aggregations[0],year_str,scenarios,models,out_path, name_variable,[name_project[0]],lon_projects,lat_projects,index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon,df_precipitation)

# %%
title_file = 'Project_PT_Revubue_2_Rev_2_01_moz_precipitation_2030-2040.csv'
path_csv = df_to_csv(df_precipitation,out_path,title_file,name_variable,time_aggregations[0],'2030-2040')

# %%
path_file_not_found

# %%
ds_did_not_open

# %%
start_year = 2021
stop_year = 2060
(year, year_str, index_year) = year_copernicus(start_year,stop_year)
time = pd.date_range('01-01-2030','31-12-2060', freq='D').strftime('%d-%m-%Y').values

# %%
df_precipitation1=create_empty_dataframe([name_project[0]],scenarios,models,time,closest_value_lat,closest_value_lon)

# %%
name_variable= 'pr'
(df_precipitation1,path_file_not_found,ds_did_not_open)=register_data_in_dataframe(name_list_precipitation,time_aggregations[0],year_str,scenarios,models,out_path, name_variable,[name_project[0]],lon_projects,lat_projects,index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon,df_precipitation1)
# Out:
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2021 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2021.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2022 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2022.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2023 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2023.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2024 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2024.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2025 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2025.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2026.nc']
# For the year 2026 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ...
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2059 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2059.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CanESM5
# ['pr_day_CanESM5_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MIROC6
# ['pr_day_MIROC6_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NESM3
# ['pr_day_NESM3_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp245, with model TaiESM1
# ['pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CanESM5
# ['pr_day_CanESM5_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MIROC6
# ['pr_day_MIROC6_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NESM3
# ['pr_day_NESM3_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp585, with model TaiESM1
# ['pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CanESM5
# ['pr_day_CanESM5_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MIROC6
# ['pr_day_MIROC6_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NESM3
# ['pr_day_NESM3_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp126, with model TaiESM1
# ['pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-CM2
# ['pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model ACCESS-ESM1-5
# ['pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model BCC-CSM2-MR
# ['pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CanESM5
# ['pr_day_CanESM5_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-CM2-SR5
# ['pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model CMCC-ESM2
# ['pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model IITM-ESM
# ['pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MIROC6
# ['pr_day_MIROC6_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-HR
# ['pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MPI-ESM1-2-LR
# ['pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model MRI-ESM2-0
# ['pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NESM3
# []
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-LM
# ['pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model NorESM2-MM
# ['pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2060.nc']
# For the year 2060 and project PT_Revubue_2_Rev_2_01, test with scenario ssp370, with model TaiESM1
# ['pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2060.nc']

# %%
title_file = 'Project_PT_Revubue_2_Rev_2_01_moz_precipitation_2020-2060.csv'
path_csv = df_to_csv(df_precipitation1,out_path,title_file,name_variable,time_aggregations[0],'2020-2060')
# Out:
# \\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6\csv_file\pr_day_2020-2060\Project_PT_Revubue_2_Rev_2_01_moz_precipitation_2020-2060.csv

# %%
len(path_file_not_found)
# Out:
# 40

# %%
ds_did_not_open
# Out:
# ['\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2021.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2022.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2023.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2024.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2025.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2026.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2027.nc',
# ...
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2027.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2028.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp245_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp585_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NESM3_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp126_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-CM2_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_ACCESS-ESM1-5_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_BCC-CSM2-MR_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CanESM5_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-CM2-SR5_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_CMCC-ESM2_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_IITM-ESM_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MIROC6_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-HR_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MPI-ESM1-2-LR_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_MRI-ESM2-0_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-LM_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_NorESM2-MM_ssp370_r1i1p1f1_gn_2029.nc',
#  '\\\\COWI.net\\projects\\A245000\\A248363\\CRVA\\Datasets\\NEX-GDDP-CMIP6\\pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2029.nc']

# %%
name_project
# Out:
# 0         PT_Revubue_2_Rev_2_01
# 1                 WTP_gate_cnr1
# 2               Mugica_dam_road
# 3         Chimoio_2ML_Reservoir
# 4               PT_Nicoadala_F5
# 5    PT1_Pemba__Breidge_Paquite
# 6              PT__Dumping_Site
# Name: Name, dtype: object

# %%
from FileManagement1 import find_column_name
from FileManagement1 import get_data_nc

# %%
path_test = os.path.join(out_path,'pr_day_ACCESS-CM2_ssp245_r1i1p1f1_gn_2040.nc')
Open_path = Dataset(path_test)

# %%
column_name = find_column_name(Open_path)

# %%
column_name

# %%
data_with_all = get_data_nc(Open_path,column_name)

# %%
np.ma.getdata(Open_path.variables['pr']).data

# %%
Open_path.variables

# %%
np.ma.getdata(Open_path.variables['lat']).data

# %%
path_test1 = os.path.join(out_path,'pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2050.nc')
Open_path1 = Dataset(path_test1)
column_name1 = find_column_name(Open_path1)

# %%
np.ma.getdata(Open_path.variables['pr']).data

# %%
### Single netcdf file ###
import xarray as xr
from FileManagement1 import closest_lat_lon_to_proj
lat_test_xr  = ds.lat.values
lon_test_xr  = ds.lon.values
(index_closest_lat, closest_value_lat)=closest_lat_lon_to_proj(lat_projects[1],lat_test_xr)
(index_closest_lon, closest_value_lon)=closest_lat_lon_to_proj(lon_projects[1],lon_test_xr)
start_time = timer()
ds =  xr.open_dataset(path_test1)
precipitation = ds.pr.isel(lat=index_closest_lat,lon=index_closest_lon).values
end_time = timer()
print('Need '+str(end_time-start_time)+' seconds to run with xarray')

# %%
index_closest_lat

# %%
lat_test_xr  = ds.lat.values

# %%
lat_test_xr

# %%
time_test_xr  = ds.time.values

# %%
time_test_xr

# %%
time=ds.indexes['time'].strftime('%m-%d-%Y')

# %%
time=ds.time.values

# %%
time

# %%
# create empty dataframe

# %%
ds =  xr.open_dataset(path_test1)
time = ds.indexes['time'].to_datetimeindex().strftime('%m-%d-%Y')
lat  = ds.lat.values
lon  = ds.lon.values
# preallocate space for the future vectors
index_closest_lat = lat_projects
index_closest_lon = lat_projects
closest_value_lat = lat_projects
closest_value_lon = lat_projects
for j in np.arange(0,len(name_project)):
    (index_closest_lat[j], closest_value_lat[j])=closest_lat_lon_to_proj(lat_projects[j],lat)
    (index_closest_lon[j], closest_value_lon[j])=closest_lat_lon_to_proj(lon_projects[j],lon)

# %%
closest_value_lat

# %%
df = pd.DataFrame()
for i in np.arange(0,len(name_project)):
    midx = pd.MultiIndex.from_product([(name_project[i],),scenarios, models, time, (closest_value_lat[i],)],names=['Name project','Experiment', 'Model', 'Date', 'Latitude'])
    #lon_str = ('Longitude',)
    #cols = pd.MultiIndex.from_product([lon_str,closest_value_lon])
    cols = pd.MultiIndex.from_product([('Longitude',),(closest_value_lon[i],)])
    Variable_dataframe = pd.DataFrame(data = [], 
                                index = midx,
                                columns = cols)
    df = pd.concat([df,Variable_dataframe])

# %%
df

# %%
df.loc[(name_project[0],scenarios[0],models[0],time,closest_value_lat[0]),('Longitude',closest_value_lon[0])]

# %%
scenarios[0]

# %%
closest_value_lon[0]

# %%
### TEST New WAY
from FileManagement1 import information_files_in_vectors
from FileManagement1 import create_empty_dataframe
from FileManagement1 import _lat_lon
from FileManagement1 import register_data_in_dataframe
from FileManagement1 import closest_lat_lon_to_proj

# %%
start_year = 2050
stop_year = 2050
(year, year_str, index_year) = year_copernicus(2050,2050)
time = pd.date_range('01-01-2050','31-12-2050', freq='D').strftime('%d-%m-%Y').values

# %%
year

# %%
year_str

# %%
index_year

# %%
(variables, time_aggregations,models,scenarios)=information_files_in_vectors(name_list_precipitation)

# %%
type(scenarios)

# %%
path_test1 = os.path.join(out_path,'pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2050.nc')
ds =  xr.open_dataset(path_test1)

Open_path1 = Dataset(path_test1)
Open_path1.variables['pr']

# %%
ds

# %%
ds.close()

# %%
(variable, time_aggregation, model, scenario, year_file) = data_information('pr_day_TaiESM1_ssp370_r1i1p1f1_gn_2050.nc')

# %%
(index_closest_lat,index_closest_lon,closest_value_lat,closest_value_lon)=_lat_lon(path_test1,lat_projects,lon_projects)

# %%
index_closest_lat

# %%
df_test=create_empty_dataframe(pd.Series(name_project[0]),scenarios,models,time,pd.Series(closest_value_lat[0]),pd.Series(closest_value_lon[0]))

# %%
df_test

# %%
s = [scenario]

# %%
s[0]

# %%
name_variable = 'pr'
start_ = timer()
df_test_ = register_data_in_dataframe(name_list_precipitation,'day',year_str,scenarios,models,out_path, name_variable, pd.Series(name_project[0]),lon_projects,lat_projects,pd.Series(index_closest_lat[0]),pd.Series(index_closest_lon[0]),pd.Series(closest_value_lat[0]),pd.Series(closest_value_lon[0]),df_test)
end_ = timer()
print('\n')
print('Time to execute the register_data_in_dataframe: ' + str(end_ - start_)+' seconds')
print('\n')

# %%
test5=pd.Series(closest_value_lon[0])

# %%
type(test5[0])

# %%
path_csv=df_to_csv(df_test_,out_path,'TESTTTTTT_projet0_models_scenarios_2050_pr.csv',name_variable,time_aggregations[0],'2050')

# %%
type(scenarios)

# %%
for p in scenarios:
    print(p)
    print(type(p))

# %%
i=0
df_test.loc[(name_project[i],ssp245,'ACCESS-CM2',time,closest_value_lat[i]),('Longitude',closest_value_lon[i])]
