# %%
from scipy import stats
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import gumbel_r
from scipy.stats import gumbel_l
import os
import os.path
from FileManagement2 import df_to_csv

# %%
out_path = r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6'
csv_path = os.path.join(out_path,'csv_file','pr_day_2030-2040','Project_PT_Revubue_2_Rev_2_01_moz_precipitation_2030-2040.csv')
precipitation_2030_2040 = pd.read_csv(csv_path,header=[0,1],index_col=[0,1,2,3,4])#*86400 # units kg.m^(-2).s^(-1)
# convert precipitation data from kg.m^(-2).s^(-1) to mm/day :  1 kg/m2/s = 86400 mm/day
# source: https://www.researchgate.net/post/How-do-I-convert-ERA-Interim-precipitation-estimates-from-kg-m2-s-to-mm-day

# %%
precipitation_2030_2040
# Out:
#                                                                 Longitude
#                                                                    33.625
# Name project          Experiment Model      Date       Latitude
# PT_Revubue_2_Rev_2_01 ssp245     ACCESS-CM2 01-01-2030 -16.125   0.000218
#                                             02-01-2030 -16.125   0.000104
#                                             03-01-2030 -16.125   0.000121
#                                             04-01-2030 -16.125   0.000217
#                                             05-01-2030 -16.125   0.000131
# ...                                                                   ...
#                       ssp370     TaiESM1    27-12-2040 -16.125   0.000015
#                                             28-12-2040 -16.125   0.000094
#                                             29-12-2040 -16.125   0.000123
#                                             30-12-2040 -16.125   0.000181
#                                             31-12-2040 -16.125   0.000042
#
# [241080 rows x 1 columns]

# %%
# find non finite values

# %%
non_finite_index=np.where(~np.isfinite(precipitation_2030_2040))[0].tolist()
non_finite_index
# Out:
# [8825,
#  10286,
#  11747,
#  12843,
#  14304,
#  15765,
#  16861,
#  18322,
#  19783,
#  20879,
#  22340,
#  23801,
#  24108,
#  25934,
#  27760,
#  49005,
#  50466,
#  51927,
#  53023,
#  54484,
#  55945,
#  57041,
#  58502,
#  59963,
#  69095,
#  70556,
#  72017,
#  73113,
#  74574,
#  76035,
#  77131,
#  78592,
#  80053,
#  81149,
#  82610,
#  84071,
#  84378,
#  86204,
#  88030,
#  109275,
#  110736,
#  112197,
#  113293,
#  114754,
#  116215,
#  117311,
#  118772,
#  120233,
#  129365,
#  130826,
#  132287,
#  133383,
#  134844,
#  136305,
#  137401,
#  138862,
#  140323,
#  141419,
#  142880,
#  144341,
#  144648,
#  146474,
#  148300,
#  169545,
#  171006,
#  172467,
#  173563,
#  175024,
#  176485,
#  177581,
#  179042,
#  180503,
#  189635,
#  191096,
#  192557,
#  193653,
#  195114,
#  196575,
#  197671,
#  199132,
#  200593,
#  201689,
#  203150,
#  204611,
#  204918,
#  206744,
#  208570,
#  225008,
#  225009,
#  225010,
#  225011,
#  225012,
#  225013,
#  225014,
#  225015,
#  225016,
#  225017,
#  225018,
#  225019,
#  225020,
#  225021,
#  225022,
#  225023,
#  225024,
#  225025,
#  225026,
#  225027,
#  225028,
#  225029,
#  225030,
#  225031,
#  225032,
#  225033,
#  225034,
#  225035,
#  225036,
#  225037,
#  225038,
#  225039,
#  225040,
#  225041,
#  225042,
#  225043,
#  225044,
#  225045,
#  225046,
#  225047,
#  225048,
#  225049,
#  225050,
#  225051,
#  225052,
#  225053,
#  225054,
#  225055,
#  225056,
#  225057,
#  225058,
#  225059,
#  225060,
#  225061,
#  225062,
#  225063,
#  225064,
#  225065,
#  225066,
#  225067,
#  225068,
#  225069,
#  225070,
#  225071,
#  225072,
#  225073,
#  225074,
#  225075,
#  225076,
#  225077,
#  225078,
#  225079,
#  225080,
#  225081,
#  225082,
#  225083,
#  225084,
#  225085,
#  225086,
#  225087,
#  225088,
#  225089,
#  225090,
#  225091,
#  225092,
#  225093,
#  225094,
#  225095,
#  225096,
#  225097,
#  225098,
#  225099,
#  225100,
#  225101,
#  225102,
#  225103,
#  225104,
#  225105,
#  225106,
#  225107,
#  225108,
#  225109,
#  225110,
#  225111,
#  225112,
#  225113,
#  225114,
#  225115,
#  225116,
#  225117,
#  225118,
#  225119,
#  225120,
#  225121,
#  225122,
#  225123,
#  225124,
#  225125,
#  225126,
#  225127,
#  225128,
#  225129,
#  225130,
#  225131,
#  225132,
#  225133,
#  225134,
#  225135,
#  225136,
#  225137,
#  225138,
#  225139,
#  225140,
#  225141,
#  225142,
#  225143,
#  225144,
#  225145,
#  225146,
#  225147,
#  225148,
#  225149,
#  225150,
#  225151,
#  225152,
#  225153,
#  225154,
#  225155,
#  225156,
#  225157,
#  225158,
#  225159,
#  225160,
#  225161,
#  225162,
#  225163,
#  225164,
#  225165,
#  225166,
#  225167,
#  225168,
#  225169,
#  225170,
#  225171,
#  225172,
#  225173,
#  225174,
#  225175,
#  225176,
#  225177,
#  225178,
#  225179,
#  225180,
#  225181,
#  225182,
#  225183,
#  225184,
#  225185,
#  225186,
#  225187,
#  225188,
#  225189,
#  225190,
#  225191,
#  225192,
#  225193,
#  225194,
#  225195,
#  225196,
#  225197,
#  225198,
#  225199,
#  225200,
#  225201,
#  225202,
#  225203,
#  225204,
#  225205,
#  225206,
#  225207,
#  225208,
#  225209,
#  225210,
#  225211,
#  225212,
#  225213,
#  225214,
#  225215,
#  225216,
#  225217,
#  225218,
#  225219,
#  225220,
#  225221,
#  225222,
#  225223,
#  225224,
#  225225,
#  225226,
#  225227,
#  225228,
#  225229,
#  225230,
#  225231,
#  225232,
#  225233,
#  225234,
#  225235,
#  225236,
#  225237,
#  225238,
#  225239,
#  225240,
#  225241,
#  225242,
#  225243,
#  225244,
#  225245,
#  225246,
#  225247,
#  225248,
#  225249,
#  225250,
#  225251,
#  225252,
#  225253,
#  225254,
#  225255,
#  225256,
#  225257,
#  225258,
#  225259,
#  225260,
#  225261,
#  225262,
#  225263,
#  225264,
#  225265,
#  225266,
#  225267,
#  225268,
#  225269,
#  225270,
#  225271,
#  225272,
#  225273,
#  225274,
#  225275,
#  225276,
#  225277,
#  225278,
#  225279,
#  225280,
#  225281,
#  225282,
#  225283,
#  225284,
#  225285,
#  225286,
#  225287,
#  225288,
#  225289,
#  225290,
#  225291,
#  225292,
#  225293,
#  225294,
#  225295,
#  225296,
#  225297,
#  225298,
#  225299,
#  225300,
#  225301,
#  225302,
#  225303,
#  225304,
#  225305,
#  225306,
#  225307,
#  225308,
#  225309,
#  225310,
#  225311,
#  225312,
#  225313,
#  225314,
#  225315,
#  225316,
#  225317,
#  225318,
#  225319,
#  225320,
#  225321,
#  225322,
#  225323,
#  225324,
#  225325,
#  225326,
#  225327,
#  225328,
#  225329,
#  225330,
#  225331,
#  225332,
#  225333,
#  225334,
#  225335,
#  225336,
#  225337,
#  225338,
#  225339,
#  225340,
#  225341,
#  225342,
#  225343,
#  225344,
#  225345,
#  225346,
#  225347,
#  225348,
#  225349,
#  225350,
#  225351,
#  225352,
#  225353,
#  225354,
#  225355,
#  225356,
#  225357,
#  225358,
#  225359,
#  225360,
#  225361,
#  225362,
#  225363,
#  225364,
#  225365,
#  225366,
#  225367,
#  225368,
#  225369,
#  225370,
#  225371,
#  225372,
#  225373,
#  225374,
#  225375,
#  225376,
#  225377,
#  225378,
#  225379,
#  225380,
#  225381,
#  225382,
#  225383,
#  225384,
#  225385,
#  225386,
#  225387,
#  225388,
#  225389,
#  225390,
#  225391,
#  225392,
#  225393,
#  225394,
#  225395,
#  225396,
#  225397,
#  225398,
#  225399,
#  225400,
#  225401,
#  225402,
#  225403,
#  225404,
#  225405,
#  225406,
#  225407,
#  225408,
#  225409,
#  225410,
#  225411,
#  225412,
#  225413,
#  225414,
#  225415,
#  225416,
#  225417,
#  225418,
#  225419,
#  225420,
#  225421,
#  225422,
#  225423,
#  225424,
#  225425,
#  225426,
#  225427,
#  225428,
#  225429,
#  225430,
#  225431,
#  225432,
#  225433,
#  225434,
#  225435,
#  225436,
#  225437,
#  225438,
#  225439,
#  225440,
#  225441,
#  225442,
#  225443,
#  225444,
#  225445,
#  225446,
#  225447,
#  225448,
#  225449,
#  225450,
#  225451,
#  225452,
#  225453,
#  225454,
#  225455,
#  225456,
#  225457,
#  225458,
#  225459,
#  225460,
#  225461,
#  225462,
#  225463,
#  225464,
#  225465,
#  225466,
#  225467,
#  225468,
#  225469,
#  225470,
#  225471,
#  225472,
#  225473,
#  225474,
#  225475,
#  225476,
#  225477,
#  225478,
#  225479,
#  225480,
#  225481,
#  225482,
#  225483,
#  225484,
#  225485,
#  225486,
#  225487,
#  225488,
#  225489,
#  225490,
#  225491,
#  225492,
#  225493,
#  225494,
#  225495,
#  225496,
#  225497,
#  225498,
#  225499,
#  225500,
#  225501,
#  225502,
#  225503,
#  225504,
#  225505,
#  225506,
#  225507,
#  225508,
#  225509,
#  225510,
#  225511,
#  225512,
#  225513,
#  225514,
#  225515,
#  225516,
#  225517,
#  225518,
#  225519,
#  225520,
#  225521,
#  225522,
#  225523,
#  225524,
#  225525,
#  225526,
#  225527,
#  225528,
#  225529,
#  225530,
#  225531,
#  225532,
#  225533,
#  225534,
#  225535,
#  225536,
#  225537,
#  225538,
#  225539,
#  225540,
#  225541,
#  225542,
#  225543,
#  225544,
#  225545,
#  225546,
#  225547,
#  225548,
#  225549,
#  225550,
#  225551,
#  225552,
#  225553,
#  225554,
#  225555,
#  225556,
#  225557,
#  225558,
#  225559,
#  225560,
#  225561,
#  225562,
#  225563,
#  225564,
#  225565,
#  225566,
#  225567,
#  225568,
#  225569,
#  225570,
#  225571,
#  225572,
#  225573,
#  225574,
#  225575,
#  225576,
#  225577,
#  225578,
#  225579,
#  225580,
#  225581,
#  225582,
#  225583,
#  225584,
#  225585,
#  225586,
#  225587,
#  225588,
#  225589,
#  225590,
#  225591,
#  225592,
#  225593,
#  225594,
#  225595,
#  225596,
#  225597,
#  225598,
#  225599,
#  225600,
#  225601,
#  225602,
#  225603,
#  225604,
#  225605,
#  225606,
#  225607,
#  225608,
#  225609,
#  225610,
#  225611,
#  225612,
#  225613,
#  225614,
#  225615,
#  225616,
#  225617,
#  225618,
#  225619,
#  225620,
#  225621,
#  225622,
#  225623,
#  225624,
#  225625,
#  225626,
#  225627,
#  225628,
#  225629,
#  225630,
#  225631,
#  225632,
#  225633,
#  225634,
#  225635,
#  225636,
#  225637,
#  225638,
#  225639,
#  225640,
#  225641,
#  225642,
#  225643,
#  225644,
#  225645,
#  225646,
#  225647,
#  225648,
#  225649,
#  225650,
#  225651,
#  225652,
#  225653,
#  225654,
#  225655,
#  225656,
#  225657,
#  225658,
#  225659,
#  225660,
#  225661,
#  225662,
#  225663,
#  225664,
#  225665,
#  225666,
#  225667,
#  225668,
#  225669,
#  225670,
#  225671,
#  225672,
#  225673,
#  225674,
#  225675,
#  225676,
#  225677,
#  225678,
#  225679,
#  225680,
#  225681,
#  225682,
#  225683,
#  225684,
#  225685,
#  225686,
#  225687,
#  225688,
#  225689,
#  225690,
#  225691,
#  225692,
#  225693,
#  225694,
#  225695,
#  225696,
#  225697,
#  225698,
#  225699,
#  225700,
#  225701,
#  225702,
#  225703,
#  225704,
#  225705,
#  225706,
#  225707,
#  225708,
#  225709,
#  225710,
#  225711,
#  225712,
#  225713,
#  225714,
#  225715,
#  225716,
#  225717,
#  225718,
#  225719,
#  225720,
#  225721,
#  225722,
#  225723,
#  225724,
#  225725,
#  225726,
#  225727,
#  225728,
#  225729,
#  225730,
#  225731,
#  225732,
#  225733,
#  225734,
#  225735,
#  225736,
#  225737,
#  225738,
#  225739,
#  225740,
#  225741,
#  225742,
#  225743,
#  225744,
#  225745,
#  225746,
#  225747,
#  225748,
#  225749,
#  225750,
#  225751,
#  225752,
#  225753,
#  225754,
#  225755,
#  225756,
#  225757,
#  225758,
#  225759,
#  225760,
#  225761,
#  225762,
#  225763,
#  225764,
#  225765,
#  225766,
#  225767,
#  225768,
#  225769,
#  225770,
#  225771,
#  225772,
#  225773,
#  225774,
#  225775,
#  225776,
#  225777,
#  225778,
#  225779,
#  225780,
#  225781,
#  225782,
#  225783,
#  225784,
#  225785,
#  225786,
#  225787,
#  225788,
#  225789,
#  225790,
#  225791,
#  225792,
#  225793,
#  225794,
#  225795,
#  225796,
#  225797,
#  225798,
#  225799,
#  225800,
#  225801,
#  225802,
#  225803,
#  225804,
#  225805,
#  225806,
#  225807,
#  225808,
#  225809,
#  225810,
#  225811,
#  225812,
#  225813,
#  225814,
#  225815,
#  225816,
#  225817,
#  225818,
#  225819,
#  225820,
#  225821,
#  225822,
#  225823,
#  225824,
#  225825,
#  225826,
#  225827,
#  225828,
#  225829,
#  225830,
#  225831,
#  225832,
#  225833,
#  225834,
#  225835,
#  225836,
#  225837,
#  225838,
#  225839,
#  225840,
#  225841,
#  225842,
#  225843,
#  225844,
#  225845,
#  225846,
#  225847,
#  225848,
#  225849,
#  225850,
#  225851,
#  225852,
#  225853,
#  225854,
#  225855,
#  225856,
#  225857,
#  225858,
#  225859,
#  225860,
#  225861,
#  225862,
#  225863,
#  225864,
#  225865,
#  225866,
#  225867,
#  225868,
#  225869,
#  225870,
#  225871,
#  225872,
#  225873,
#  225874,
#  225875,
#  225876,
#  225877,
#  225878,
#  225879,
#  225880,
#  225881,
#  225882,
#  225883,
#  225884,
#  225885,
#  225886,
#  225887,
#  225888,
#  225889,
#  225890,
#  225891,
#  225892,
#  225893,
#  225894,
#  225895,
#  225896,
#  225897,
#  225898,
#  225899,
#  225900,
#  225901,
#  225902,
#  225903,
#  225904,
#  225905,
#  225906,
#  225907,
#  225908,
#  225909,
#  225910,
#  225911,
#  225912,
#  225913,
#  225914,
#  225915,
#  225916,
#  225917,
#  225918,
#  225919,
#  225920,
#  ...]

# %%
df_non_finite=precipitation_2030_2040.iloc[non_finite_index]
df_non_finite
# Out:
#                                                                  Longitude
#                                                                     33.625
# Name project          Experiment Model       Date       Latitude
# PT_Revubue_2_Rev_2_01 ssp245     BCC-CSM2-MR 29-02-2032 -16.125        NaN
#                                              29-02-2036 -16.125        NaN
#                                              29-02-2040 -16.125        NaN
#                                  CanESM5     29-02-2032 -16.125        NaN
#                                              29-02-2036 -16.125        NaN
# ...                                                                    ...
#                       ssp370     NorESM2-MM  29-02-2036 -16.125        NaN
#                                              29-02-2040 -16.125        NaN
#                                  TaiESM1     29-02-2032 -16.125        NaN
#                                              29-02-2036 -16.125        NaN
#                                              29-02-2040 -16.125        NaN
#
# [4114 rows x 1 columns]

# %%
models_to_delete = []
for i in (np.arange(0,len(df_non_finite.index.tolist())-1)):
    if df_non_finite.index.tolist()[i][2] not in models_to_delete:
        models_to_delete.append(df_non_finite.index.tolist()[i][2])

# %%
models_to_delete
# Out:
# ['BCC-CSM2-MR',
#  'CanESM5',
#  'CMCC-CM2-SR5',
#  'CMCC-ESM2',
#  'IITM-ESM',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'TaiESM1',
#  'NESM3']

# %%
precipitation_2030_2040.shape
# Out:
# (241080, 1)

# %%
precipitation_2030_2040_no_NaN = precipitation_2030_2040.drop(models_to_delete,level=2)

# %%
precipitation_2030_2040_no_NaN.shape
# Out:
# (96432, 1)

# %%
precipitation_2030_2040_no_NaN.index.levels[2].tolist()
# Out:
# ['ACCESS-CM2',
#  'ACCESS-ESM1-5',
#  'BCC-CSM2-MR',
#  'CMCC-CM2-SR5',
#  'CMCC-ESM2',
#  'CanESM5',
#  'IITM-ESM',
#  'MIROC6',
#  'MPI-ESM1-2-HR',
#  'MPI-ESM1-2-LR',
#  'MRI-ESM2-0',
#  'NESM3',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'TaiESM1']

# %%
new_index_models=[]
for item in precipitation_2030_2040.index.levels[2].tolist():
    if item in models_to_delete:
        continue
    else:
        new_index_models.append(item)

# %%
type(new_index_models)
# Out:
# list

# %%
new_index_models
# Out:
# ['ACCESS-CM2',
#  'ACCESS-ESM1-5',
#  'MIROC6',
#  'MPI-ESM1-2-HR',
#  'MPI-ESM1-2-LR',
#  'MRI-ESM2-0']

# %%
time_2030_2040=pd.date_range('01-01-2030','31-12-2040', freq='D').strftime('%d-%m-%Y').values.tolist()
list_time_2030_2040= [item[3:10] for item in time_2030_2040]

# %%
df = pd.DataFrame()
midx = pd.MultiIndex.from_product([[precipitation_2030_2040_no_NaN.index.levels[0].tolist()[0],],precipitation_2030_2040_no_NaN.index.levels[1].tolist(), new_index_models, list_time_2030_2040],names=['Name project','Experiment', 'Model', 'Month and year'])
cols = pd.MultiIndex.from_product([('Precipitation mm/day',)])
Variable_dataframe = pd.DataFrame(data = precipitation_2030_2040_no_NaN.values*86400, 
                            index = midx,
                            columns = cols)
df = pd.concat([df,Variable_dataframe])
df['year']=df.reset_index()['Month and year'].apply(lambda k: int(k.split('-')[1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 8
#       4 Variable_dataframe = pd.DataFrame(data = precipitation_2030_2040_no_NaN.values*86400,
#       5                             index = midx,
#       6                             columns = cols)
#       7 df = pd.concat([df,Variable_dataframe])
# ----> 8 df['year']=df.reset_index()['Month and year'].apply(lambda k: int(k.split('-')[1]),axis=1).values
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[91], line 8, in <lambda>(k)
#       4 Variable_dataframe = pd.DataFrame(data = precipitation_2030_2040_no_NaN.values*86400,
#       5                             index = midx,
#       6                             columns = cols)
#       7 df = pd.concat([df,Variable_dataframe])
# ----> 8 df['year']=df.reset_index()['Month and year'].apply(lambda k: int(k.split('-')[1]),axis=1).values
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
a=df.reset_index()
a['year']=a['Month and year'].apply(lambda k: int(k.split('-')[1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 2
#       1 a=df.reset_index()
# ----> 2 a['year']=a['Month and year'].apply(lambda k: int(k.split('-')[1]))
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[103], line 2, in <lambda>(k)
#       1 a=df.reset_index()
# ----> 2 a['year']=a['Month and year'].apply(lambda k: int(k.split('-')[1]))
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df_max_month_2030_2040=df.groupby(['Name project','Experiment', 'Model', 'Month and year']).max() # .sum() to count the number of true and false

# %%
df_max_month_2030_2040
# Out:
#                                                            Precipitation mm/day
# Name project          Experiment Model      Month and year
# PT_Revubue_2_Rev_2_01 ssp126     ACCESS-CM2 01-2030                   28.500094
#                                             01-2031                   26.094935
#                                             01-2032                   22.877599
#                                             01-2033                   17.736608
#                                             01-2034                   22.220564
# ...                                                                         ...
#                       ssp585     MRI-ESM2-0 12-2036                   35.560444
#                                             12-2037                   13.130333
#                                             12-2038                   13.935345
#                                             12-2039                   12.010463
#                                             12-2040                   19.539956
#
# [3168 rows x 1 columns]

# %%
df_max_month_2030_2040_ssp126_ACCESS_CM2 = df_max_month_2030_2040.loc[('PT_Revubue_2_Rev_2_01','ssp126','ACCESS-CM2')]

# %%
df_max_month_2030_2040_ssp126_ACCESS_CM2
# Out:
#                Precipitation mm/day
# Month and year
# 01-2030                   28.500094
# 01-2031                   26.094935
# 01-2032                   22.877599
# 01-2033                   17.736608
# 01-2034                   22.220564
# ...                             ...
# 12-2036                   19.006146
# 12-2037                   17.778331
# 12-2038                   22.223846
# 12-2039                   19.395542
# 12-2040                   20.819816
#
# [132 rows x 1 columns]

# %%
plt.plot(df_max_month_2030_2040_ssp126_ACCESS_CM2.values)

# %%
Z = df_max_month_2030_2040_ssp126_ACCESS_CM2.values.reshape(132)/len(df_max_month_2030_2040_ssp126_ACCESS_CM2.values.reshape(132))
Z1 = df_max_month_2030_2040_ssp126_ACCESS_CM2.values.reshape(132).tolist()
Z = Z.tolist()
Z.sort()
Z1.sort()

# %%
print(Z)
# Out:
# [0.0, 0.0, 0.0, 0.0, 0.00018342904736941406, 0.00021669135838403073, 0.0002701771315762678, 0.0003066574973590005, 0.0005202048421117731, 0.0005741141938580603, 0.0005904301071330502, 0.0006873470903718209, 0.0008943232470218472, 0.0009069888206299352, 0.0012223749680825592, 0.0013722130957334725, 0.0014343582403274593, 0.0015369293991666796, 0.00202290104260266, 0.0022374892234273084, 0.002337114363564813, 0.0023424054399418474, 0.0024184134665781384, 0.0024456302443550985, 0.0024554664791635746, 0.0025700352787019006, 0.0026444583041170104, 0.0029456570535496053, 0.0031224515127674254, 0.0031392956853696064, 0.0032708632881456815, 0.00343920321690596, 0.0035032694127452983, 0.0037327591350979424, 0.004033483128296211, 0.004517783897674896, 0.004864925358560868, 0.004986181077335707, 0.005476657547247173, 0.005733496800530702, 0.005932223509510302, 0.00604184546814808, 0.006258148575646126, 0.006421076580987905, 0.006515959963011978, 0.006566319842187857, 0.007142341134815731, 0.0075551760594614525, 0.00768163564233956, 0.00797447957500646, 0.008901215055216613, 0.009495908108709213, 0.00968479560635222, 0.00984261588944884, 0.010847537619569763, 0.010922918789385056, 0.010971574308562347, 0.01105314308502288, 0.01161518541101197, 0.011837268936109136, 0.011918515056922017, 0.012788322055712342, 0.013818290079308843, 0.01841356848176061, 0.019726746011821724, 0.021444977822036228, 0.02439820091240108, 0.0257549929136241, 0.02657575268213722, 0.027489380127835004, 0.02853906348305331, 0.037262276799248706, 0.037262555402280254, 0.0375971624056216, 0.03976255565331402, 0.04030903907154094, 0.04076543369923125, 0.04645308363251388, 0.04825569287111813, 0.04972797416319901, 0.05327452884309671, 0.054206677437336606, 0.05613558195446702, 0.06645673367358546, 0.06947678101077819, 0.07419196825304727, 0.07715073721058181, 0.0864963354118909, 0.09702247228808727, 0.09838141691445818, 0.09959899312387636, 0.1001731439662691, 0.10031839853825456, 0.11309835297816001, 0.11510886675253092, 0.11520615397863274, 0.11655613568356364, 0.12864106842735273, 0.12975477571171637, 0.12990022078156363, 0.1319738083772727, 0.13294062280852365, 0.13436824189156363, 0.13456468322227635, 0.13468432536517091, 0.13704405970529454, 0.13829251560800726, 0.13892843536180366, 0.1410602295601309, 0.14226496621795637, 0.14286707261234183, 0.14369207095688727, 0.14397550310768728, 0.1439859519119782, 0.14693592463363636, 0.1475104564715564, 0.14933896864848, 0.15772588191209455, 0.16317048999056727, 0.1681792105293818, 0.16833760944951276, 0.16836246941236366, 0.16869645015421092, 0.17123919573017457, 0.17163004006512003, 0.17331514549861088, 0.17565720164299636, 0.17746854996816, 0.1821693879636218, 0.1976889007809164, 0.21100915460421818, 0.21590980574144725]

# %%
plt.plot(np.arange(0,len(np.sort(Z))),Z)

# %%
non_finite_index2=np.where(~np.isfinite(df_max_month_2030_2040_ssp126_ACCESS_CM2))[0].tolist()
non_finite_index2
# Out:
# []

# %%
(loc,scale)=stats.gumbel_r.fit(Z1) # renvoie les deux parametres necessaire pour etablir la fonction continue
loc
# Out:
# 3.878624004222221

# %%
scale
# Out:
# 6.051699560443534

# %%
max(gumbel_r.pdf(Z,loc,scale))
# Out:
# 0.04847104575782623

# %%
x = 100
gumbel_r.pdf(x,loc,scale)
# Out:
# 2.089600008346823e-08

# %%
p = 0.995 # percentile of non-exceedance
print('For a return period '+str(round((1/(1-p))))+' years')
gumbel_r.ppf(p,loc,scale) # Percent point function
# Out:
# For a return period 200 years
# 35.92728801939296

# %%
p = 0.99 # percentile of non-exceedance
print('For a return period '+str(round((1/(1-p))))+' years')
gumbel_r.ppf(p,loc,scale) # Percent point function
# Out:
# For a return period 100 years
# 31.71734505788071

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(Z1,gumbel_r.pdf(Z1))

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(Z1,gumbel_r.pdf((Z1-loc)/scale) / scale)

# %%
# xaxis is precipitation and yaxis is densiy of probability
myHist = plt.hist(Z1,density=True)
h = plt.plot(Z1,gumbel_l.pdf(Z1,loc,scale))
plt.show()

# %%
# need to find which law to apply when
