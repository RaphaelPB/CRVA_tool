# %% [markdown]
# # Test downscaling

# %%
#Import python packages
from rasterstats import zonal_stats
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.plot import show
import rioxarray #used when calling ncdata.rio.write_crs
import xarray as xr
import os
import os.path
import matplotlib.pyplot as plt
import netCDF4 as nc#not directly used but needs to be imported for some nc4 files manipulations, use for nc files
from netCDF4 import Dataset
import csv #REMOVE ? not in use ?
import numpy as np
import numpy.ma as ma
from mpl_toolkits.basemap import Basemap
import shutil # to move folders
import warnings
warnings.filterwarnings('ignore') # to ignore the warnings
#import io
import cdsapi # for copernicus function
import datetime # to have actual date
from osgeo import gdal, ogr, osr # in order to convert shp in raster
from geopandas import GeoDataFrame
from shapely.geometry import Point
from matplotlib.lines import Line2D

from FunctionsAndClass import read_cckp_ncdata
from FunctionsAndClass import get_cckp_file_name
from FileManagement import read_nc_file
from FileManagement import time_vector_conversion

#project locations (shapefile with location of elements to evaluate)
data_folder=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets'
#data_folder=os.path.join(os.pardir,'dataset')
project_location_path=os.path.join(data_folder,'Mozambique_PPIS/EIB_locations_few.shp')
project_id='Name' #name of column used as id

#study boundary (optional)
study_area_path=os.path.join(data_folder,'Mozambique_PPIS/mozambique.shp')

#output folder
#out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Scripts\outputs'
out_path=r'C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\outputs'
out_path_database=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets'
#projection CRS (default = 'EPSG:4326')
bCRS='EPSG:4326'

#buffer for climate/grid variables
buffer=40000 #buffer in meters, 0 = no buffer is computed

mCRS='EPSG:31983' #metric CRS for buffer in meters (find relevant metric CRS for location!)
# Out:
# C:\Users\CLMRX\AppData\Local\Temp\1\ipykernel_201788\1264531973.py:4: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# #### Pointwise models

# %%
# importing librairies and setting up
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")  # sklearn

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

from utils import get_sample_data

sns.set(style='darkgrid')

# %%
## load project information

#load shapefiles
projects = gpd.read_file(project_location_path).to_crs(bCRS)
study_area = gpd.read_file(study_area_path).to_crs(bCRS)

#calculate buffer around points/shape
if buffer != 0:
    projects_buf=projects.to_crs(mCRS)  #project to crs with metric units to get buffer in meters
    projects_buf['geometry']=projects.to_crs(mCRS).buffer(buffer) #assign the buffer as the new geometry - 
    projects_buf=projects_buf.to_crs(bCRS)#project back to orginal crs

    
#plot shapefiles
study_area.plot()
projects.plot()
projects_buf.plot() 


#show table
projects[[project_id]]

# register geographic information concerning projects
lon_projects = projects['geometry'].x
lat_projects = projects['geometry'].y
area_projects = [lat_projects - 5, lat_projects+5, lon_projects-5,lon_projects+5] # list format
# 5 degres trop grand 
#### determination of the geographical zone of interest 
lat_min_wanted = min(study_area['LAT'])-10
lat_max_wanted = max(study_area['LAT'])+10
lon_min_wanted = min(study_area['LON'])-20
lon_max_wanted = max(study_area['LON'])+20
# addind and substracting to lon and lat to have margin
# substracting more to longitude because the range of longitude is -180 to 180. The range of latitude is -90 to 90

area = [lat_min_wanted, lon_min_wanted, lat_max_wanted,lon_max_wanted,] # used to download from copernicus

### YEAR
first_year = 2025 # start year included
last_year = 2026 # last year included

year = np.arange(first_year,(last_year+1),1) # create vector of years
year_str = [0]*len(year) # create initiale empty vector to convert years in int
index = np.arange(0,len(year)) # create vector of index for year
i = 0 # initialize index
for i in index: # convert all the date in string format
    year_str[i]=str(year[i])

start_date = "01-01-"+year_str[0] # string start date based on start year
stop_date = "31-12-"+year_str[len(year)-1] # string stop date based on stop year
dates = pd.date_range(start_date,stop_date) # vector of dates between start date and stop date
index_dates = np.arange(0,len(dates)) # vector containning index o dates vector

# %% [markdown]
# ## Upload data observation and correction

# %% [markdown]
# ### Data to correct

# %%
path_train=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\temperature\Copernicus-CMIP6\daily_maximum_near_surface_air_temperature\PT_Revubue2(Rev201)\historical-1950-2014\monthly\download\tasmax_Amon_EC-Earth3-CC_historical_r1i1p1f1_gr_19500116-20141216_v20210113.nc'
(lat_train, lon_train, time_train, tasmax_train) = read_nc_file(path_train)
tasmax_train = tasmax_train -273.15 # convert tasmax from Kelvin to celsius degrees
time_str_train = time_vector_conversion(path_train,'monthly')
data_structure_train = xr.DataArray(tasmax_train, coords=[time_str_train,np.around(lat_train.astype('float32'),2),np.around(lon_train.astype('float32'),2)], dims=['time', 'lat','lon'])

# %%
data_structure_train_2014_project1=data_structure_train.loc['2014-01':'2014-12',:,:]

# %%
len(np.around(lat_train.astype('float32'),2))
# Out:
# 71

# %% [markdown]
# ### Observation data

# %%
# Observation data 
# from copernicus CRU, tasmax in degrees Celsius
#obs = Dataset(r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\Observations\temperature\global\1950-2019\monthly\0_5_x_0_5\cru\v4.03\CRU_maximum_temperature_mon_0.5x0.5_global_1950_v4.03.nc')
path_obs =r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\Observations\temperature\global\1950-2019\monthly\0_5_x_0_5\cru\v4.03\CRU_maximum_temperature_mon_0.5x0.5_global_2014_v4.03.nc'

# %%
# read data
(lat_obs, lon_obs, time_obs, tasmax_obs) = read_nc_file(path_obs)
time_str_obs = time_vector_conversion(path_obs,'daily')
# data for the whole world for the year 2014
data_structure_obs = xr.DataArray(tasmax_obs, coords=[time_str_obs,lat_obs,lon_obs], dims=['time', 'lat','lon'])

# %%
lat_obs_project1=lat_obs[lat_obs>min(lat_train)]
lat_obs_project1=lat_obs_project1[lat_obs_project1<max(lat_train)]
lon_obs_project1=lon_obs[lon_obs>min(lon_train)]
lon_obs_project1=lon_obs_project1[lon_obs_project1<max(lon_train)]

# %%
data_structure_obs_2014_project1=data_structure_obs.loc[:,lat_obs_project1,lon_obs_project1]

# %%
len(lon_obs_project1)
# Out:
# 98

# %%
## FILLVALUE, Not working

from netCDF4 import Dataset
data = Dataset(path)
data.variables['tasmax']._FillValue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 ## FILLVALUE, Not working
#       3 from netCDF4 import Dataset
# ----> 4 data = Dataset(path)
#       5 data.variables['tasmax']._FillValue
#
# NameError: name 'path' is not defined

# %%
data.variables['tasmax']

# %%
# data to correct
path_train_data=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\temperature\Copernicus-CMIP6\daily_maximum_near_surface_air_temperature\PT_Revubue2(Rev201)\historical-1950-2014\monthly\tasmax_Amon_EC-Earth3-CC_historical_r1i1p1f1_gr_19500116-20141216_v20210113.nc'
(lat_train, lon_train, time_train, tasmax_train)  = read_nc_file(path_train_data)

# %%
Dataset(path_train_data)

# %%
os.path.isdir(path_train_data)

# %%
# dans 
# partie 1, BC
# partie 2, downscaling
# ligne les plus importante pour downscaling 

# on les donnees, on peut y aller. obs ceux de l'exemple ou bien copernicus. a corriger temp CMIP6 
from skdownscale.pointwise_models import PointWiseDownscaler # importation fonctionne
from skdownscale.pointwise_models import BcsdTemperature, BcsdPrecipitation # importation fonctionne
#from dask.diagnostics import ProgressBar

model = PointWiseDownscaler(BcsdTemperature(return_anoms=False)) # fonctioonne
model
#model.fit(data_structure_train_2014_project1, data_structure_obs_2014_project1) # train subset and obs_subset are xarray.DataArray 'tasmax'
#display(model, model._models)
# Out:
# <skdownscale.PointWiseDownscaler>
#   Fit Status: False
#   Model:
#     BcsdTemperature(return_anoms=False)

# %%
predicted = model.predict(data_structure_train_2014_project1).load()
display(predicted)
predicted.isel(time=0).plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 predicted = model.predict(data_structure_train_2014_project1).load()
#       2 display(predicted)
#       3 predicted.isel(time=0).plot()
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\skdownscale\pointwise_models\core.py:301, in PointWiseDownscaler.predict(self, X, **kwargs)
#     297     return xr.map_blocks(
#     298         _predict_wrapper, X, args=[self._models], kwargs=kws, template=template
#     299     )
#     300 else:
# --> 301     return _predict_wrapper(X, self._models, **kws)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\skdownscale\pointwise_models\core.py:111, in _predict_wrapper(X, models, along_dim, feature_dim, n_outputs, output_names, **kwargs)
#     108     y = y.expand_dims(**{feature_dim: output_names}, axis=1).copy()
#     109     y = y.transpose(along_dim, feature_dim, ...)
# --> 111 for index, model in xenumerate(models):
#     112     if model.item():
#     113         xdf = X[index].pipe(_da_to_df, feature_dim)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\skdownscale\pointwise_models\core.py:28, in xenumerate(arr)
#      12 """
#      13 Multidimensional index iterator for xarray objects
#      14
#    (...)
#      24 numpy.ndenumerate
#      25 """
#      27 for index, _ in np.ndenumerate(arr):
# ---> 28     xindex = dict(zip(arr.dims, index))
#      29     yield xindex, arr.isel(**xindex)
#
# AttributeError: 'NoneType' object has no attribute 'dims'

# %%
type(data_structure_train_2014_project1)
# Out:
# xarray.core.dataarray.DataArray

# %%
type(model)
# Out:
# skdownscale.pointwise_models.core.PointWiseDownscaler

# %%
# ne fonctionne pas car il faut entrainer le model et il faut faire ca avec des set de data des dimensions similaire
# test avec ce qu'ils font dans le code d'origine

# %%
# parameters
train_slice = slice('1980', '1982')  # train time range
holdout_slice = slice('1990', '1991')  # prediction time range

# bounding box of downscaling region
lon_slice = slice(lon_min_wanted, lon_max_wanted) 
lat_slice = slice(lat_min_wanted, lat_max_wanted)

# chunk shape for dask execution (time must be contiguous, ie -1)
chunks = {'lat': 10, 'lon': 10, 'time': -1}

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:49865' processes=4 threads=8, memory=15.71 GiB>

# %%
import xarray as xr

fnames = [f'http://thredds.northwestknowledge.net:8080/thredds/dodsC/MET/tmmx/tmmx_{year}.nc'
          for year in range(int(train_slice.start), int(train_slice.stop) + 1)]
# open the data and cleanup a bit of metadata
obs = xr.open_mfdataset(fnames, engine='pydap', concat_dim='day',combine = 'nested').rename({'day': 'time'}).drop('crs')
# added combine = 'nested'

### PROBLEM: does not work, because of URL, not valid anymore

obs_subset = obs['air_temperature'].sel(time=train_slice, lon=lon_slice, lat=lat_slice).resample(time='1d').mean().load(scheduler='threads').chunk(chunks)

# display
display(obs_subset)
obs_subset.isel(time=0).plot()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 # open the data and cleanup a bit of metadata
#       6 obs = xr.open_mfdataset(fnames, engine='pydap', concat_dim='day',combine = 'nested').rename({'day': 'time'}).drop('crs')
# ----> 8 obs_subset = obs['air_temperature'].sel(time=train_slice, lon=lon_slice, lat=lat_slice).resample(time='1d').mean().load(scheduler='threads').chunk(chunks)
#      10 # display
#      11 display(obs_subset)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\dataarray.py:1065, in DataArray.load(self, **kwargs)
#    1047 def load(self: T_DataArray, **kwargs) -> T_DataArray:
#    1048     """Manually trigger loading of this array's data from disk or a
#    1049     remote source into memory and return this array.
#    1050
#    (...)
#    1063     dask.compute
#    1064     """
# -> 1065     ds = self._to_temp_dataset().load(**kwargs)
#    1066     new = self._from_temp_dataset(ds)
#    1067     self._variable = new._variable
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\dataset.py:738, in Dataset.load(self, **kwargs)
#     735 import dask.array as da
#     737 # evaluate all the dask arrays simultaneously
# --> 738 evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     740 for k, data in zip(lazy_data, evaluated_data):
#     741     self.variables[k].data = data
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\dask\array\core.py:126, in getter(a, b, asarray, lock)
#     121     # Below we special-case `np.matrix` to force a conversion to
#     122     # `np.ndarray` and preserve original Dask behavior for `getter`,
#     123     # as for all purposes `np.matrix` is array-like and thus
#     124     # `is_arraylike` evaluates to `True` in that case.
#     125     if asarray and (not is_arraylike(c) or isinstance(c, np.matrix)):
# --> 126         c = np.asarray(c)
#     127 finally:
#     128     if lock:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\indexing.py:459, in ImplicitToExplicitIndexingAdapter.__array__(self, dtype)
#     458 def __array__(self, dtype=None):
# --> 459     return np.asarray(self.array, dtype=dtype)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\indexing.py:623, in CopyOnWriteArray.__array__(self, dtype)
#     622 def __array__(self, dtype=None):
# --> 623     return np.asarray(self.array, dtype=dtype)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\indexing.py:524, in LazilyIndexedArray.__array__(self, dtype)
#     522 def __array__(self, dtype=None):
#     523     array = as_indexable(self.array)
# --> 524     return np.asarray(array[self.key], dtype=None)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\coding\variables.py:72, in _ElementwiseFunctionArray.__array__(self, dtype)
#      71 def __array__(self, dtype=None):
# ---> 72     return self.func(self.array)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\coding\variables.py:219, in _scale_offset_decoding(data, scale_factor, add_offset, dtype)
#     218 def _scale_offset_decoding(data, scale_factor, add_offset, dtype):
# --> 219     data = np.array(data, dtype=dtype, copy=True)
#     220     if scale_factor is not None:
#     221         data *= scale_factor
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\coding\variables.py:72, in _ElementwiseFunctionArray.__array__(self, dtype)
#      71 def __array__(self, dtype=None):
# ---> 72     return self.func(self.array)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\coding\variables.py:139, in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     135 def _apply_mask(
#     136     data: np.ndarray, encoded_fill_values: list, decoded_fill_value: Any, dtype: Any
#     137 ) -> np.ndarray:
#     138     """Mask all matching values in a NumPy arrays."""
# --> 139     data = np.asarray(data, dtype=dtype)
#     140     condition = False
#     141     for fv in encoded_fill_values:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\indexing.py:524, in LazilyIndexedArray.__array__(self, dtype)
#     522 def __array__(self, dtype=None):
#     523     array = as_indexable(self.array)
# --> 524     return np.asarray(array[self.key], dtype=None)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\backends\pydap_.py:40, in PydapArrayWrapper.__getitem__(self, key)
#      39 def __getitem__(self, key):
# ---> 40     return indexing.explicit_indexing_adapter(
#      41         key, self.shape, indexing.IndexingSupport.BASIC, self._getitem
#      42     )
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\core\indexing.py:815, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     793 """Support explicit indexing by delegating to a raw indexing method.
#     794
#     795 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     812 Indexing result, in the form of a duck numpy-array.
#     813 """
#     814 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 815 result = raw_indexing_method(raw_key.tuple)
#     816 if numpy_indices.tuple:
#     817     # index the loaded np.ndarray
#     818     result = NumpyIndexingAdapter(np.asarray(result))[numpy_indices]
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\backends\pydap_.py:48, in PydapArrayWrapper._getitem(self, key)
#      44 def _getitem(self, key):
#      45     # pull the data from the array attribute if possible, to avoid
#      46     # downloading coordinate data twice
#      47     array = getattr(self.array, "array", self.array)
# ---> 48     result = robust_getitem(array, key, catch=ValueError)
#      49     # in some cases, pydap doesn't squeeze axes automatically like numpy
#      50     axis = tuple(n for n, k in enumerate(key) if isinstance(k, integer_types))
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\xarray\backends\common.py:69, in robust_getitem(array, key, catch, max_retries, initial_delay)
#      67 for n in range(max_retries + 1):
#      68     try:
# ---> 69         return array[key]
#      70     except catch:
#      71         if n == max_retries:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pydap\model.py:324, in BaseType.__getitem__(self, index)
#     322 def __getitem__(self, index):
#     323     out = copy.copy(self)
# --> 324     out.data = self._get_data_index(index)
#     325     if type(self.data).__name__ == 'BaseProxyDap4':
#     326         out.attributes['checksum'] = self.data.checksum
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pydap\model.py:355, in BaseType._get_data_index(self, index)
#     353     return np.vectorize(decode_np_strings)(self._data[index])
#     354 else:
# --> 355     return self._data[index]
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pydap\handlers\dap.py:247, in BaseProxyDap2.__getitem__(self, index)
#     244 logger.info("Fetching URL: %s" % url)
#     245 r = pydap.net.GET(url, self.application, self.session, timeout=self.timeout, verify=self.verify)
# --> 247 pydap.net.raise_for_status(r)
#     248 dds, data = safe_dds_and_data(r, self.user_charset)
#     250 # Parse received dataset:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\pydap\net.py:38, in raise_for_status(response)
#      35 def raise_for_status(response):
#      36     # Raise error if status is above 300:
#      37     if response.status_code >= 400:
# ---> 38         raise HTTPError(
#      39             detail=response.status+'\n'+response.text,
#      40             headers=response.headers,
#      41             comment=response.body
#      42         )
#      43     elif response.status_code >= 300:
#      44         try:
#
# HTTPError: 400 Bad Request
# Error {
#     code = 5;
#     message = "Illegal index for range last index";
# };

# %%
# use datat of PANGEO ?? que acces payant

# %%
 # essayer de rouver des donnes avce la meme resolution
    # pour le model, piste ERA 5 a comparer avec autre, il faut la meme resolution
