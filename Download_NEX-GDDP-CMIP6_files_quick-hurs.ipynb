# %% [markdown]
# # User input

# %%
variable_of_interest = 'hurs' # need hurs, rsds, sfcWind
temporal_resolution = 'day'

start_year = 1950
stop_year = 2100

# zone of interest in Mozambique
# negative latitude is southern hemisphere, latitude is horizontal, longitude is vertical
#min_lat_zone_interest = -20
#max_lat_zone_interest = -10
#min_lon_zone_interest = 30
#max_lon_zone_interest = 42

# %% [markdown]
# # Import Packages

# %%
import requests
import pandas as pd

import os
import os.path

from netCDF4 import Dataset

import numpy as np
import numpy.ma as ma

import multiprocessing as mp# to download several file in parrallel
from multiprocessing.pool import ThreadPool

# %% [markdown]
# # Define Functions

# %%
# function to extract the name of the file from its url
# the imput is an url
def extract_name_file(url):
    index_before_name=url.rfind('/') # returns the highest index where the last character '/' was found, which is just before the name of the file    
    #index_end_name=url.rfind('?') # returns the lowest index where the character '?' was found, which is just after the name of the file    
    name = url[index_before_name+1:len(url)] # return the name of the file as a string, with the suffix '.nc'
    return name

# function 'produce_name_list' produce a list of files' name, with the suffix '.nc'
# 'produce_name_list' use the function 'extract_name_file' to have the name of a file from its url
# the input is a list of url, from which we want to extract the corresponding names of files
def produce_name_list(url_list):
    name_list=[] # create empty list
    for file in url_list:
        f_name = extract_name_file(file) # return the name of the file as a string, with the suffix '.nc'
        name_list.append(f_name) # add extracted name in the list
    return name_list # return the list of names in the url_list

# %%
# function download_file download the file in the url given as input
# the input is an url of a file
def download_file(file):
    out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6' 
    # find the name of the file
    f_name = extract_name_file(file) # return the name of the file as a string, with the suffix '.nc' at the end of the name
    print('\nName of the file: '+f_name)
    if os.path.join(out_path,f_name):
        print('The file '+f_name+' exists')
        if test_open_file(os.path.join(out_path,f_name))==[]:
        # the file exists and is not corrupted
            return print('The file '+f_name+' is not corrupted')# will return None when used in 
    print('The file '+f_name+' must be requested')
    #connect_timeout = 1000 # time in seconds, the timeout for establishing a connection to the server. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "connect" key to the desired timeout value:
    #read_timeout = 1000000 # time in seconds, the timeout for waiting for a response from the server after the connection has been established. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "read" key to the desired timeout value:
    
    r = requests.get(file)#, timeout=(connect_timeout, read_timeout)) # return the url were data need to be downloaded
    # download data in the servor for datasets
    with open(f'//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/{f_name}', 'wb') as f:
        f.write(r.content)
    
    while test_open_file(os.path.join(out_path,f_name))!=[]: # test if download file is corrupted
        print('\nFile '+f_name+' did not open')
        
        #connect_timeout = 1 # time in seconds, the timeout for establishing a connection to the server. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "connect" key to the desired timeout value:
        #read_timeout = 1000 # time in seconds, the timeout for waiting for a response from the server after the connection has been established. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "read" key to the desired timeout value:

        r = requests.get(file)#, timeout=(connect_timeout, read_timeout)) # return the url were data need to be downloaded
        # download data in the servor for datasets
        with open(f'//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/{f_name}', 'wb') as f:
            f.write(r.content)
    
    print('\nFile '+f_name+' did open')
    
    return file

# %%
# function 'list_name_corrupted_file' aims to return a list of names, corresponding to the names of the corrupted files
# in the name_list given as input
def list_name_corrupted_file(name_list,out_path):
    ## Hypothesis: some files are corrupted
    # check if files are corrupted and count the corrupted ones
    invalid_files = [] # create an empty list to register the names of the corrupted files
    for name in name_list:
        if not name.endswith('.nc'):
            name = name + '.nc'
        if test_open_file(os.path.join(out_path,name))!=[]:
            invalid_files.append(name) # register name of the corrupted files
    return invalid_files # return a list of names, with suffix '.nc', of corrupted files

# %%
def test_open_file(path):
    try:
        im = Dataset(path)
        name = []
        im.close()
    except (IOError, OSError):
        # the files is corrupted
        name = extract_name_file(path) # return the name of the file as a string, with the suffix '.nc'
    return name

# %%
# list urls that should be downloaded again
def url_to_download_again(url_list,invalid_files):
    url_corrupted_file = []
    for url in url_list:
        f_name = extract_name_file(url) # return the name of the file as a string
        if f_name in invalid_files:
            url_corrupted_file.append(url)

    dict ={' fileUrl':url_corrupted_file}
    df = pd.DataFrame(dict)
    path = os.path.join(out_path,'file_to_download_again.csv')
    df.to_csv(path)
    return url_corrupted_file

# %%
## those three function are used to have the information concerning a file
## information are in the name of the file, so the name of the file is used to find its related information
## information mean variable, time_aggregation, model, scenario, year of the file

### this function permit to extract the word before the first character '_' in the input 'name'
### the input name is in format str
### returning the new_name, without the word found, will permit to re-use the function to find all 
#     the information concerning the studied file
def name_next_boundary(name):
    index_before_name=name.find('_') # returns the lowest index where the character '_' was found
    word = name[0:index_before_name] # first word in the string 'name', before the first character '_'
    new_name = name.replace(word+'_','') # delete the word found from the string 'name'
    return word, new_name # return, in string format, the word found (which is an information of the studied file), 
                    # and the string 'new_name', which is 'name' without the word found

# this function permit to extract the year of the studied file
# the year is always writen at the end of the name's file
# the input name is in format str
def find_year(name):
    index_before_name=name.rfind('_') # returns the highest index where the character '_' was found
    # the last character '_' is just before the year in the string 'name'
    # determine if the string 'name' ends with '.nc'
    if name.endswith('.nc'):
        # 'name' ends with '.nc'
        name_end = 3 # the three last character of the string name will be removed to find the year of the studied file
    else:
        # 'name' does not end with '.nc'
        name_end = 0 # no character will be removed at the end of 'name' to find the year of the studied file
    year = name[index_before_name+1:len(name)-name_end] # the year is extracted from the name of the file studied
    # based on the index_before_name (highest index where the character '_' was found) and the suffix of 'name'
    return year # the year in string format is returned

# This function use the functions 'name_next_boundary' and 'find_year' to extract the information of the file studied
# the input name is in format str, the name of the file from which we want information
def data_information(name):
    #### use of the function 'name_next_boundary': each time it is used, 
    # returns an information, and the name of the studied file without this information
    (variable, shorten_name) = name_next_boundary(name)
    (time_aggregation, shorten_name) = name_next_boundary(shorten_name)
    (model, shorten_name) = name_next_boundary(shorten_name)
    (scenario, shorten_name) = name_next_boundary(shorten_name)
    #### use the function 'find_year' to extract the information 'year' from the string 'shorten_name'
    year = find_year(shorten_name)
    # the function returns all the information of the studied file
    return variable, time_aggregation, model, scenario, year

# %% [markdown]
# # Define Paths

# %%
out_path=r'\\COWI.net\projects\A245000\A248363\CRVA\Datasets\NEX-GDDP-CMIP6'

# %% [markdown]
# # Infos for Multiprocessing

# %%
# count the number of CPU/cores
mp.cpu_count()
# Out:
# 8

# %%
NBCORES=5

# %% [markdown]
# # Complete list of url with files to download

# %%
# register information from csv file
#all_urls = pd.read_csv(r'C:\Users\CLMRX\OneDrive - COWI\Documents\GitHub\CRVA_tool\outputs\NEX-GDDP-CMIP6\gddp-cmip6-thredds-fileserver.csv')
csv_path = os.path.join(out_path,'gddp-cmip6-thredds-fileserver.csv')
all_urls = pd.read_csv(csv_path)

# %%
### make all elements of the csv into a readable list

temp_list = all_urls[[' fileUrl']].T# transpose csv
temp_list=temp_list.values.tolist()
temp_list=temp_list[0]
url_list=[s.replace(' ', '') for s in temp_list]

# %% [markdown]
# # Interest in temperature files
# Define list of url and files' names corresponding to temperature files between start day and stop day

# %%
url_list_climate_variable = [url for url in url_list if (variable_of_interest+'_') in url and int(url[len(url)-7:len(url)-3])>=start_year and int(url[len(url)-7:len(url)-3])<=stop_year and 'r1i1p1f1_gn' in url and temporal_resolution in url]

# %%
len(url_list_climate_variable)
# Out:
# 5312

# %%
# create url that will only that zone of interest
#url_list_climate_variable_zone_of_interest = [url.replace('thredds2/fileServer','thredds/ncss') + '?var='+variable_of_interest+'&north='+str(max_lat_zone_interest)+'&west='+str(min_lon_zone_interest)+'&east='+str(max_lon_zone_interest)+'&south='+str(min_lat_zone_interest)+'&disableProjSubset=on&horizStride=1&time_start='+url[len(url)-7:len(url)-3]+'-01-01T12%3A00%3A00Z&time_end='+url[len(url)-7:len(url)-3]+'-12-31T12%3A00%3A00Z&timeStride=1&addLatLon=true' for url in url_list_climate_variable]

# %%
#url_list_climate_variable_zone_of_interest

# %% [markdown]
# # Download file of interest

# %%
# download files with Threads
results = ThreadPool(NBCORES).imap_unordered(download_file, url_list_climate_variable) 
# first input is the function, second input must be an iterable
for r in results: #I don't understand why, without this step, it does not work
     print(r)
# Out:
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1951.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1951.nc exists
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1952.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1952.nc exists
#
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc exists
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc exists
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc exists
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc must be requested
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc must be requested
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1955.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1955.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1952.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1956.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1956.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1951.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1957.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1957.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1956.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1958.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1958.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1957.nc is not corruptedThe file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1955.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1959.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1959.nc exists
# None
#
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1958.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1962.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1962.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc must be requested
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1959.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1963.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1963.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1962.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1964.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1964.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1963.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1964.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1965.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1965.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc must be requested
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1965.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1966.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1966.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1966.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1967.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1967.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1967.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1968.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1968.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1968.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1970.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1970.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1970.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1972.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1972.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1972.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1971.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1971.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1971.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1973.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1973.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1973.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1969.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1969.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1969.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1974.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1974.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1974.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1976.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1976.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1976.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1980.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1980.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1980.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1975.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1975.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1975.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1979.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1979.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1979.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc exists
# None
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc must be requested
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1961.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1954.nc did not open
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1953.nc did not open
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1978.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1978.nc exists
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1978.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1981.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1981.nc exists
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1981.nc is not corrupted
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1977.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1977.nc exists
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1977.nc must be requested
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1983.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1983.nc exists
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1983.nc must be requested
#
# Name of the file: hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1984.nc
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1984.nc exists
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[18], line 4
#       2 results = ThreadPool(NBCORES).imap_unordered(download_file, url_list_climate_variable)
#       3 # first input is the function, second input must be an iterable
# ----> 4 for r in results: #I don't understand why, without this step, it does not work
#       5      print(r)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\multiprocessing\pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# Cell In[4], line 28, in download_file(file)
#      23 print('\nFile '+f_name+' did not open')
#      25 #connect_timeout = 1 # time in seconds, the timeout for establishing a connection to the server. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "connect" key to the desired timeout value:
#      26 #read_timeout = 1000 # time in seconds, the timeout for waiting for a response from the server after the connection has been established. This timeout value can be set by passing the "timeout" parameter to the requests.request() function and setting the "read" key to the desired timeout value:
# ---> 28 r = requests.get(file)#, timeout=(connect_timeout, read_timeout)) # return the url were data need to be downloaded
#      29 # download data in the servor for datasets
#      30 with open(f'//COWI.net/projects/A245000/A248363/CRVA/Datasets/NEX-GDDP-CMIP6/{f_name}', 'wb') as f:
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\miniconda3\envs\geodata\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
name_list_climate_variable = produce_name_list(url_list_climate_variable)
name_list_climate_variable_corrupted = list_name_corrupted_file(name_list_climate_variable,out_path)
url_corrupted_file=url_to_download_again(url_list_climate_variable,name_list_climate_variable_corrupted)
len(name_list_climate_variable_corrupted)
# Out:
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
# 5184
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open

# %%
while name_list_climate_variable_corrupted!=[]:
    # download files with Threads
    results = ThreadPool(NBCORES).imap_unordered(download_file, url_corrupted_file) 
    # first input is the function, second input must be an iterable
    for r in results: #I don't understand why, without this step, it does not work
         print(r)
    name_list_climate_variable_corrupted = list_name_corrupted_file(name_list_climate_variable,out_path)
    url_corrupted_file=url_to_download_again(url_list_climate_variable,name_list_climate_variable_corrupted)
    len(name_list_climate_variable_corrupted)
# Out:
# The file hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1953.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1954.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1954.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1954.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1955.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1955.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1955.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1956.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1956.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1956.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1957.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1957.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1957.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1958.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1958.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1958.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1959.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1959.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1959.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1960.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1960.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1960.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1961.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1961.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1961.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1962.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1962.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1962.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1963.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1963.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1963.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1964.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1964.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1964.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1965.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1965.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1965.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1966.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1966.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1966.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1967.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1967.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1967.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1968.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1968.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1968.nc must be requested
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1982.nc did not open
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1969.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1969.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1969.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1970.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1970.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1970.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1971.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1971.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1971.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1972.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1972.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1972.nc must be requested
#
# File hurs_day_ACCESS-CM2_historical_r1i1p1f1_gn_1960.nc did not open
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1973.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1973.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1973.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1974.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1974.nc exists
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1975.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1975.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1974.nc must be requested
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1975.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1976.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1976.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1976.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1977.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1977.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1977.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1978.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1978.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1978.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1979.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1979.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1979.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1980.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1980.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1980.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1981.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1981.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1981.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1982.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1982.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1982.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1983.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1983.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1983.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc must be requested
#
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc must be requested
# Name of the file: hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc exists
# The file hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc must be requested
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1984.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1985.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1986.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1987.nc did not open
#
# File hurs_day_ACCESS-ESM1-5_historical_r1i1p1f1_gn_1988.nc did not open
